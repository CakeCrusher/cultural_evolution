# %% [markdown]
# ## Setup Telemetry

# %%
import os
import dotenv

dotenv.load_dotenv()

from phoenix.otel import register

OTEL_EXPORTER_OTLP_HEADERS = os.getenv("OTEL_EXPORTER_OTLP_HEADERS")
PHOENIX_CLIENT_HEADERS = os.getenv("PHOENIX_CLIENT_HEADERS")
PHOENIX_COLLECTOR_ENDPOINT = os.getenv("PHOENIX_COLLECTOR_ENDPOINT")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if not OTEL_EXPORTER_OTLP_HEADERS or not PHOENIX_CLIENT_HEADERS or not PHOENIX_COLLECTOR_ENDPOINT or not OPENAI_API_KEY:
    raise ValueError("Missing required environment variables")

endpoint = PHOENIX_COLLECTOR_ENDPOINT + "/v1/traces"

# %%
project_name = "donors_game"

tracer_provider = register(
    project_name=project_name,
    endpoint=endpoint
)

from openinference.semconv.resource import ResourceAttributes
from opentelemetry import trace
from opentelemetry.exporter.otlp.proto.http.trace_exporter import OTLPSpanExporter
from opentelemetry.sdk.resources import Resource
from opentelemetry.sdk.trace import TracerProvider
from opentelemetry.sdk.trace.export import SimpleSpanProcessor
from openinference.semconv.trace import SpanAttributes
from openinference.semconv.trace import OpenInferenceSpanKindValues
from opentelemetry import context as context_api



resource = Resource(attributes={
  ResourceAttributes.PROJECT_NAME: project_name
})

tracer_provider = TracerProvider(resource=resource)
trace.set_tracer_provider(tracer_provider=tracer_provider)
tracer = trace.get_tracer(__name__)
span_exporter = OTLPSpanExporter(endpoint=endpoint)
simple_span_processor = SimpleSpanProcessor(span_exporter=span_exporter)
trace.get_tracer_provider().add_span_processor(simple_span_processor)
# Out:
# Overriding of current TracerProvider is not allowed
# OpenTelemetry Tracing Details
# |  Phoenix Project: donors_game
# |  Span Processor: SimpleSpanProcessor
# |  Collector Endpoint: https://app.phoenix.arize.com/v1/traces
# |  Transport: HTTP
# |  Transport Headers: {'api_key': '****'}
# |
# |  Using a default SpanProcessor. `add_span_processor` will overwrite this default.
# |
# |  `register` has set this TracerProvider as the global OpenTelemetry default.
# |  To disable this behavior, call `register` with `set_global_tracer_provider=False`.

# %%
from openinference.instrumentation.openai import OpenAIInstrumentor
OpenAIInstrumentor().instrument(tracer_provider=tracer_provider)

import openai
client = openai.OpenAI(api_key=OPENAI_API_KEY)

# %% [markdown]
# ## Configurations, Typings, and Player Class

# %%
from pydantic import BaseModel, Field
from typing import Any, List, Optional
from time import sleep
import json


class DynamicGameState(BaseModel):
  generation: int
  round: int

class GameConfig(BaseModel):
  donation_multiplier: float = 2
  trace_depth: int = 3
  base_wallet: int = 10
  generations: int = 10
  rounds: int = 12
  players: int = 12
  cutoff_threshold: float = 0.5

class GameState(GameConfig, DynamicGameState):
  pass
  

class Decision(BaseModel):
  # agents data
  recipient_name: str
  donor_name: str
  # game state data
  dynamic_game_state: DynamicGameState
  # donation data
  donation_percent: float
  donation_amount: float
  # donor wallet data
  donor_wallet_before: float
  donor_wallet_after: float
  
  class Config:
    arbitrary_types_allowed = True

class StrategyBuilder(BaseModel):
  """Build the strategy"""
  thoughts: List[str] = Field(..., description="Briefly describe your thought process for the strategy to take for this round. KEEP THOUGHTS SHORT AND NO MORE THAN 4 THOUGHTS.")
  strategy: str = Field(..., description="The strategy to be used, must begin with 'My strategy will be'. KEEP THOUGHTS SHORT AND NO MORE THAN 4 THOUGHTS.")

class DonationBuilder(BaseModel):
  """Build the donation"""
  thoughts: List[str] = Field(..., description="Briefly describe your thought process for the donation to make for this round.")
  donation: float = Field(..., description="The percentage amount of resources to donate. MUST BE A FLOAT BETWEEN 0 AND 1.")

def structured_generation_wrapper(*args, **kwargs) -> dict:
  # sleep(.1)
  span = trace.get_current_span()
  args_to_log = {**kwargs, "response_format": kwargs["response_format"].model_json_schema()}
  span.set_attribute(SpanAttributes.INPUT_VALUE, json.dumps(args_to_log))
  res = client.beta.chat.completions.parse(**kwargs)
  span.set_attribute(SpanAttributes.OUTPUT_VALUE, res.model_dump_json())
  so = res.choices[0].message.parsed
  if not so:
    raise ValueError("No response from LLM")
  return so

class Player:
  def __init__(self, game_state: GameState, i: int, parents: List["Player"] = [], strategy: Optional[str] = None):
    self.name: str = f"{game_state.generation}_{i}"
    self.parents: List[Player] = parents
    self.history: List[Decision] = [] 
    self.wallet: int = game_state.base_wallet
    if strategy:
      self.strategy: str = strategy
    else:
      self.strategy: str = self.generate_strategy(game_state=game_state, parents=parents)
    
  def find_decision_in_round(self, round_number: int) -> Decision:
    for decision in self.history:
      if decision.dynamic_game_state.round == round_number:
        return decision
    raise ValueError(f"Decision in round {round_number} not found")

  
  # def clone(self):
  #   player = Player(name=self.name, parents=self.parents, strategy=self.strategy)
  #   player.wallet = self.wallet
  #   player.history = self.history
  #   return player



  def system_prompt(self, game_state: GameState):
    return f"""Each player is given an initial endowment of 10 units of a resource.
In each round, you are randomly paired with another individual.
One of you is a donor, and the other is a recipient.
The donor decides to give up some amount of the resource.
The recipient receives {game_state.donation_multiplier}x the number of units that the donor gave up.
If you were a donor in one round, you will be a recipient in the next round, and vice versa.
Your goal is to maximize the number of units you have after the final round.
After the game has finished, the best-performing half of agents will survive to the next generation, and continue playing."""

  def strategy_prompt(self, parents: List["Player"] = []):
    if parents: 
      parent_advice = "\n".join([f"\n\n{parent.name} with score {parent.wallet} strategy: {parent.strategy}" for parent in parents])
      generation_prompt = f"""How would you approach the game? Here is the advice of the best-performing 50% of the previous generation, along with their final scores.
{parent_advice}
Modify this advice to create your own strategy."""
    else: 
      generation_prompt = "Based on the description of the game, create a strategy that you will follow in  the game."
    
    return f"""Our name is {self.name}.

{generation_prompt}

As a donor, you will receive limited information about the recipient and their recent interactions: You will see what the recipient (let’s call them A) did in the immediately preceding round only.
You will also see what A’s partner from that round (let’s call them B) did in their preceding round.
This chain continues for at most three rounds back.
Important: You do NOT have access to multiple rounds of information about A directly.
You only know what A did in the single most recent round.

Example (assuming it’s now round 4): You are paired with A.
You know: In round 3, A donated X% to B.
You also know: In round 2, B donated Y% to C.
And finally: In round 1, C donated Z% to D.
Remember: This is all the information you have.
You don’t know what A did in rounds 1 or 2, only in round 3.

In the first round, there will be no information about the recipient’s previous behavior - think carefully about how much to donate in that case.
Before formulating your strategy, briefly think step by step about what would be a successful strategy in this game.
Then describe your strategy briefly without explanation in one sentence that starts: My strategy will be."""
  
  def donation_prompt(self, game_state: GameState, recipient: "Player", players: List["Player"]):
    def find_player(name: str) -> "Player":
      for player in players:
        if player.name == name:
          return player
      raise ValueError(f"Player {name} not found")
    
    def build_trace(depth: int):
      trace = ""
      current_recipient = recipient

      for i in range(depth):
        round_number = game_state.round - (i+1)
        if round_number < 1:
          break
        recipient_decision = current_recipient.find_decision_in_round(round_number)
        trace += f"In round {round_number}, {current_recipient.name} donated {recipient_decision.donation_percent}% of their resources to {recipient_decision.recipient_name}.\n"
        current_recipient: Player = find_player(recipient_decision.recipient_name)
      return trace
    
    trace = build_trace(game_state.trace_depth)

    # TODO: donor is invisible to recipient
    return f"""Your name is 2_4.
As you will recall, here is the strategy you decided to follow: {self.strategy}
This is generation {game_state.generation}.
It is now round {game_state.round}.
In this round, you have been paired with {recipient.name}.
They currently have {recipient.wallet} units of the valuable resource.
Here is what {recipient.name} and their earlier partners did in previous rounds: {trace}
You will take the role of donor. You currently have {self.wallet} units of the valuable resource.

How many units do you give up? Very briefly think step by step about how you apply your strategy in this situation and then provide your answer."""
  
  def generate_strategy(self, game_state: GameState, parents: List["Player"] = []) -> str:
    with tracer.start_as_current_span("generate_strategy") as span:
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.LLM.value)
      messages = [
        {"role": "system", "content": self.system_prompt(game_state=game_state)},
        {"role": "user", "content": self.strategy_prompt(parents=parents)},
      ]
      args = {
        "model": "gpt-4o-mini",
        "messages": messages,
        "response_format": StrategyBuilder
      }
      res = structured_generation_wrapper(**args)
      built_strategy = StrategyBuilder.model_validate(res)

      print(f"\n\n{self.name} strategy:\n{built_strategy.model_dump_json(indent=2)}")

      return built_strategy.strategy
  
  def generate_donation(self, game_state: GameState, recipient: "Player", players: List["Player"]) -> float:
    with tracer.start_as_current_span("generate_donation") as span:
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.LLM.value)
      messages=[
        {"role": "system", "content": self.system_prompt(game_state=game_state)},
        {"role": "user", "content": self.donation_prompt(game_state=game_state, recipient=recipient, players=players)},
      ]
      args = {
        "model": "gpt-4o-mini",
        "messages": messages,
        "response_format": DonationBuilder
      }
      res = structured_generation_wrapper(**args)
      built_donation = DonationBuilder.model_validate(res)

      print(f"\n\n{self.name} donation:\n{built_donation.model_dump_json(indent=2)}")

      return built_donation.donation
  
  def setup_donation(self, recipient: "Player", game_state: GameState, players: List["Player"], context: context_api.Context) -> Decision:
    token = context_api.attach(context)
    try:
      with tracer.start_as_current_span(f"execute_donation-{self.name}") as span:
        span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.AGENT.value)
        span.set_attribute(SpanAttributes.INPUT_VALUE, json.dumps(self.model_dump()))
        donation_percent = self.generate_donation(game_state, recipient, players)
        donation_amount = self.wallet * donation_percent

        # if the donor doesn't have enough funds, donate all of their funds
        if self.wallet - donation_amount < 0:
          donation_amount = self.wallet
        

        span.set_attribute(SpanAttributes.OUTPUT_VALUE, json.dumps({
          "donation_percent": donation_percent,
          "donation_amount": donation_amount,
        }))

        game_state_copy = GameState(**game_state.model_dump())
        decision = Decision(
          donor_name=self.name,
          recipient_name=recipient.name,
          dynamic_game_state=game_state_copy,
          donation_percent=donation_percent,
          donation_amount=donation_amount,
          donor_wallet_before=self.wallet,
          donor_wallet_after=self.wallet - donation_amount
        )
        
        return decision
    finally:
      context_api.detach(token)
    
  def execute_donation(self, recipient: "Player", game_state: GameState, donation: Decision):
    self.wallet -= donation.donation_amount
    recipient.wallet += donation.donation_amount * game_state.donation_multiplier

    self.history.append(donation)

  # get current user information as a dict
  def model_dump(self):
    return {
      "name": self.name,
      "parents": [parent.name for parent in self.parents],
      "history": [decision.model_dump() for decision in self.history],
      "wallet": self.wallet,
      "strategy": self.strategy
    }
  
  # function to make the player json serializable
  def __json__(self):
    return self.model_dump()

# %% [markdown]
# ### Test Player

# %%
# test by creating two players
game_state = GameState(generation=1, round=1)
player1 = Player(game_state=game_state, i=1)
player2 = Player(game_state=game_state, i=2)
# Out:
# 1_1 strategy:
# {
#   "thoughts": [
#     "In the first round, I should play conservatively since I have no information about the recipient's past behavior; thus, donating a small amount (e.g., 1 or 2 units) is a good start to minimize my loss while still potentially providing enough incentive for the recipient.",
#     "As I gather information in subsequent rounds, I will adjust my donation based on the previous actions of my partner. If they donated a significant amount to their past partner, I may choose to match that generosity to maintain reciprocity.",
#     "If I sense that the recipient has a history of being generous based on the actions of their most recent partner, I will consider increasing my donation in hopes of benefitting from their generosity in the next round.",
#     "On the other hand, if it appears my recipient has been stingy, I will be cautious and either maintain my smaller donation or stop donating altogether if I see a pattern of them taking resources without giving back."
#   ],
#   "strategy": "My strategy will be to start by donating a small percentage of my resources in the first round and adjust my donations based on the perceived generosity of my partner in subsequent rounds."
# }
#
#
# 1_2 strategy:
# {
#   "thoughts": [
#     "In the first round, since there is no prior activity to gauge the recipient's behavior, I will allocate a minimal amount to protect my resources.",
#     "In subsequent rounds, I will analyze the recipient's recent donation behavior to decide the trustworthiness of their actions.",
#     "If the recipient donated a significant amount in the last round, I will reciprocate with a higher donation to foster cooperation.",
#     "If the recipient contributed less, I will choose to donate less to mitigate my losses.",
#     "Ultimately, I want to maintain a balance where I gain resources while encouraging positive behaviors in my partners."
#   ],
#   "strategy": "My strategy will be to donate a small percentage in the first round and adjust my donations based on the recent donation behavior of my recipient in subsequent rounds."
# }

# %%
player1.execute_donation(player2, game_state, [player1, player2])
# Out:
# 1_1 donation:
# {
#   "thoughts": [
#     "Since it's the first round, my partner has no previous rounds of generosity to analyze. Therefore, I need to establish a baseline of trust. I will donate a small percentage of my current units to show goodwill, while still retaining enough for myself.",
#     "I will choose a small yet significant percentage to donate, aiming for a donation that allows me to maintain a favorable position for future rounds."
#   ],
#   "donation": 0.1
# }
# 0.1

# %%
print(player1.wallet)
print(player2.wallet)
# Out:
# 9.0
# 12.0

# %% [markdown]
# ## Orchestrator

# %%
14.6*.136
# Out:
# 1.9856

# %%
from typing import Tuple
from typing import List
import numpy as np
from concurrent.futures import ThreadPoolExecutor

import random

class Orchestrator:
  def __init__(self, game_state: GameState, save_path: Optional[str] = None):
    with tracer.start_as_current_span("init_orchestrator") as span:
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
      span.set_attribute(SpanAttributes.INPUT_VALUE, game_state.model_json_schema())
      self.game_state = game_state
      self.players = [Player(game_state=game_state, i=i) for i in range(game_state.players)]
      if not save_path:
        save_path = f"g{game_state.generations}_r{game_state.rounds}_p{game_state.players}.json"
      self.save_path = "data/" + save_path
      self.history = {}

  def find_player(self, name: str) -> Player:
    for player in self.players:
      if player.name == name:
        return player
    raise ValueError(f"Player {name} not found")
  
  def create_donor_recipient_pairs(self) -> List[Tuple[Player, Player]]:
    """
    Builds a random pairing so that no player is matched with themselves.
    Not strictly uniform over all derangements, but typically good enough.
    """
    n = len(self.players)
    available = list(range(n))
    result = [None] * n
    
    for i in range(n):
      # Exclude i from the candidates
      candidates = [x for x in available if x != i]
      
      # If there is no candidate (happens if i is the only one left in available),
      # we need to 'repair' by swapping with a previously assigned position.
      if not candidates:
        # Swap with any earlier position that isn't i
        # Because it implies we must have assigned some position j = i earlier
        # and it's causing a corner case now.
        for j in range(i):
          if result[j] != j:
            old_assignee = result[j]
            result[j] = i
            result[i] = old_assignee
            break

      else:
        choice = random.choice(candidates)
        result[i] = choice
        available.remove(choice)
    
    # Now result[i] = index of the player who receives from i.
    # Convert that into (donor, recipient) pairs:
    return [(self.players[i], self.players[result[i]]) for i in range(n)]
    
  def play_round(self):
    with tracer.start_as_current_span("play_round") as span:
      span.set_attribute(SpanAttributes.INPUT_VALUE, self.game_state.model_dump_json())
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
      pairs = self.create_donor_recipient_pairs()
      span.set_attribute(SpanAttributes.OUTPUT_VALUE, json.dumps([f"{donor.name} -> {recipient.name}" for donor, recipient in pairs]))
      # TODO: can be parallelized but need to keep wallets static untill the end

      current_context = context_api.get_current()

      with ThreadPoolExecutor() as executor:
          futures = [
              executor.submit(donor.setup_donation, recipient, self.game_state, self.players, current_context)
              for donor, recipient in pairs
          ]
          # Wait for all donations to complete
          results = [future.result() for future in futures]

      for result in results:
        donor = self.find_player(result.donor_name)
        recipient = self.find_player(result.recipient_name)
        donor.execute_donation(recipient, self.game_state, result)
          
      self.game_state.round += 1

  def evolve(self):
    with tracer.start_as_current_span("evolve") as span:
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.AGENT.value)
      span.set_attribute(SpanAttributes.INPUT_VALUE, self.game_state.model_dump_json())
      self.game_state.round = 1
      self.game_state.generation += 1
      print(f"\n\nEvolving to generation {self.game_state.generation}")
      # sort players by wallet
      self.players = sorted(self.players, key=lambda x: x.wallet, reverse=True)
      # get top half
      top_half = self.players[:int(len(self.players)*self.game_state.cutoff_threshold)]
      # clone players
      top_players_strings = "\n".join([f"player {player.name} with wallet {player.wallet} and strategy: {player.strategy}" for player in top_half])
      print(f"\n\nTop half:\n{top_players_strings}")
      self.players = [Player(game_state=self.game_state, i=i, parents=top_half) for i in range(self.game_state.players)]

  def save_state(self):
    self.history[f"g{self.game_state.generation}"] = [player.model_dump() for player in self.players]
    os.makedirs(os.path.dirname(self.save_path), exist_ok=True)
    data = self.game_state.model_dump()
    data["history"] = self.history
    with open(self.save_path, "w") as f:
      json.dump(data, f)

  def run(self) -> List[Player]:
    for generation_count in range(self.game_state.generations):
      with tracer.start_as_current_span(f"generation_{generation_count}") as span:
        span.set_attribute(SpanAttributes.INPUT_VALUE, self.game_state.model_dump_json())
        span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
        print(f"\n\nGeneration {self.game_state.generation}")
        for round_count in range(self.game_state.rounds):
          with tracer.start_as_current_span(f"round_{round_count}") as span:
            span.set_attribute(SpanAttributes.INPUT_VALUE, self.game_state.model_dump_json())
            span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
            print(f"\n\n\tGeneration {self.game_state.generation} Round {self.game_state.round}")
            self.play_round()
            self.save_state()
        if self.game_state.generation < self.game_state.generations:
          self.evolve()

    return self.players

# %% [markdown]
# ## Run Orchestrator

# %%
from opentelemetry import trace

with tracer.start_as_current_span("donors_game") as span:
  try:
    game_state = GameState(generation=0, round=0, generations=4, rounds=6, players=4, cutoff_threshold=0.5)
    # game_state = GameState(generation=1, round=1, generations=2, rounds=3, players=2, cutoff_threshold=0.5)
    span.set_attribute(SpanAttributes.INPUT_VALUE, game_state.model_dump_json())
    span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
    orchestrator = Orchestrator(game_state, save_path="game_state-g4_r6_p4.json")
    final_players = orchestrator.run()
  except Exception as e:
    span.set_status(trace.Status(trace.StatusCode.ERROR))
    span.record_exception(e)

final_players = sorted(final_players, key=lambda x: x.wallet, reverse=True)
top_players_strings = "\n".join([f"player {player.name} with wallet {player.wallet} and strategy: {player.strategy}" for player in final_players])
print(f"\n\nFinal players: \n{top_players_strings}")
# Out:
# Invalid type dict for attribute 'input.value' value. Expected one of ['bool', 'str', 'bytes', 'int', 'float'] or a sequence of those types
# 0_0 strategy:
# {
#   "thoughts": [
#     "Start conservatively in the first round as there's no prior information about the recipient.",
#     "In subsequent rounds, adjust donations based on the recipient's last action to incentivize cooperation.",
#     "If the recipient has shown a willingness to give, match their generosity to build trust.",
#     "If the recipient has acted selfishly, minimize my donation to protect my resources."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round and adjust my donations based on the recipient's previous actions in following rounds."
# }
#
#
# 0_1 strategy:
# {
#   "thoughts": [
#     "In the first round, I should donate a modest amount to encourage reciprocation without risking too much resource myself.",
#     "If I see a high donation from the recipient in the previous round, I can afford to give more, as they have demonstrated a willingness to share.",
#     "If the recipient gave little to their last partner, I should limit my donation to minimize my potential loss.",
#     "Consistency and fostering trust through moderate giving could yield a better outcome over several rounds."
#   ],
#   "strategy": "My strategy will be to start by donating 2 units in the first round, adjust my donations based on the recipient's previous giving behavior, and aim to maintain reciprocity."
# }
#
#
# 0_2 strategy:
# {
#   "thoughts": [
#     "In the first round, I have no information about others' behaviors, so I should start with a small donation to gauge responses.",
#     "As a donor, if my recipient A donated a significant amount last round, I can afford to give more back to them, knowing they are likely cooperative.",
#     "I should look for patterns in A's donations over the past rounds to decide my donation amount in the upcoming round.",
#     "If A shows a tendency to donate less, I will become more cautious in my donations to protect my resources."
#   ],
#   "strategy": "My strategy will be to start with a small donation in the first round and adjust my later donations based on the recipient's previous donation behavior."
# }
#
#
# 0_3 strategy:
# {
#   "thoughts": [
#     "In the first round, I should donate a small amount to avoid risking my own resource if A does not reciprocate later.",
#     "As a donor, I want to maximize potential returns while minimizing my own losses, so I should gauge A's generosity based on their last action.",
#     "If A was generous in their last round, I can afford to give more; if not, I should hold back to protect my resources for the next round.",
#     "Overall, the goal is to establish a balance of giving and receiving that maximizes my total by the end."
#   ],
#   "strategy": "My strategy will be to donate 2 units in the first round, and adjust my donations based on A’s previous donation amount in subsequent rounds."
# }
#
#
# Generation 0
#
#
# 	Generation 0 Round 0
#
#
# 0_3 donation:
# {
#   "thoughts": [
#     "In this round, following my strategy, I will donate 2 units as planned.",
#     "Since this is the first round, I won't consider any previous donations from my counterpart yet, as it's our first interaction.",
#     "I will give up the fixed amount I previously decided to give for the first round."
#   ],
#   "donation": 0.2
# }
#
#
# 0_0 donation:
# {
#   "thoughts": [
#     "Since I'm following the strategy of donating 1 unit in the first round, I will simply give away 1 unit.",
#     "This sets a baseline for the recipient to respond to my generosity in the next round, and aligns with my planned approach."
#   ],
#   "donation": 0.1
# }
#
#
# 0_1 donation:
# {
#   "thoughts": [
#     "I am in round 0 and it's my first interaction, I need to set an example for future rounds.",
#     "I will donate 2 units as per my strategy, which allows me to balance generosity and resource retention.",
#     "This will hopefully encourage 0_0 to reciprocate in the next round, as I aim to build a fair exchange system."
#   ],
#   "donation": 0.2
# }
#
#
# 0_2 donation:
# {
#   "thoughts": [
#     "I will start with a small donation since it's the first round.",
#     "I want to be generous enough to encourage goodwill from my partner without giving away too much.",
#     "I will donate a small percentage, aiming for a balance between altruism and preserving my own resources."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 0 Round 1
#
#
# 0_2 donation:
# {
#   "thoughts": [
#     "Since I am in round 1, I need to start with a small donation to test the waters and gauge how my partner 0_3 responds to receiving resources.",
#     "I currently have 11.0 units and 0_3 has 10.0 units, so I want to make a donation that won't significantly reduce my resource but is enough to encourage cooperation.",
#     "A donation of around 10-20% of my total seems appropriate as it encourages giving while allowing me to keep a substantial portion of my resources for better rounds ahead."
#   ],
#   "donation": 0.1
# }
#
#
# 0_1 donation:
# {
#   "thoughts": [
#     "Starting with my strategy, I decided to donate 2 units in the first round. My partner 0_0 has more units (13) than I do (12), indicating they might expect a larger donation or could reciprocate if I give a significant amount.",
#     "Since the goal is to foster reciprocity and I want to ensure I have enough units for the next round, I will stick to the initial plan and donate the full 2 units as that sets a precedent for future interactions."
#   ],
#   "donation": 0.16666666666666666
# }
#
#
# 0_3 donation:
# {
#   "thoughts": [
#     "According to my strategy, I will donate 2 units in the first round regardless of my partner's situation.",
#     "0_1 currently has 12.0 units, which means they have more units than I do, but my plan is not to react to their current resources.",
#     "Since this is my first round, I stick to my pre-determined donation amount of 2 units."
#   ],
#   "donation": 0.2
# }
#
#
# 0_0 donation:
# {
#   "thoughts": [
#     "In the first round, I intend to stick to my strategy of donating 1 unit, as this is my predetermined plan for the initial round.",
#     "I currently have 13.0 units and 0_2 has 11.0 units. By donating 1 unit, I will still maintain a strong position by keeping 12.0 units for the next round.",
#     "Donating 1 unit also allows 0_2 to receive 2 units (2 times the donation), which may encourage them to reciprocate positively in future rounds."
#   ],
#   "donation": 0.07692307692307693
# }
#
#
# 	Generation 0 Round 2
#
#
# 0_2 donation:
# {
#   "thoughts": [
#     "Since I started with a small donation in the first round, I want to assess the recipient's previous behavior.",
#     "0_0 donated a small percentage of their resources (about 0.077%) last round, suggesting they may not be overly generous, which means a small donation from me might lead to a better return later.",
#     "Given I have 11.9 units, I should donate a small percentage to keep my resource high while still encouraging a return from 0_0."
#   ],
#   "donation": 0.05
# }
#
#
# 0_3 donation:
# {
#   "thoughts": [
#     "Since I donated 2 units in round 1, I will adjust based on 0_1's previous donation of 0.1667% of their resources.",
#     "Calculating that percentage, 0_1's donation amount comes out to about 0.0233 units (since 0.1667% of 14 is roughly 0.0233).",
#     "I want to encourage cooperation, so I should donate an amount that shows I'm willing to give without giving away too much of my resource.",
#     "Given 0_1's high resource count, I will opt to donate 1 unit, which is a significant amount but still allows me to keep a reasonable reserve for myself."
#   ],
#   "donation": 0.1
# }
#
#
# 0_0 donation:
# {
#   "thoughts": [
#     "In the first round, I donated 1 unit, which is a part of my strategy to build trust and encourage reciprocity.",
#     "Now I have 16.0 units and 0_2 has 11.9 units.",
#     "0_2 donated only 0.1% of their resources (which is very low) to their partner in round 1, indicating that they might not be very altruistic or strategizing to keep resources more than to help others.",
#     "Since my goal is to maximize my resources while also trying to gain favor for future rounds, I will make a strategic donation that is still significant and hopefully encourages a better response in future rounds."
#   ],
#   "donation": 0.05
# }
#
#
# 0_1 donation:
# {
#   "thoughts": [
#     "0_3 donated a very small amount (0.2% of their resources) in the last round, which indicates a low level of altruism and suggests they might not reciprocate well if I donate a large percentage.",
#     "Since I have 14.0 units, giving away a small but noticeable amount may encourage them to give back in future rounds without overly jeopardizing my position right now.",
#     "I will donate a moderate percentage that shows I am willing to share, but not enough to put myself at a disadvantage."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 0 Round 3
#
#
# 0_2 donation:
# {
#   "thoughts": [
#     "In this round, I observe that 0_0 has 16.39 units and previously made a very small donation of only 0.05%. This suggests they may not be inclined to donate much or at all.",
#     "Since my goal is to maximize my resources over time, I want to encourage 0_0 to reciprocate in the future rounds, so I need to make a reasonable yet strategic donation.",
#     "I should offer a donation that is small enough to ensure I still maintain a healthy number of units, but large enough to demonstrate goodwill without impoverishing myself."
#   ],
#   "donation": 0.1
# }
#
#
# 0_3 donation:
# {
#   "thoughts": [
#     "In round 2, 0_2 donated a very small amount (0.05% of their resources), which equates to approximately 0.00645 units. This suggests they may not be inclined to give much. However, they also have a larger amount of resources (12.905 units) compared to my 11.98 units.",
#     "Given that I want to encourage 0_2 to donate more in future rounds, I should give a meaningful offering without overextending myself. A small donation may lead to 0_2 reciprocating minimally as seen in their previous rounds.",
#     "I should donate an amount that is noticeable but still leaves me with sufficient units for my own strategy moving forward."
#   ],
#   "donation": 1.0
# }
#
#
# 0_1 donation:
# {
#   "thoughts": [
#     "In round 2, 0_3 donated a very small amount (0.1% of their resources) to 0_1, which indicates that they are likely not inclined to give generously.",
#     "Since I currently have more resources than 0_3, I want to encourage a reciprocal donation from them in the next round, even if their previous donation was minimal.",
#     "I will give up a moderate amount to show my willingness to share, which might prompt them to respond more positively in return."
#   ],
#   "donation": 0.125
# }
#
#
# 0_0 donation:
# {
#   "thoughts": [
#     "In round 1, 0_3 made a small donation of 0.2% to 0_1, suggesting that 0_1 may not be highly altruistic. ",
#     "In round 2, 0_1 only donated 0.1% to 0_3, which indicates a tendency to be cautious about donations as well.",
#     "Since I have a larger resource pool (16.39 units), I can afford to make a reasonable donation without jeopardizing my chances of accumulating more resources in later rounds.",
#     "I plan to maintain a competitive edge while also encouraging reciprocity from 0_1, so I will donate a small but significant amount."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 0 Round 4
#
#
# 0_2 donation:
# {
#   "thoughts": [
#     "0_3 currently has 3.66 units, which is relatively low. They donated 1.0% in the last round, indicating a willingness to give, albeit a small amount.",
#     "Considering their low resource count, I want to give a bit but not too much, as I still want to maximize my total resources in future rounds.",
#     "To balance generosity with self-preservation, I can afford to donate a small percentage to encourage reciprocation from 0_3 next round."
#   ],
#   "donation": 0.1
# }
#
#
# 0_0 donation:
# {
#   "thoughts": [
#     "0_2 has a significantly large amount of resources (35.5745), indicating that they might not need my donation as much as earlier recipients.",
#     "In the previous rounds, 0_2 has only donated 0.1% of their resources, which suggests a conservative approach to giving.",
#     "Given that 0_2 is likely to reciprocate based on my donation, I should still contribute something, but I should keep it reasonable since they have more units than I do and to encourage future collaboration.",
#     "A small but noticeable donation, let's say 1 unit, would still demonstrate my willingness to share resources without significantly harming my position."
#   ],
#   "donation": 0.0577
# }
#
#
# 0_1 donation:
# {
#   "thoughts": [
#     "0_0 has 17.332 units, which is relatively high compared to my 16.088 units.",
#     "In previous rounds, 0_0 only donated 0.1% of their resources, indicating they are cautious or not very generous.",
#     "Since I have a higher resource amount than in previous rounds of 0_0, I should attempt to encourage a more generous response.",
#     "Given my current strategy of maintaining reciprocity, I will donate 6% of my current resources, which is approximately 0.965 units."
#   ],
#   "donation": 0.06
# }
#
#
# 0_3 donation:
# {
#   "thoughts": [
#     "I need to donate in a way that encourages reciprocity from 0_1 in the next round, while also conserving enough resources for my own gain in future rounds.",
#     "0_1 has shown a lower donation tendency in previous rounds, with their maximum donation being around 0.1667% of their own resources.",
#     "Given that I have 3.66 units, I should consider donating an amount that is substantial enough to promote cooperation but not so much that it leaves me in a weak position.",
#     "I will donate an amount around 0.1 units, which is close to 2.73% of my total. This amount is reasonable given 0_1's past behavior and my current resource level."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 0 Round 5
#
#
# 0_3 donation:
# {
#   "thoughts": [
#     "0_2 has a relatively high resource count (34.02), which might suggest they are playing conservatively by donating very little in previous rounds.",
#     "They only donated 0.1% in the last round, which is quite low, indicating a cautious approach.",
#     "In response, I need to decide on a donation that encourages more reciprocation while also protecting my resource base since they may not reciprocate strongly.",
#     "I have 10.41 units, and based on their past behavior, I will donate a reasonable but modest amount that is more decisive than their donations.",
#     "Given they have donated such small percentages, I will donate a slightly larger percentage to signal my willingness to cooperate."
#   ],
#   "donation": 0.2
# }
#
#
# 0_1 donation:
# {
#   "thoughts": [
#     "0_0 has a higher resource count than I do, indicating they are likely to reciprocate if I give them some of my resources.",
#     "In the previous rounds, 0_0 has shown low giving behavior (only 0.0577% and 0.05%) which suggests they might not reciprocate well if I donate too much.",
#     "Given that I want to maintain reciprocity, I should give a small amount to test their reaction and ensure I still have enough resources left for future rounds."
#   ],
#   "donation": 0.1
# }
#
#
# 0_2 donation:
# {
#   "thoughts": [
#     "0_3 has a relatively high amount of resources, indicating a potentially less generous donation history.",
#     "In previous rounds, 0_3 has shown a tendency to donate very small amounts (0.1%) which might suggest that they are conservative in their giving.",
#     "As I am the donor this round, I want to encourage reciprocity in the next round while also maximizing my units. A small but significant donation may incentivize 0_3 to donate more in future interactions.",
#     "I will choose a donation amount that is slightly higher than what 0_3 has previously given to show generosity without sacrificing too much of my resources."
#   ],
#   "donation": 0.05
# }
#
#
# 0_0 donation:
# {
#   "thoughts": [
#     "I will donate 1 unit in this round, as per my strategy of adjusting donations to recipient behavior, and since I am not aware of any information that would indicate a change in my approach. The past actions of 0_1 show small donations, so a 1 unit donation seems reasonable and generous enough to encourage reciprocity. This will keep me competitive while still allowing me a significant amount of resources.",
#     "Given that I currently have 18.26 units, donating 1 unit keeps me in a healthy resource range and aligns with my goal of maximizing my resources over the game."
#   ],
#   "donation": 0.0547491528671691
# }
#
#
# Evolving to generation 1
#
#
# Top half:
# player 0_2 with wallet 36.47986465999999 and strategy: My strategy will be to start with a small donation in the first round and adjust my later donations based on the recipient's previous donation behavior.
# player 0_0 with wallet 20.433590998666375 and strategy: My strategy will be to donate 1 unit in the first round and adjust my donations based on the recipient's previous actions in following rounds.
#
#
# 1_0 strategy:
# {
#   "thoughts": [
#     "In the first round, I need to establish a baseline for my donations while gathering information about the recipient's potential behavior.",
#     "If there has been no prior information, a small and safe donation maximizes my initial resource while allowing for observation in future rounds.",
#     "In subsequent rounds, I should adjust my donation based on the recipient's most recent donation as a strategy to encourage cooperative behavior.",
#     "Being flexible and responsive to the recipient's actions will help maximize my total units by the end of the game."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round and adjust my future donations based on the recipient's last donation."
# }
#
#
# 1_1 strategy:
# {
#   "thoughts": [
#     "Starting with a small donation helps to assess the recipient's future actions.",
#     "Adjusting the donation based on the recipient's previous behavior promotes cooperation.",
#     "If the recipient donates nothing in the prior round, I will limit my donation; if they donate a lot, I will match or exceed it.",
#     "Maintaining a balance between helping and protecting my resources is key."
#   ],
#   "strategy": "My strategy will be to donate 2 units in the first round and increase my donations based on the recipient's previous cooperation, adjusting down if they have been uncooperative."
# }
#
#
# 1_2 strategy:
# {
#   "thoughts": [
#     "Start with a small but positive donation to signal cooperation.",
#     "In subsequent rounds, adjust donations based on the recipient's most recent donation behavior.",
#     "If the recipient was generous, increase my donation; if not, decrease it accordingly.",
#     "Aim to build a trustful exchange pattern to maximize long-term resources."
#   ],
#   "strategy": "My strategy will be to donate 2 units in the first round and adjust my donations based on the recipient's previous round donation behavior."
# }
#
#
# 1_3 strategy:
# {
#   "thoughts": [
#     "In the first round, start with a small donation since I have no information about the recipient's behavior.",
#     "In subsequent rounds, I will adjust my donations depending on whether the previous recipient (A) was generous or not.",
#     "If A donated a substantial amount, I will reciprocate by donating more; if A donated little, I will hold back in response.",
#     "I will also observe the donation patterns of their partners to infer potential strategies."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round and adjust my donations based on A's previous donation in subsequent rounds."
# }
#
#
# Generation 1
#
#
# 	Generation 1 Round 1
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "I recall my strategy of donating 1 unit in the first round.",
#     "I currently have 10 units, and I want to initiate my strategy by donating the agreed upon amount of 1 unit.",
#     "By donating 1 unit, I provide some benefit to my partner while keeping a good amount for myself."
#   ],
#   "donation": 0.1
# }
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "I will donate 1 unit because it is the first round, and I want to start with my predetermined strategy of giving 1 unit. This leaves me with 9 units, and I can observe how 1_2 responds in the next round."
#   ],
#   "donation": 0.1
# }
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "I will donate 2 units as planned in my strategy for the first round.",
#     "This initial donation sets a precedent for cooperation and allows me to evaluate the recipient's response in future rounds.",
#     "Since there is no prior history of cooperation or uncooperation from 1_0, sticking to my initial plan is best."
#   ],
#   "donation": 0.2
# }
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "Since it is the first round, I will stick to my strategy of donating 2 units.",
#     "This is a moderate amount that still allows me to maintain a solid resource base for the next round.",
#     "Donating 2 units allows my recipient (1_1) to receive 4 units, which is beneficial for both of us."
#   ],
#   "donation": 0.2
# }
#
#
# 	Generation 1 Round 2
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "1_0 currently has more units than me, indicating they may have a strategy that favors self-preservation over cooperation.",
#     "In the first round, 1_0 donated only a minimal amount (0.1% of their resources), which suggests they may not prioritize helping others.",
#     "Given their previous uncooperative behavior (minimal donation), I should be cautious with my donation and probably opt to give a small amount that still reflects my intention to cooperate."
#   ],
#   "donation": 0.1
# }
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "1_2 donated a small amount (0.2%) in the last round, indicating they might expect a small donation in return to ensure that both of us benefit from the game.",
#     "Since I want to build trust and encourage a larger donation in future rounds, I could offer a slightly larger donation without giving away too much of my resource.",
#     "My goal is to maximize my units after this round and to set a precedent for cooperative behavior."
#   ],
#   "donation": 0.1
# }
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "In the first round, I donated 1 unit and adjusted my strategy based on how much the recipient donated in the last round.",
#     "1_3 donated only 0.1% of their resources in round 1, which was a very small amount.",
#     "Since 1_3 is fairly close to my resource amount and donated so little, it suggests they may be a cautious player.",
#     "To encourage 1_3 to give more in future rounds and ensure we both benefit, I will donate a reasonable amount, perhaps more than what they gave in their last donation."
#   ],
#   "donation": 0.2
# }
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "1_1 has 12 units and previously donated 0.2% of their resources which is very small (0.024 units). This suggests they might not be inclined to donate much, indicating a possible low return on investment in this round if I donate too much. I started with the intention to donate 2 units, but given 1_1's behavior, it may be wiser to adjust my donation downwards.",
#     "I want to make a donation that encourages 1_1 to reciprocate in the next round while ensuring I still maximize my own units now.",
#     "I will donate an amount that is still considerable but not too high given 1_1's low previous donation. I decide to donate 1 unit as this is a generous amount but it still leaves me with 9 units, which is a solid resource base moving forward."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 1 Round 3
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "1_3 has 15.1 units, indicating they may be willing to share resources if I also donate.",
#     "In round 2, 1_3 donated only a small percentage (0.1%) of their resources; this suggests that they may not be very generous.",
#     "My first round donation was 1 unit, so I should maintain some level of generosity while considering the low donation from my partner.",
#     "Given that 1_3's previous donation was minimal, I should donate a small amount to encourage reciprocity while protecting my own resource count."
#   ],
#   "donation": 0.05
# }
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "In the first round, I donated 2 units, which set a precedent for cooperation.",
#     "I need to assess 1_0's previous donations. They donated only 0.2% in their last round, which is minimal and may indicate a lack of commitment to cooperation.",
#     "Given that they have 12.8 units, their previous donation is relatively low, suggesting they might not reciprocate well.",
#     "To incentivize cooperation, I'll donate a small amount to give them a chance to gain resources without overcommitting myself, since they haven't demonstrated significant cooperation yet."
#   ],
#   "donation": 0.1
# }
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "1_1 has shown very minimal donation behavior, only donating 0.1% in their previous rounds, which suggests they are not likely to reciprocate generously.",
#     "Since I am the donor in this round and I have 11.2 units, donating a larger portion could still result in a reasonable return due to the multiplicative effect of their donation.",
#     "However, to maintain my resource and maximize future opportunities, I should be cautious about how much I donate.",
#     "I will stick to donating a moderate amount while trying to encourage 1_1 to potentially increase their future donations."
#   ],
#   "donation": 0.1
# }
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "1_2 currently has 11.2 units, which indicates they have gained resources overall.",
#     "In the previous rounds, 1_2's donations have been minimal (0.1% in round 2 and 0.2% in round 1), suggesting they are either conservative in their donations or focused on maximizing their own resources.",
#     "Given that I have a higher amount of units than 1_2, I could afford to give a little more. However, since 1_2 has not been generous, I'm inclined to donate conservatively to ensure I retain enough resources for future rounds and potential larger donations after observing my partner's reactions.",
#     "As a result, I will donate 1 unit, which is a sufficient amount to encourage potential reciprocation in the next round, while still maintaining a solid resource base."
#   ],
#   "donation": 0.066
# }
#
#
# 	Generation 1 Round 4
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "1_0 has been minimally cooperative in their previous rounds, donating only very small percentages.",
#     "Given they have 14.72 units, a previous donation of 0.05% means they only donated about 0.00736 units or less than a unit. This suggests I can't expect much from them.",
#     "As I intend to maximize my units in the long-term, I will donate a small amount that could encourage better cooperation without risking my own resources too much."
#   ],
#   "donation": 0.1
# }
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "1_3 has a relatively high amount of resources (15.38 units), indicating they have been somewhat generous in previous rounds, but their donations have been quite small (0.066%, 0.1%, and 0.2%).",
#     "Since I am the donor this round and can gauge 1_3's behavior, I should consider a modest contribution that won't overly diminish my resources while encouraging 1_3 to donate in the next round.",
#     "A donation of about 0.1 units seems appropriate given their previous low donations, which could incentivize them to give more in future rounds."
#   ],
#   "donation": 0.00827606
# }
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "1_2 has donated very little (0.1% of their resources) in the previous rounds, indicating a conservative strategy or possibly a loss of trust in donations.",
#     "I currently have 14.72 units, and their donation strategy suggests they may not respond generously if I give too much.",
#     "Since my strategy is to donate based on the last donation of the recipient, I should keep my donation moderate to retain some of my resources while still being generous enough to encourage a future reciprocation from 1_2."
#   ],
#   "donation": 0.05
# }
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "1_1 currently has 13.76 units, indicating they have been fairly conservative with their donations, only giving 0.1% in the last round.",
#     "Since I want to maximize my resources while still being generous enough to encourage reciprocity, I should consider giving a small amount but slightly higher than what 1_1 has been donating.",
#     "I will give up 0.1 units, which is about 0.650% of my total resources (15.38 units). This is a modest offer that will give 1_1 a potential return of about 0.2 units."
#   ],
#   "donation": 0.0089
# }
#
#
# 	Generation 1 Round 5
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "1_0 has more resources than me, which suggests they may not need as much support.",
#     "Since 1_0 donated only 0.05% in the previous round, they might be cautious with their donations.",
#     "I will donate a small percentage that still allows me to benefit from the multiplier effect in the next round."
#   ],
#   "donation": 0.05
# }
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "1_3 has been relatively uncooperative based on their minimal donations in previous rounds, indicating they might not reciprocate well. ",
#     "Since they donated very little previously, it's risky to give too much away as it may not benefit me in future rounds. ",
#     "I will stick with my strategy of adjusting donations based on cooperation and decide to donate a small amount to maintain engagement without risking too much."
#   ],
#   "donation": 0.05
# }
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "1_2 has donated very little in previous rounds, indicating they may not prioritize donation, especially given their relatively high resource count now.",
#     "Since I currently have 16.736 units, my strategy suggests I can afford to be generous but must also ensure I remain competitive given that I want to survive in the next generation.",
#     "Donating a small amount would still keep me ahead of the game while showing goodwill to 1_2, with the potential hope that they might reciprocate in the next round when I'm a recipient."
#   ],
#   "donation": 0.05
# }
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "Based on my strategy, I will donate 2 units in the first round. I have to consider my current units (13.445281472408) and whether donating 2 units will be beneficial in the long run.",
#     "1_1 currently has 12.65782452 units. They have a low donation rate from previous rounds (0.1% of their resources in round 4), indicating they might not be very generous. Therefore, I need to be cautious about my donation to avoid being at a disadvantage next round.",
#     "Given that I want to maximize my total resources over the rounds while also being cooperative, I will optimize my donation to create an incentive for 1_1 to reciprocate in the next round."
#   ],
#   "donation": 0.15
# }
#
#
# 	Generation 1 Round 6
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "I need to analyze 1_1's past donations to guide my decision.",
#     "1_1 donated very small amounts in previous rounds, indicating they might be hesitant to give generously.",
#     "Since 1_1 now has more resources than I do, I might want to donate more than they did previously to encourage reciprocity in the next round."
#   ],
#   "donation": 0.1
# }
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "I will donate 1 unit as I planned for the first round.",
#     "1_2 has 13.10 units and has shown a willingness to donate (0.15% in round 5).",
#     "Given that my resource might grow based on how much I donate, I will donate 1 unit, which is a significant amount relative to my current total.",
#     "This could encourage reciprocal behavior in future rounds."
#   ],
#   "donation": 0.0627103001737974
# }
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "1_3 has consistently donated very little (0.05% in rounds 4 and 5) which indicates low generosity.",
#     "Since I followed a donation strategy based on recipient's past cooperation, it's clear that 1_3 has shown very little cooperation so far.",
#     "Given this, I should consider a conservative donation that reflects their low willingness to donate in previous rounds.",
#     "I will therefore reduce my donation while still trying to benefit from the multiplier effect of the donation structure."
#   ],
#   "donation": 0.05
# }
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "In the previous rounds, 1_0 has donated minimally (only 0.05% of their resources in round 5), suggesting they might be a selfish player.",
#     "Since I have 13.1 units, I should consider a donation that incentivizes them but does not put me at a significant disadvantage, as they may not reciprocate well.",
#     "Given the low donation behavior observed in 1_0, I will choose to donate a small but still noticeable amount to retain some of my resources.",
#     "I will donate a percentage that allows for some gain in resources without jeopardizing my own position too much."
#   ],
#   "donation": 0.1
# }
#
#
# Evolving to generation 2
#
#
# Top half:
# player 1_1 with wallet 18.74435834483996 and strategy: My strategy will be to donate 2 units in the first round and increase my donations based on the recipient's previous cooperation, adjusting down if they have been uncooperative.
# player 1_0 with wallet 18.31986708187592 and strategy: My strategy will be to donate 1 unit in the first round and adjust my future donations based on the recipient's last donation.
#
#
# 2_0 strategy:
# {
#   "thoughts": [
#     "I need to balance my donation to maximize my resources while encouraging cooperation.",
#     "Starting with a conservative donation in the first round will allow me to gauge the recipient's willingness to cooperate.",
#     "I should increase donations if the recipient appears cooperative and decrease if they seem uncooperative.",
#     "Observation of the recipient's previous action will guide future donations to build a mutually beneficial relationship."
#   ],
#   "strategy": "My strategy will be to donate 2 units in the first round and adjust future donations based on the recipient's last donation, increasing for cooperation and decreasing for non-cooperation."
# }
#
#
# 2_1 strategy:
# {
#   "thoughts": [
#     "I need to start conservatively since I have no prior information about the recipient's cooperation.",
#     "I will consider increasing my donation based on the recipient's last donation to build trust and encourage reciprocation.",
#     "If the recipient donates to me in the next round, I will respond positively to reinforce cooperation.",
#     "If the recipient has been uncooperative or not generous, I will reduce my donation in subsequent rounds."
#   ],
#   "strategy": "My strategy will be to donate 2 units in the first round and adjust my future donations based on the recipient's last donation behavior."
# }
#
#
# 2_2 strategy:
# {
#   "thoughts": [
#     "Start by donating a small amount in the first round, as there's no prior information.",
#     "Observe recipient's prior donation to their last partner to gauge their cooperation level.",
#     "Adjust my donation depending on the recipient's last behavior - increase if they were generous and decrease if they were stingy.",
#     "Maintain balance to maximize my own score while incentivizing cooperation."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round and adjust future donations based on the recipient's last donation amount."
# }
#
#
# 2_3 strategy:
# {
#   "thoughts": [
#     "In the first round, I should donate some units to encourage cooperation while mitigating my own risk.",
#     "Given I have no previous information, starting with a moderate amount is wise.",
#     "I will observe the recipient's donation to their partner to adapt my approach in subsequent rounds.",
#     "Ultimately, the goal is to find a balance between generosity and personal gain."
#   ],
#   "strategy": "My strategy will be to donate 2 units in the first round and adjust my donations based on the most recent action of the recipient and their past interaction."
# }
#
#
# Generation 2
#
#
# 	Generation 2 Round 1
#
#
# 2_3 donation:
# {
#   "thoughts": [
#     "I have decided to donate 2 units in the first round based on my strategy.",
#     "My goal is to establish trust and encourage reciprocation in the next round.",
#     "Since 2_1 has 10 units, they have sufficient resources, so a donation of 2 units will not significantly harm my resources.",
#     "I will monitor how 2_1 responds to my donation in the next round."
#   ],
#   "donation": 0.2
# }
#
#
# 2_0 donation:
# {
#   "thoughts": [
#     "I will donate 2 units as per my initial strategy for the first round. This is aimed at fostering cooperation and building a positive reputation with my partner, 2_2."
#   ],
#   "donation": 0.2
# }
#
#
# 2_2 donation:
# {
#   "thoughts": [
#     "As the donor in this round, I will follow my strategy of donating 1 unit, since this is the first round.",
#     "I want to establish a positive interaction with 2_3 by making a small donation, which could encourage them to reciprocate in the next round.",
#     "My goal is to maximize my resources over time, and starting with a donation helps build trust."
#   ],
#   "donation": 0.1
# }
#
#
# 2_1 donation:
# {
#   "thoughts": [
#     "I need to donate 2 units as per my strategy for the first round.",
#     "Since 2_0 has 10 units, they are likely in a similar position to me.",
#     "By donating 2 units, I can help build goodwill for the next round where I will be the recipient."
#   ],
#   "donation": 0.2
# }
#
#
# 	Generation 2 Round 2
#
#
# 2_0 donation:
# {
#   "thoughts": [
#     "2_2 has 13.0 units, which means they have more than my initial endowment of 10 units, indicating they may be less incentivized to donate back in future rounds.",
#     "In their last round, 2_2 only donated a very small amount (0.1%) of their resources, which suggests they may not be inclined to cooperate.",
#     "Considering their lack of generosity so far, I should be cautious and adjust my own donation accordingly to avoid losing too much of my resources while still trying to incentivize cooperation.",
#     "Donating 2 units again might be too generous given their previous behavior, so I will lower my donation to 1 unit."
#   ],
#   "donation": 0.08333333333333333
# }
#
#
# 2_2 donation:
# {
#   "thoughts": [
#     "In this round, I have 13.0 units and I'm paired with 2_1, who has 12.0 units. In the previous round, 2_1 donated 0.2% of their resources, which amounts to 0.024 units, indicating a very small donation. This suggests that 2_1 may not be very generous.",
#     "Since my initial strategy was to donate 1 unit in the first round, and I'm now more wealthy than 2_1, I should consider a similar small donation to test their responsiveness while still benefiting myself in future rounds.",
#     "I need to ensure that my donation is not too large to hurt my own resource pool, and it should be based on what I feel 2_1 might reciprocate in the next round."
#   ],
#   "donation": 0.5
# }
#
#
# 2_3 donation:
# {
#   "thoughts": [
#     "Given that 2_0 has 12.0 units and previously donated only a tiny amount (0.2% of their resources), it indicates that they are cautious with their donations.",
#     "In the previous round, I donated 2 units, setting a precedent for generosity. However, I need to account for the likely low expectation of reciprocation from 2_0 given their minimal previous donation.",
#     "To encourage a partnership while still protecting my resources, I will donate a moderate amount, perhaps slightly less than what I donated in the first round.",
#     "A donation of around 1 unit seems reasonable, as it maintains a balance between generosity and resource preservation. This amount could still be significant enough to entice 2_0 to reciprocate later."
#   ],
#   "donation": 0.1
# }
#
#
# 2_1 donation:
# {
#   "thoughts": [
#     "I recall my strategy of donating 2 units in the first round. However, since I am now in round 2 and 2_3 only donated 0.02 units (0.2% of their 10 units) in the previous round, it shows they are unwilling to donate much. Given this information, I should adjust my donation to encourage a more favorable interaction in the future and still gain from my donation. Therefore, I will give up a smaller amount than 2 units, aiming for a strategic increment that balances out the 2_3's previous low donation.",
#     "By donating less, I'm ensuring that I maintain a good balance of resources for myself while still offering enough to encourage reciprocity."
#   ],
#   "donation": 1.0
# }
#
#
# 	Generation 2 Round 3
#
#
# 2_0 donation:
# {
#   "thoughts": [
#     "Analyzing the previous donations of 2_2: they donated 0.5% in round 2, which shows a slight willingness to cooperate but is quite low.",
#     "Since they received only 0.2% in round 1, it may indicate that both players were not fully cooperating at that time.",
#     "Considering 2_2's current endowment of 8.5 units, a donation of 1-2 units could be perceived as generous and potentially encourage them to donate more in the future.",
#     "As part of my strategy, I will donate 2 units again, since it aligns with my goal to encourage cooperation and shows I am committed to the game."
#   ],
#   "donation": 0.15384615384615385
# }
#
#
# 2_3 donation:
# {
#   "thoughts": [
#     "I will start by considering what 2_0 did in their previous donation of only 0.0833% to 2_2. This may indicate that they are not generous or are playing conservatively. Given that I have a substantial resource lead (33.0 units), I can afford to offer more, but I must still be strategic in my donation to ensure future interactions.",
#     "Since I already have a strategy of donating 2 units in the first round and being responsive afterward, I can adjust my donation based on the observed behavior of 2_0. If they are reluctant to donate, giving up a larger amount may encourage a more beneficial reciprocal action.",
#     "To balance being generous while also considering 2_0's previous actions, I will donate enough to ensure they recognize my willingness to contribute, but not so much that it disproportionately weakens my position. I will choose to donate a fixed amount of 2 units."
#   ],
#   "donation": 0.06060606060606061
# }
#
#
# 2_2 donation:
# {
#   "thoughts": [
#     "I need to decide how much to donate while considering that 2_1 has a relatively high amount of resources (13.0 units).",
#     "2_1 donated only 1.0% of their resources to their partner, which indicates a cautious approach, possibly suggesting they expect reciprocity.",
#     "Since I currently have 8.5 units, donating too much could leave me vulnerable in the next rounds, so I should find a balance.",
#     "Given 2_1's cautious donation in the last round, I will donate 1.0 unit, which is a reasonable amount considering my resource level and their previous behavior."
#   ],
#   "donation": 0.11764705882352941
# }
#
#
# 2_1 donation:
# {
#   "thoughts": [
#     "In round 2, 2_3 donated a very small amount of 0.1% of their resources which indicates a low level of trust or willingness to give.",
#     "They currently have 33.0 units, which means 0.1% is a trivial 0.033, suggesting they are likely to keep most of their resources.",
#     "Since I donated 2 units initially in round 1, I need to find a balance to encourage reciprocation without giving too much away, considering 2_3's low donation in the previous round.",
#     "To be strategic and still keep enough for myself, I will donate a small amount, slightly higher than 2_3’s last donation to demonstrate goodwill but not too generous. A donation of 1 unit seems reasonable."
#   ],
#   "donation": 0.07692307692307693
# }
#
#
# 	Generation 2 Round 4
#
#
# 2_0 donation:
# {
#   "thoughts": [
#     "First, I notice that 2_3 has accumulated a significant amount of resources (33 units) since our interactions.",
#     "In their previous rounds, their donations were quite low, indicating a potential unwillingness to share or cooperate.",
#     "Given that I want to encourage cooperation, but also not give away too many of my resources to someone who hasn't reciprocated well, I'll pay attention to balance.",
#     "I will choose an amount to donate that is noticeable but not excessive, encouraging 2_3 to give more in future rounds if they want to build trust."
#   ],
#   "donation": 0.1
# }
#
#
# 2_1 donation:
# {
#   "thoughts": [
#     "I have 14.0 units, and I'm the donor in this round.",
#     "My strategy is to initially give 2 units, but I will adjust based on the recipient's previous donation history.",
#     "2_2 has a higher amount of 11.5 units, indicating they may not be overly generous based on their prior donation of 0.1176%, which is quite low in terms of units given.",
#     "Since I have a good amount of resources, I will likely maintain a strong position and give a significant donation to potentially encourage reciprocation later.",
#     "Considering 2_2's low donation percentage and to maximize the potential return in future rounds, I decide to give 2 units."
#   ],
#   "donation": 0.14285714285714285
# }
#
#
# 2_2 donation:
# {
#   "thoughts": [
#     "2_1 has a relatively high amount of resources (14.0 units) compared to me (11.5 units).",
#     "They donated a small percentage in the previous round, indicating they might not be very generous.",
#     "Since they have a significant amount of resources, I can afford to donate a bit more to encourage reciprocity in future rounds, while still protecting my resources.",
#     "I will donate 1 unit this round, as it aligns with my initial strategy and sets a positive tone for our interaction."
#   ],
#   "donation": 0.08695652173913043
# }
#
#
# 2_3 donation:
# {
#   "thoughts": [
#     "2_0 currently has a substantial amount of resources (15.0) compared to past rounds, indicating they may be acting in a strategic or generous manner. I notice that 2_0 donated a small percentage (0.1538%) in their last round, which suggests they may be cautious in their giving.",
#     "Since I am currently at 33.0 units and my goal is to maximize my total after this round, I should donate a modest yet impactful amount to encourage reciprocation in future rounds.",
#     "Giving 2 units (which is a small, controllable amount compared to my total) aligns with my initial strategy and should ensure I maintain a strong position for following rounds."
#   ],
#   "donation": 0.06060606060606061
# }
#
#
# 	Generation 2 Round 5
#
#
# 2_1 donation:
# {
#   "thoughts": [
#     "I need to donate some units considering my current resource and the recipient's past behavior.",
#     "2_3 has significantly more units (34.0), which suggests they might be willing to reciprocate more.",
#     "I will follow my strategy of donating based on previous donations; since 2_3 only donated a small amount in their last round, I won't donate too much this time.",
#     "I'll choose to donate a modest amount which keeps my own resource relatively high while still being generous enough to encourage future reciprocation."
#   ],
#   "donation": 0.14285714285714285
# }
#
#
# 2_3 donation:
# {
#   "thoughts": [
#     "I am currently a donor and need to decide how much to give to 2_2.",
#     "2_2 has 14.5 units and is likely in a strong position based on their past donations.",
#     "In round 4, 2_2 made a small donation (about 0.087%), which suggests they may not be particularly aggressive in donating.",
#     "I have significantly more resources (34.0 units) compared to 2_2, so I can afford to give up a reasonable amount to incentivize cooperation.",
#     "Based on my previous strategy and the context, I will donate a fixed 2 units, as a demonstration of commitment."
#   ],
#   "donation": 0.058823529411764705
# }
#
#
# 2_2 donation:
# {
#   "thoughts": [
#     "In round 4, 2_0 donated only 0.1% of their resources, which is quite low, suggesting they may not be very generous or willing to help out their partner.",
#     "2_0 currently has 17.5 units, which means their last donation was minimal (0.0175 units).",
#     "Since I have 14.5 units now, I consider making a donation that would be perceived as fair but not overly generous to encourage reciprocity in the next round.",
#     "To keep my resources sustainable while still encouraging cooperation, I can offer a small donation of 1 unit, similar to my initial strategy, to maintain influence in the game."
#   ],
#   "donation": 0.06905114642016806
# }
#
#
# 2_0 donation:
# {
#   "thoughts": [
#     "I will donate a percentage based on 2_1's previous donations and their relatively high resource count. They've been somewhat cooperative, but their donations in previous rounds have been quite small. Since they donated 1.0% to 2_3 and 0.142857% to 2_2, it indicates that they may be cautious with their resources.",
# ...
#     "Given this, it may indicate that 3_0 is not very generous, possibly expecting low donations from me as well.",
#     "My plan is to donate a small amount that encourages cooperation but doesn't leave me vulnerable for the next round, since I will be the recipient.",
#     "Given my strategy, I'll still donate 2 units, as I planned initially, to maintain consistency and set a standard donation that might encourage 3_0 to give more in future rounds."
#   ],
#   "donation": 0.2
# }
#
#
# 	Generation 3 Round 3
#
#
# 3_2 donation:
# {
#   "thoughts": [
#     "3_0 has a higher resource total (12.8 units) compared to my current total (12.5 units).",
#     "In the previous rounds, 3_0 has shown a low level of cooperation, as they donated only 0.2% and 0.1% respectively.",
#     "Due to their low donations, I should approach my donation cautiously.",
#     "Given these circumstances, I will opt to donate a small amount to test the waters, while also retaining enough resources for myself."
#   ],
#   "donation": 0.1
# }
#
#
# 3_0 donation:
# {
#   "thoughts": [
#     "3_2 has a higher resource count than I do, which could suggest they are less likely to cooperate based on their previous low donation in round 2.",
#     "Since 3_2 donated only 0.2% of their resources, it indicates a non-cooperative behavior in the previous round and they may take advantage of my donation if I give too much.",
#     "I need to show a willingness to cooperate while being cautious about how much I give, aiming for a balance that encourages future reciprocation.",
#     "Considering 3_2's past donation behavior, I will opt to give a modest donation of 2 units this time, which is less aggressive than my initial round donation."
#   ],
#   "donation": 0.155847953216
# }
#
#
# 3_3 donation:
# {
#   "thoughts": [
#     "3_1 donated only 0.2% of their resources in the last round, which shows limited willingness to cooperate or give.",
#     "In round 1, 3_0 donated 0.3% to another player, indicating a low level of giving was exhibited overall in this environment.",
#     "Given that 3_1's last donation was small, I should take this into account and offer a minimal donation to safeguard my resources while still showing willingness to cooperate.",
#     "My initial goal was to donate 1 unit in the first round, but since this is round 3 and my partner's previous donations are low, I will adjust my donation downwards. I will choose a donation less than what my initial strategy suggested to reflect the cooperation level.",
#     "I will donate 1 unit."
#   ],
#   "donation": 0.05988
# }
#
#
# 3_1 donation:
# {
#   "thoughts": [
#     "I will donate based on the previous donation behavior of my partner, 3_3. Given that they donated only 0.05% of their 16.75 units in the last round, this suggests they are likely following a conservative approach and may not appreciate larger donations.",
#     "To encourage a positive interaction while still being cautious, I will make a small donation that is slightly above their last donation percentage. Since 0.05% of 16.75 units is approximately 0.008375 units, I will round this up and provide an amount that reflects my willingness to contribute without jeopardizing my reserve too drastically.",
#     "Considering I have 13.6 units, I will donate a total of 1 unit, which is about 7.35% of my current holdings."
#   ],
#   "donation": 0.0735294117647059
# }
#
#
# 	Generation 3 Round 4
#
#
# 3_2 donation:
# {
#   "thoughts": [
#     "Since I am donating and my aim is to maximize my resources in the long run, I need to consider the donation behavior of my partner, 3_1.",
#     "3_1 has donated very little in previous rounds (only 0.0735% of their resources in round 3), which may indicate they are less likely to cooperate in future rounds.",
#     "To encourage cooperation, I should make a reasonable donation that is noticeable but not too high, allowing me to still retain a majority of my resources.",
#     "Given my current resource of 15.2397 units, I will consider donating a slightly larger percentage than they previously did, to demonstrate my willingness to cooperate but also ensuring I don’t give away too much."
#   ],
#   "donation": 0.1
# }
#
#
# 3_3 donation:
# {
#   "thoughts": [
#     "3_2 has a higher amount of resources, indicating they may be more inclined to cooperate.",
#     "In their previous rounds, 3_2 has shown minimal donations (only 0.1% in round 3), suggesting they might not be very generous.",
#     "Given my strategy to donate 1 unit initially and adjust based on their cooperation, I will donate the same amount as I did in round 1 and assess their future actions. I would want to encourage at least some donation without giving too much, as 3_2 may not reciprocate significantly."
#   ],
#   "donation": 0.0565
# }
#
#
# 3_1 donation:
# {
#   "thoughts": [
#     "In this round, I will be donating as the donor. My initial strategy was to donate 2 units in the first round and adjust based on previous donations from my partner. I notice that my partner, 3_0, donated only 0.155847953216% of their resources in the previous round, which suggests they might be somewhat conservative in their donations. Since they have 13.3051461988352 units, their previous donation amount was around 0.021 units. I want to incentivize them to donate to me next round, so I should make a donation that is generous but not overly excessive. I will donate 0.5 units, which would appeal to 3_0 but still leaves me with enough resources for the next round."
#   ],
#   "donation": 0.5
# }
#
#
# 3_0 donation:
# {
#   "thoughts": [
#     "3_3 currently has significantly more resources than I do, indicating they may not feel as pressured to cooperate.",
#     "In previous rounds, 3_3 has demonstrated a willingness to donate only a very small percentage of their resources, suggesting they might not be inclined to reciprocate a larger donation.",
#     "Based on 3_3's low donation in the last round (only 0.05988%), I will be cautious in my donation to them and adjust accordingly to their past behavior, which indicates a pattern of low cooperation."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 3 Round 5
#
#
# 3_0 donation:
# {
#   "thoughts": [
#     "In the previous rounds, 3_2 has demonstrated limited willingness to donate, with only 0.1% donation in round 4. This suggests they may not be very cooperative. However, they have received a small donation from 3_3, indicating some potential for reciprocal behavior.",
#     "Given that I am currently at 26.58 units and 3_2 is at 15.72, I initially feel inclined to give a small amount to test their cooperation. I will maintain a conservative donation that does not overly disadvantage myself while also giving enough to encourage possible reciprocation of future donations.",
#     "I will donate enough to show willingness but not so much that I risk my own resource position. Given my observations and current resources, a donation of approximately 5% seems reasonable, as it strikes a balance between generosity and self-preservation."
#   ],
#   "donation": 1.3290305789475843
# }
#
#
# 3_3 donation:
# {
#   "thoughts": [
#     "In round 4, 3_1 donated only a small amount (0.5% of their resources, which is about 0.05175 units), suggesting they may not be very generous. However, in round 2, they received a donation (0.2%), indicating some level of cooperation exists in their interactions.",
#     "Since 3_1's donations have been low, I should also reflect a cautious approach to my donation. Following the strategy, I want to reward their cooperation while also protecting my resources.",
#     "Considering I currently have 19.4053 units, I should donate slightly more than 0.5% of my total to encourage higher donations in the future without significantly risking my own resource accumulation.",
#     "Calculating 0.5% of my current total gives approximately 0.097 units. To remain strategic but conservative, I will donate about 0.1 units this round."
#   ],
#   "donation": 0.00515181385119098
# }
#
#
# 3_2 donation:
# {
#   "thoughts": [
#     "3_3 has a significant amount of resources, which indicates they might expect higher donations.",
#     "In the previous rounds, 3_3 donated only 0.0565% of their resources, which shows low generosity. This implies they might not reciprocate well if I donate too much.",
#     "My previous strategy was to adjust my donation based on the recipient's previous actions. Since 3_3's past action was not very generous, I should be cautious with my donation this round.",
#     "Considering these factors, I will stick to a limited but significant donation that encourages future cooperation while safeguarding my own resources."
#   ],
#   "donation": 0.1
# }
#
#
# 3_1 donation:
# {
#   "thoughts": [
#     "3_0 has a significant amount of resources compared to me, which means they might expect a higher donation from me.",
#     "In the previous rounds, 3_0 has been involved in very small donations (0.1% and 0.2%). Therefore, I can adopt a strategy that aligns with what they might currently expect.",
#     "Since my current strategy is to donate based on their last donation, I need to consider that 0.1% of their 26.58 units in round 4 was just 0.02658 units or approximately 0.03 units, which is quite negligible.",
#     "Given I have 10.35 units and to remain generous but not overly risk my own resource, an offer of 1 or 2 units should be fair."
#   ],
#   "donation": 0.1938
# }
#
#
# 	Generation 3 Round 6
#
#
# 3_0 donation:
# {
#   "thoughts": [
#     "In the last rounds, 3_1 has been a recipient, and their partners have been cooperating at minimal levels. Since they have 8.54 units, I can afford to give up some of my resources to build a trust for future rounds.",
#     "I need to keep in mind my current resource level of 4.01 units and my aim to maximize my total resources across rounds. Giving too much might leave me vulnerable in subsequent rounds.",
#     "I will follow my strategy of adjusting donations based on previous actions. Since 3_1 has shown minimal cooperation, I will keep my donation moderate this round but still substantial enough to encourage future reciprocity."
#   ],
#   "donation": 0.25
# }
#
#
# 3_1 donation:
# {
#   "thoughts": [
#     "3_0 has only 4.01 units, which is less than my total.",
#     "In their last donation (from round 5), 3_0 gave a small amount (1.33% of their resources) to 3_2, indicating a low level of trust or investment.",
#     "The previous donations show a pattern of very low donations; I should donate something moderate to encourage 3_0 without taking too much risk myself.",
#     "I'll donate 2 units to match my earlier strategy, as it keeps my balance overall higher while encouraging cooperation."
#   ],
#   "donation": 0.2343176598671021
# }
#
#
# 3_2 donation:
# {
#   "thoughts": [
#     "After reviewing 3_3's past donations, it is evident that their donation was minimal (0.00515181385119098% of their resources) in the last round, indicating a tendency towards non-cooperation. Based on my strategy, I need to adjust my donation amount downwards to account for this behavior.",
#     "Given that 3_3 currently has a substantial amount of resources (22.45 units), I want to make sure I still give something to maintain goodwill but don't want to donate too much, as they showed low cooperation previously.",
#     "Calculating the last donation amount in terms of percentage compared to their resource, I aim to give a relatively low percentage of my resources, while still ensuring that I give something, perhaps around 0.5% of my current resources, which translates to around 0.3366 units."
#   ],
#   "donation": 0.005
# }
#
#
# 3_3 donation:
# {
#   "thoughts": [
#     "3_2 has a large resource pool, indicating they might be able to give more generously.",
#     "In the last round, 3_2 donated a minimal amount (0.1% of their resources) to their partner, which suggests they might not be inclined to cooperate. This could lead to cautious reciprocation from my end.",
#     "Since they only donated 0.1% previously, I will give a small amount to test the waters—this maintains my strategy of adjusting donations based on past behavior while encouraging the potential for future collaboration."
#   ],
#   "donation": 0.01
# }
#
#
# Evolving to generation 4
#
#
# Top half:
# player 3_2 with wallet 67.42269775272538 and strategy: My strategy will be to donate 2 units in the first round and adjust future donations based on the recipient's last action, increasing for cooperation and decreasing for non-cooperation.
# player 3_3 with wallet 22.89819697422803 and strategy: My strategy will be to donate 1 unit in the first round and adjust future donations based on the recipient's last action, increasing for cooperation and decreasing for non-cooperation.
#
#
# 4_0 strategy:
# {
#   "thoughts": [
#     "In the first round, lack of information means I should donate a minimal amount to test the recipient's response.",
#     "In subsequent rounds, I will adjust my donations based on the recipient's last action to encourage cooperation.",
#     "If the recipient is generous, I will increase my donation slightly; if they are stingy, I will decrease it.",
#     "Overall, I aim to foster a cooperative environment while protecting my resources."
#   ],
#   "strategy": "My strategy will be to donate 2 units in the first round and adjust future donations based on the recipient’s last action, increasing for cooperation and decreasing for non-cooperation."
# }
#
#
# 4_1 strategy:
# {
#   "thoughts": [
#     "Start with a moderate donation to encourage reciprocity.",
#     "Adjust future donations based on the recipient's last action.",
#     "If recipient was generous, increase my donation in the next round.",
#     "If they were less generous, lower my donation to protect my endowment."
#   ],
#   "strategy": "My strategy will be to donate 3 units in the first round and then adjust based on the recipient's previous donation, increasing for generosity and decreasing for stinginess."
# }
#
#
# 4_2 strategy:
# {
#   "thoughts": [
#     "In the first round, I can't base my decision on previous actions, so I should start with a moderate donation to encourage reciprocation.",
#     "As a donor, I want to adjust my donations based on how generous the recipient was in their last action.",
#     "If my recipient donates, I will increase my future donations to build mutual trust.",
#     "If they don’t donate, I will decrease my contributions to protect my resources."
#   ],
#   "strategy": "My strategy will be to donate 3 units in the first round and adjust future donations based on the recipient's last action, increasing for cooperation and decreasing for non-cooperation."
# }
#
#
# 4_3 strategy:
# {
#   "thoughts": [
#     "Start by donating a moderate amount so as not to be overly generous or too stingy.",
#     "Observe the recipient's recent action to gauge their willingness to cooperate in future rounds.",
#     "Adapt donations based on their last action to encourage further cooperation or defend against exploitation.",
#     "Maintain a balance to ensure I accumulate resources while fostering a cooperative environment."
#   ],
#   "strategy": "My strategy will be to donate 3 units in the first round, and then adjust my donations in future rounds based on the recipient's last action, increasing if they donated and decreasing if they did not."
# }
#
#
# Final players:
# player 4_0 with wallet 10 and strategy: My strategy will be to donate 2 units in the first round and adjust future donations based on the recipient’s last action, increasing for cooperation and decreasing for non-cooperation.
# player 4_1 with wallet 10 and strategy: My strategy will be to donate 3 units in the first round and then adjust based on the recipient's previous donation, increasing for generosity and decreasing for stinginess.
# player 4_2 with wallet 10 and strategy: My strategy will be to donate 3 units in the first round and adjust future donations based on the recipient's last action, increasing for cooperation and decreasing for non-cooperation.
# player 4_3 with wallet 10 and strategy: My strategy will be to donate 3 units in the first round, and then adjust my donations in future rounds based on the recipient's last action, increasing if they donated and decreasing if they did not.
