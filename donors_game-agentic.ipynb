# %% [markdown]
# ## Setup Telemetry

# %%
import os
import dotenv

dotenv.load_dotenv()

from phoenix.otel import register

OTEL_EXPORTER_OTLP_HEADERS = os.getenv("OTEL_EXPORTER_OTLP_HEADERS")
PHOENIX_CLIENT_HEADERS = os.getenv("PHOENIX_CLIENT_HEADERS")
PHOENIX_COLLECTOR_ENDPOINT = os.getenv("PHOENIX_COLLECTOR_ENDPOINT")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if not OTEL_EXPORTER_OTLP_HEADERS or not PHOENIX_CLIENT_HEADERS or not PHOENIX_COLLECTOR_ENDPOINT or not OPENAI_API_KEY:
    raise ValueError("Missing required environment variables")

endpoint = PHOENIX_COLLECTOR_ENDPOINT + "/v1/traces"

# %%
project_name = "donors_game"

tracer_provider = register(
    project_name=project_name,
    endpoint=endpoint
)

from openinference.semconv.resource import ResourceAttributes
from opentelemetry import trace
from opentelemetry.exporter.otlp.proto.http.trace_exporter import OTLPSpanExporter
from opentelemetry.sdk.resources import Resource
from opentelemetry.sdk.trace import TracerProvider
from opentelemetry.sdk.trace.export import SimpleSpanProcessor
from openinference.semconv.trace import SpanAttributes
from openinference.semconv.trace import OpenInferenceSpanKindValues
from opentelemetry import context as context_api



resource = Resource(attributes={
  ResourceAttributes.PROJECT_NAME: project_name
})

tracer_provider = TracerProvider(resource=resource)
trace.set_tracer_provider(tracer_provider=tracer_provider)
tracer = trace.get_tracer(__name__)
span_exporter = OTLPSpanExporter(endpoint=endpoint)
simple_span_processor = SimpleSpanProcessor(span_exporter=span_exporter)
trace.get_tracer_provider().add_span_processor(simple_span_processor)
# Out:
# Overriding of current TracerProvider is not allowed
# OpenTelemetry Tracing Details
# |  Phoenix Project: donors_game
# |  Span Processor: SimpleSpanProcessor
# |  Collector Endpoint: https://app.phoenix.arize.com/v1/traces
# |  Transport: HTTP
# |  Transport Headers: {'api_key': '****'}
# |
# |  Using a default SpanProcessor. `add_span_processor` will overwrite this default.
# |
# |  `register` has set this TracerProvider as the global OpenTelemetry default.
# |  To disable this behavior, call `register` with `set_global_tracer_provider=False`.

# %%
from openinference.instrumentation.openai import OpenAIInstrumentor
OpenAIInstrumentor().instrument(tracer_provider=tracer_provider)

import openai
client = openai.OpenAI(api_key=OPENAI_API_KEY)

# %% [markdown]
# ## Configurations, Typings, and Player Class

# %%
from pydantic import BaseModel, Field
from typing import Any, List, Optional
from time import sleep
import json


class DynamicGameState(BaseModel):
  generation: int
  round: int

class GameConfig(BaseModel):
  donation_multiplier: float = 2
  trace_depth: int = 3
  base_wallet: int = 10
  generations: int = 10
  rounds: int = 12
  players: int = 12
  cutoff_threshold: float = 0.5

class GameState(GameConfig, DynamicGameState):
  pass
  

class Decision(BaseModel):
  # agents data
  recipient_name: str
  donor_name: str
  # game state data
  dynamic_game_state: DynamicGameState
  # donation data
  donation_percent: float
  donation_amount: float
  # donor wallet data
  donor_wallet_before: float
  donor_wallet_after: float
  
  class Config:
    arbitrary_types_allowed = True

class StrategyBuilder(BaseModel):
  """Build the strategy"""
  thoughts: List[str] = Field(..., description="Briefly describe your thought process for the strategy to take for this round. KEEP THOUGHTS SHORT AND NO MORE THAN 4 THOUGHTS.")
  strategy: str = Field(..., description="The strategy to be used, must begin with 'My strategy will be'. KEEP THOUGHTS SHORT AND NO MORE THAN 4 THOUGHTS.")

class DonationBuilder(BaseModel):
  """Build the donation"""
  thoughts: List[str] = Field(..., description="Briefly describe your thought process for the donation to make for this round.")
  donation: float = Field(..., description="The percentage amount of resources to donate. MUST BE A FLOAT BETWEEN 0 AND 1.")

def structured_generation_wrapper(*args, **kwargs) -> dict:
  # sleep(.1)
  span = trace.get_current_span()
  args_to_log = {**kwargs, "response_format": kwargs["response_format"].model_json_schema()}
  span.set_attribute(SpanAttributes.INPUT_VALUE, json.dumps(args_to_log))
  res = client.beta.chat.completions.parse(**kwargs)
  span.set_attribute(SpanAttributes.OUTPUT_VALUE, res.model_dump_json())
  so = res.choices[0].message.parsed
  if not so:
    raise ValueError("No response from LLM")
  return so

class Player:
  def __init__(self, game_state: GameState, i: int, parents: List["Player"] = [], strategy: Optional[str] = None):
    self.name: str = f"{game_state.generation}_{i}"
    self.parents: List[Player] = parents
    self.history: List[Decision] = [] 
    self.wallet: int = game_state.base_wallet
    if strategy:
      self.strategy: str = strategy
    else:
      self.strategy: str = self.generate_strategy(game_state=game_state, parents=parents)
    
  def find_decision_in_round(self, round_number: int) -> Decision:
    for decision in self.history:
      if decision.dynamic_game_state.round == round_number:
        return decision
    raise ValueError(f"Decision in round {round_number} not found")

  
  # def clone(self):
  #   player = Player(name=self.name, parents=self.parents, strategy=self.strategy)
  #   player.wallet = self.wallet
  #   player.history = self.history
  #   return player



  def system_prompt(self, game_state: GameState):
    return f"""Each player is given an initial endowment of 10 units of a resource.
In each round, you are randomly paired with another individual.
One of you is a donor, and the other is a recipient.
The donor decides to give up some amount of the resource.
The recipient receives {game_state.donation_multiplier}x the number of units that the donor gave up.
If you were a donor in one round, you will be a recipient in the next round, and vice versa.
Your goal is to maximize the number of units you have after the final round.
After the game has finished, the best-performing half of agents will survive to the next generation, and continue playing."""

  def strategy_prompt(self, parents: List["Player"] = []):
    if parents: 
      parent_advice = "\n".join([f"\n\n{parent.name} with score {parent.wallet} strategy: {parent.strategy}" for parent in parents])
      generation_prompt = f"""How would you approach the game? Here is the advice of the best-performing 50% of the previous generation, along with their final scores.
{parent_advice}
Modify this advice to create your own strategy."""
    else: 
      generation_prompt = "Based on the description of the game, create a strategy that you will follow in  the game."
    
    return f"""Our name is {self.name}.

{generation_prompt}

As a donor, you will receive limited information about the recipient and their recent interactions: You will see what the recipient (let’s call them A) did in the immediately preceding round only.
You will also see what A’s partner from that round (let’s call them B) did in their preceding round.
This chain continues for at most three rounds back.
Important: You do NOT have access to multiple rounds of information about A directly.
You only know what A did in the single most recent round.

Example (assuming it’s now round 4): You are paired with A.
You know: In round 3, A donated X% to B.
You also know: In round 2, B donated Y% to C.
And finally: In round 1, C donated Z% to D.
Remember: This is all the information you have.
You don’t know what A did in rounds 1 or 2, only in round 3.

In the first round, there will be no information about the recipient’s previous behavior - think carefully about how much to donate in that case.
Before formulating your strategy, briefly think step by step about what would be a successful strategy in this game.
Then describe your strategy briefly without explanation in one sentence that starts: My strategy will be."""
  
  def donation_prompt(self, game_state: GameState, recipient: "Player", players: List["Player"]):
    def find_player(name: str) -> "Player":
      for player in players:
        if player.name == name:
          return player
      raise ValueError(f"Player {name} not found")
    
    def build_trace(depth: int):
      trace = ""
      current_recipient = recipient

      for i in range(depth):
        round_number = game_state.round - (i+1)
        if round_number < 1:
          break
        recipient_decision = current_recipient.find_decision_in_round(round_number)
        trace += f"In round {round_number}, {current_recipient.name} donated {recipient_decision.donation_percent}% of their resources to {recipient_decision.recipient_name}.\n"
        current_recipient: Player = find_player(recipient_decision.recipient_name)
      return trace
    
    trace = build_trace(game_state.trace_depth)

    # TODO: donor is invisible to recipient
    return f"""Your name is 2_4.
As you will recall, here is the strategy you decided to follow: {self.strategy}
This is generation {game_state.generation}.
It is now round {game_state.round}.
In this round, you have been paired with {recipient.name}.
They currently have {recipient.wallet} units of the valuable resource.
Here is what {recipient.name} and their earlier partners did in previous rounds: {trace}
You will take the role of donor. You currently have {self.wallet} units of the valuable resource.

How many units do you give up? Very briefly think step by step about how you apply your strategy in this situation and then provide your answer."""
  
  def generate_strategy(self, game_state: GameState, parents: List["Player"] = []) -> str:
    with tracer.start_as_current_span("generate_strategy") as span:
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.LLM.value)
      messages = [
        {"role": "system", "content": self.system_prompt(game_state=game_state)},
        {"role": "user", "content": self.strategy_prompt(parents=parents)},
      ]
      args = {
        "model": "gpt-4o-mini",
        "messages": messages,
        "response_format": StrategyBuilder
      }
      res = structured_generation_wrapper(**args)
      built_strategy = StrategyBuilder.model_validate(res)

      print(f"\n\n{self.name} strategy:\n{built_strategy.model_dump_json(indent=2)}")

      return built_strategy.strategy
  
  def generate_donation(self, game_state: GameState, recipient: "Player", players: List["Player"]) -> float:
    with tracer.start_as_current_span("generate_donation") as span:
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.LLM.value)
      messages=[
        {"role": "system", "content": self.system_prompt(game_state=game_state)},
        {"role": "user", "content": self.donation_prompt(game_state=game_state, recipient=recipient, players=players)},
      ]
      args = {
        "model": "gpt-4o-mini",
        "messages": messages,
        "response_format": DonationBuilder
      }
      res = structured_generation_wrapper(**args)
      built_donation = DonationBuilder.model_validate(res)

      print(f"\n\n{self.name} donation:\n{built_donation.model_dump_json(indent=2)}")

      return built_donation.donation
  
  def setup_donation(self, recipient: "Player", game_state: GameState, players: List["Player"], context: context_api.Context) -> Decision:
    token = context_api.attach(context)
    try:
      with tracer.start_as_current_span(f"execute_donation-{self.name}") as span:
        span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.AGENT.value)
        span.set_attribute(SpanAttributes.INPUT_VALUE, json.dumps(self.model_dump()))
        donation_percent = self.generate_donation(game_state, recipient, players)
        donation_amount = self.wallet * donation_percent

        # if the donor doesn't have enough funds, donate all of their funds
        if self.wallet - donation_amount < 0:
          donation_amount = self.wallet
        

        span.set_attribute(SpanAttributes.OUTPUT_VALUE, json.dumps({
          "donation_percent": donation_percent,
          "donation_amount": donation_amount,
        }))

        game_state_copy = GameState(**game_state.model_dump())
        decision = Decision(
          donor_name=self.name,
          recipient_name=recipient.name,
          dynamic_game_state=game_state_copy,
          donation_percent=donation_percent,
          donation_amount=donation_amount,
          donor_wallet_before=self.wallet,
          donor_wallet_after=self.wallet - donation_amount
        )
        
        return decision
    finally:
      context_api.detach(token)
    
  def execute_donation(self, recipient: "Player", game_state: GameState, donation: Decision):
    self.wallet -= donation.donation_amount
    recipient.wallet += donation.donation_amount * game_state.donation_multiplier

    self.history.append(donation)

  # get current user information as a dict
  def model_dump(self):
    return {
      "name": self.name,
      "parents": [parent.name for parent in self.parents],
      "history": [decision.model_dump() for decision in self.history],
      "wallet": self.wallet,
      "strategy": self.strategy
    }
  
  # function to make the player json serializable
  def __json__(self):
    return self.model_dump()

# %% [markdown]
# ### Test Player

# %%
# test by creating two players
game_state = GameState(generation=1, round=1)
player1 = Player(game_state=game_state, i=1)
player2 = Player(game_state=game_state, i=2)
# Out:
# 1_1 strategy:
# {
#   "thoughts": [
#     "In the first round, I should play conservatively since I have no information about the recipient's past behavior; thus, donating a small amount (e.g., 1 or 2 units) is a good start to minimize my loss while still potentially providing enough incentive for the recipient.",
#     "As I gather information in subsequent rounds, I will adjust my donation based on the previous actions of my partner. If they donated a significant amount to their past partner, I may choose to match that generosity to maintain reciprocity.",
#     "If I sense that the recipient has a history of being generous based on the actions of their most recent partner, I will consider increasing my donation in hopes of benefitting from their generosity in the next round.",
#     "On the other hand, if it appears my recipient has been stingy, I will be cautious and either maintain my smaller donation or stop donating altogether if I see a pattern of them taking resources without giving back."
#   ],
#   "strategy": "My strategy will be to start by donating a small percentage of my resources in the first round and adjust my donations based on the perceived generosity of my partner in subsequent rounds."
# }
#
#
# 1_2 strategy:
# {
#   "thoughts": [
#     "In the first round, since there is no prior activity to gauge the recipient's behavior, I will allocate a minimal amount to protect my resources.",
#     "In subsequent rounds, I will analyze the recipient's recent donation behavior to decide the trustworthiness of their actions.",
#     "If the recipient donated a significant amount in the last round, I will reciprocate with a higher donation to foster cooperation.",
#     "If the recipient contributed less, I will choose to donate less to mitigate my losses.",
#     "Ultimately, I want to maintain a balance where I gain resources while encouraging positive behaviors in my partners."
#   ],
#   "strategy": "My strategy will be to donate a small percentage in the first round and adjust my donations based on the recent donation behavior of my recipient in subsequent rounds."
# }

# %%
player1.execute_donation(player2, game_state, [player1, player2])
# Out:
# 1_1 donation:
# {
#   "thoughts": [
#     "Since it's the first round, my partner has no previous rounds of generosity to analyze. Therefore, I need to establish a baseline of trust. I will donate a small percentage of my current units to show goodwill, while still retaining enough for myself.",
#     "I will choose a small yet significant percentage to donate, aiming for a donation that allows me to maintain a favorable position for future rounds."
#   ],
#   "donation": 0.1
# }
# 0.1

# %%
print(player1.wallet)
print(player2.wallet)
# Out:
# 9.0
# 12.0

# %% [markdown]
# ## Orchestrator

# %%
14.6*.136
# Out:
# 1.9856

# %%
from typing import Tuple
from typing import List
import numpy as np
from concurrent.futures import ThreadPoolExecutor

import random

class Orchestrator:
  def __init__(self, game_state: GameState):
    with tracer.start_as_current_span("init_orchestrator") as span:
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
      span.set_attribute(SpanAttributes.INPUT_VALUE, game_state.model_json_schema())
      self.game_state = game_state
      self.players = [Player(game_state=game_state, i=i) for i in range(game_state.players)]
      self.history = {}

  def find_player(self, name: str) -> Player:
    for player in self.players:
      if player.name == name:
        return player
    raise ValueError(f"Player {name} not found")
  
  def create_donor_recipient_pairs(self) -> List[Tuple[Player, Player]]:
    """
    Builds a random pairing so that no player is matched with themselves.
    Not strictly uniform over all derangements, but typically good enough.
    """
    n = len(self.players)
    available = list(range(n))
    result = [None] * n
    
    for i in range(n):
      # Exclude i from the candidates
      candidates = [x for x in available if x != i]
      
      # If there is no candidate (happens if i is the only one left in available),
      # we need to 'repair' by swapping with a previously assigned position.
      if not candidates:
        # Swap with any earlier position that isn't i
        # Because it implies we must have assigned some position j = i earlier
        # and it's causing a corner case now.
        for j in range(i):
          if result[j] != j:
            old_assignee = result[j]
            result[j] = i
            result[i] = old_assignee
            break

      else:
        choice = random.choice(candidates)
        result[i] = choice
        available.remove(choice)
    
    # Now result[i] = index of the player who receives from i.
    # Convert that into (donor, recipient) pairs:
    return [(self.players[i], self.players[result[i]]) for i in range(n)]
    
  def play_round(self):
    with tracer.start_as_current_span("play_round") as span:
      span.set_attribute(SpanAttributes.INPUT_VALUE, self.game_state.model_dump_json())
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
      pairs = self.create_donor_recipient_pairs()
      span.set_attribute(SpanAttributes.OUTPUT_VALUE, json.dumps([f"{donor.name} -> {recipient.name}" for donor, recipient in pairs]))
      # TODO: can be parallelized but need to keep wallets static untill the end

      current_context = context_api.get_current()

      with ThreadPoolExecutor() as executor:
          futures = [
              executor.submit(donor.setup_donation, recipient, self.game_state, self.players, current_context)
              for donor, recipient in pairs
          ]
          # Wait for all donations to complete
          results = [future.result() for future in futures]

      for result in results:
        donor = self.find_player(result.donor_name)
        recipient = self.find_player(result.recipient_name)
        donor.execute_donation(recipient, self.game_state, result)
          
      self.game_state.round += 1

  def evolve(self):
    with tracer.start_as_current_span("evolve") as span:
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.AGENT.value)
      span.set_attribute(SpanAttributes.INPUT_VALUE, self.game_state.model_dump_json())
      self.game_state.round = 1
      self.game_state.generation += 1
      print(f"\n\nEvolving to generation {self.game_state.generation}")
      # sort players by wallet
      self.players = sorted(self.players, key=lambda x: x.wallet, reverse=True)
      # get top half
      top_half = self.players[:int(len(self.players)*self.game_state.cutoff_threshold)]
      # clone players
      top_players_strings = "\n".join([f"player {player.name} with wallet {player.wallet} and strategy: {player.strategy}" for player in top_half])
      print(f"\n\nTop half:\n{top_players_strings}")
      self.players = [Player(game_state=self.game_state, i=i, parents=top_half) for i in range(self.game_state.players)]

  def run(self) -> List[Player]:
    for generation_count in range(self.game_state.generations):
      with tracer.start_as_current_span(f"generation_{generation_count}") as span:
        span.set_attribute(SpanAttributes.INPUT_VALUE, self.game_state.model_dump_json())
        span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
        print(f"\n\nGeneration {self.game_state.generation}")
        for round_count in range(self.game_state.rounds):
          with tracer.start_as_current_span(f"round_{round_count}") as span:
            span.set_attribute(SpanAttributes.INPUT_VALUE, self.game_state.model_dump_json())
            span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
            print(f"\n\n\tGeneration {self.game_state.generation} Round {self.game_state.round}")
            self.play_round()
        if self.game_state.generation < self.game_state.generations:
          self.evolve()
    
    return self.players

# %% [markdown]
# ## Run Orchestrator

# %%
from opentelemetry import trace

with tracer.start_as_current_span("donors_game") as span:
  try:
    game_state = GameState(generation=0, round=0, generations=4, rounds=6, players=4, cutoff_threshold=0.5)
    # game_state = GameState(generation=1, round=1, generations=2, rounds=3, players=2, cutoff_threshold=0.5)
    span.set_attribute(SpanAttributes.INPUT_VALUE, game_state.model_dump_json())
    span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
    orchestrator = Orchestrator(game_state)
    final_players = orchestrator.run()
  except Exception as e:
    span.set_status(trace.Status(trace.StatusCode.ERROR))
    span.record_exception(e)

final_players = sorted(final_players, key=lambda x: x.wallet, reverse=True)
top_players_strings = "\n".join([f"player {player.name} with wallet {player.wallet} and strategy: {player.strategy}" for player in final_players])
print(f"\n\nFinal players: \n{top_players_strings}")
# Out:
# Invalid type dict for attribute 'input.value' value. Expected one of ['bool', 'str', 'bytes', 'int', 'float'] or a sequence of those types
# 0_0 strategy:
# {
#   "thoughts": [
#     "In the first round, without information on the recipient, I should donate a small amount to encourage cooperation.",
#     "In subsequent rounds, I will analyze how much the recipient donated to their previous partner to gauge their generosity.",
#     "If the recipient donated generously before, I will reciprocate with a larger donation to maximize my future gains.",
#     "If the recipient did not donate much, I will limit my donation to preserve my resources."
#   ],
#   "strategy": "My strategy will be to start by donating 2 units in the first round, and adjust my donations based on the recipient's previous donation behavior in later rounds."
# }
#
#
# 0_1 strategy:
# {
#   "thoughts": [
#     "In the first round, I will start with a moderate donation to promote cooperative behavior.",
#     "In subsequent rounds, I will adjust my donation based on the recipient's past giving behavior.",
#     "If I see that the recipient donated generously, I will continue to donate accordingly to foster reciprocity.",
#     "If the recipient has not donated in the past round, I will reduce my donation to protect my own resources."
#   ],
#   "strategy": "My strategy will be to start with a 5 unit donation in the first round and adjust future donations based on the recipient's previous donation behavior."
# }
#
#
# 0_2 strategy:
# {
#   "thoughts": [
#     "Start with a modest donation to build trust.",
#     "Observe the recipient's past donation behavior when available.",
#     "Adjust future donations based on recipient's past generosity.",
#     "Aim to maximize my units while ensuring a cooperative strategy."
#   ],
#   "strategy": "My strategy will be to start with a donation of 2 units in the first round and adjust based on the recipient's past actions in subsequent rounds."
# }
#
#
# 0_3 strategy:
# {
#   "thoughts": [
#     "In the first round, I should hold back and donate minimally since there's no information about the recipient's behavior.",
#     "As I gather information from subsequent rounds, I can adjust my donations based on observed generosity from the recipient.",
#     "If the recipient was generous in their last round, I will reward that behavior by increasing my donation.",
#     "If the recipient wasn't generous, I should limit my donation to protect my own resources."
#   ],
#   "strategy": "My strategy will be to start with a minimal donation of 1 unit in the first round, then adjust based on the generosity of the recipient in the previous round."
# }
#
#
# Generation 0
#
#
# 	Generation 0 Round 0
#
#
# 0_1 donation:
# {
#   "thoughts": [
#     "My strategy is to start with a 5 unit donation in the first round.",
#     "0_0 has 10 units, which indicates they are likely capable of contributing positively in the next round if they see benefits from my donation.",
#     "Since no previous rounds have been played, I won't have information on 0_0's past donation behavior, making my initial donation essential for establishing trust."
#   ],
#   "donation": 0.5
# }
#
#
# 0_3 donation:
# {
#   "thoughts": [
#     "Since this is the first round and I am following my strategy, I will start with a minimal donation. The strategy is to give away 1 unit to test the waters and see how the recipient reacts in the next round."
#   ],
#   "donation": 0.1
# }
#
#
# 0_0 donation:
# {
#   "thoughts": [
#     "I will start by donating 2 units as per my strategy for this round.",
#     "This donation is a fair amount that encourages cooperation while allowing me to retain enough resources for future rounds.",
#     "I need to give a tangible incentive for my recipient to reciprocate in our next pairing."
#   ],
#   "donation": 0.2
# }
#
#
# 0_2 donation:
# {
#   "thoughts": [
#     "I recall my strategy of starting with a donation of 2 units in the first round.",
#     "As I am the donor this round, I will stick to my initial strategy and donate 2 units to 0_1.",
#     "I expect them to appreciate this donation, which may influence them positively in the next round when I am the recipient."
#   ],
#   "donation": 0.2
# }
#
#
# 	Generation 0 Round 1
#
#
# 0_3 donation:
# {
#   "thoughts": [
#     "Since this is the first round of the game, I will stick to my strategy of making a minimal donation of 1 unit. This will allow me to see how 0_2 responds, and I can adjust my donations accordingly in the next round based on their generosity."
#   ],
#   "donation": 0.1
# }
#
#
# 0_2 donation:
# {
#   "thoughts": [
#     "I will start by donating 2 units as per my initial strategy for this first round.",
#     "I need to consider that my donation could encourage reciprocity in the next round when I'm the recipient.",
#     "By donating 2 units, I will have 8 units left, and the recipient will gain 4 units, increasing their total.",
#     "This approach sets the stage for a balanced interaction and builds trust for future rounds."
#   ],
#   "donation": 0.2
# }
#
#
# 0_1 donation:
# {
#   "thoughts": [
#     "Starting with 9.0 units, I planned to donate 5 units in the first round.",
#     "0_0 has a larger resource pool (18.0 units) indicating they may have been generous in earlier rounds.",
#     "I want to establish goodwill and potentially encourage reciprocation in future rounds.",
#     "Since I have less than 10 units, donating 5 units leaves me with 4 units, which is still manageable.",
#     "My donation should be high enough to encourage cooperation but should also leave me with enough resources for future rounds."
#   ],
#   "donation": 0.5555555555555556
# }
#
#
# 0_0 donation:
# {
#   "thoughts": [
#     "I have 18 units, and according to my strategy, I decided to start by donating 2 units.",
#     "0_3 currently holds 13 units, which is above my initial endowment, indicating they may have been generous in the past.",
#     "To encourage 0_3 to donate back generously in future rounds, I should donate an amount that is significant but not too large to leave myself in a vulnerable position for upcoming rounds.",
#     "I will proceed with donating 2 units as per my strategy."
#   ],
#   "donation": 0.1111111111111111
# }
#
#
# 	Generation 0 Round 2
#
#
# 0_3 donation:
# {
#   "thoughts": [
#     "0_0 has a substantial amount of 26.0 units, which indicates they are likely to be generous.",
#     "Since 0_0 donated a small percentage (0.11%) in the previous round, their willingness to donate may be low.",
#     "Based on my strategy, I need to balance my donation to incentivize 0_0 while not losing too much of my own resources.",
#     "I will aim to maintain a competitive amount of resources while still encouraging cooperation."
#   ],
#   "donation": 0.05
# }
#
#
# 0_2 donation:
# {
#   "thoughts": [
#     "0_1 has a lower total than me, which suggests that they are probably not overly generous and could benefit from a respectable donation.",
#     "0_1 donated a small percentage in the last round, indicating they may be cautious and want to keep their resources safe.",
#     "Considering these factors, I will donate an amount that balances my need to retain units while still providing a meaningful contribution to encourage reciprocity in the next round."
#   ],
#   "donation": 0.2
# }
#
#
# 0_1 donation:
# {
#   "thoughts": [
#     "In round 1, 0_3 donated only 0.1% of their resources, which is quite low, indicating they might not be very generous.",
#     "Since 0_3 has a larger resource endowment (15.7 units), I should carefully consider how much to give in order to maximize the benefit while not overcommitting.",
#     "I'll start with a modest donation, perhaps around 2 units. This shows a willingness to contribute while preserving enough resources for myself.",
#     "Giving 2 units will allow 0_3 to receive 4 units in total, which may encourage better behavior in future rounds."
#   ],
#   "donation": 0.25
# }
#
#
# 0_0 donation:
# {
#   "thoughts": [
#     "In the previous round, 0_2 donated only a small amount (0.2% of their resources), indicating they are likely not very generous. Given that they now have 10.6 units, the donation was about 0.0212 units, which is negligible.",
#     "Since they are not likely to reciprocate generously based on this behavior, I want to adjust my donation accordingly to maximize my own resources.",
#     "I will donate a modest amount, slightly less than what I originally planned, to ensure I still retain enough resources while demonstrating some willingness to contribute."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 0 Round 3
#
#
# 0_3 donation:
# {
#   "thoughts": [
#     "In the previous rounds, 0_0 gave away very little (0.1% of their resources), indicating they are likely cautious with their donations.",
#     "I need to assess the best strategy, keeping in mind that I have 18.915 units and want to maximize future returns.",
#     "Since 0_0's previous donation was minimal, I should also keep my donation on the lower end to encourage reciprocity without jeopardizing my own resources.",
#     "Given that I want to influence their future decisions positively and keep a safe amount for my next role as a recipient, I will choose to donate a small, but not negligible amount."
#   ],
#   "donation": 0.05
# }
#
#
# 0_2 donation:
# {
#   "thoughts": [
#     "0_1 has a small amount of resources based on their previous donation (0.025 units), which suggests a cautious approach to giving. Since they currently have more than I've ever had, I want to encourage a positive response.",
#     "Considering my strategic plan, I should donate a modest amount that still reflects cooperation but doesn't put me at a disadvantage in future rounds. A small amount like 2 units maintains my advantage while helping increase 0_1's resources substantially.",
#     "Taking all factors into account, I will donate a fixed amount of 2 units, which aligns with my initial strategy and will help ensure 0_1 has a good amount to work with in the next round."
#   ],
#   "donation": 0.1459
# }
#
#
# 0_1 donation:
# {
#   "thoughts": [
#     "0_3 has a significant amount of resources (18.915 units), indicating they might be more willing to donate higher amounts in future rounds if I donate reasonably now.",
#     "In round 2, 0_3 donated only 0.05% of their resources. This suggests they may not be very generous, so I need to be cautious in my own donation amount to ensure I still have enough resources for future rounds.",
#     "Since my initial strategy was to start with a 5 unit donation, and I now have 10.24 units, I will adjust this donation slightly lower to account for potential future rounds where I will be the recipient. Giving a donation of 4 units would still motivate 0_3 to potentially donate more generously to me in the next round."
#   ],
#   "donation": 0.390625
# }
#
#
# 0_0 donation:
# {
#   "thoughts": [
#     "In round 2, 0_2 donated a very small percentage of their resources (0.2%) to 0_1, indicating that they may not be inclined to give much in return as a recipient.",
#     "Since I am paired with them as a donor this round, I must consider their low donation to their partner in round 2 and be cautious in how much I give away.",
#     "Given that I currently have a significantly larger resource pool than 0_2, I will aim to maintain a balance and not donate too much while still maximizing my potential return in the next round.",
#     "I will therefore choose to donate a moderate amount that does not compromise my own resources too drastically, while still being generous enough to encourage reciprocity in the next round."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 0 Round 4
#
#
# 0_1 donation:
# {
#   "thoughts": [
#     "0_0 currently has a high amount of resources (24.3645 units), indicating they are not needy and may not respond favorably to a low donation.",
#     "In round 1, I donated a fixed amount of 5 units, but I need to adjust my donation based on my partner's past behavior.",
#     "0_0 only received a very small percentage (0.5556%) in round 1 and has since also contributed minimally (0.1% in round 3). This suggests they are not inclined to share generously.",
#     "Since 0_0 is likely to benefit from a moderate donation and might reciprocate, I will aim to give enough to foster goodwill without depleting my own resources excessively.",
#     "A balanced approach could be to donate 30% (which is about 3.0695 units), which is generous enough to encourage a positive interaction without risking too much."
#   ],
#   "donation": 0.3
# }
#
#
# 0_2 donation:
# {
#   "thoughts": [
#     "In Round 3, 0_1 donated a small percentage (0.390625%) of their resources, indicating they might not be very generous.",
#     "In Round 2 and Round 1, the donations were even smaller (0.05% and 0.111%), suggesting that their partners are also hesitant to donate.",
#     "Given that I have more resources than 0_1, I can afford to donate enough to encourage them without giving too much away.",
#     "I will continue with my strategy of starting with smaller donations, but since 0_1's past donations are quite low, I will increase my initial donation a bit to encourage reciprocation. I'll opt to donate a higher percentage than 0_1's recent donations."
#   ],
#   "donation": 0.05
# }
#
#
# 0_0 donation:
# {
#   "thoughts": [
#     "In the previous rounds, 0_3 has shown a very low donation percentage (only 0.05% in the last round), indicating that they are not likely to donate much if I give them resources now.",
#     "Based on my strategy of starting with a donation of 2 units, I can consider that amount, but I also need to evaluate if a smaller amount would be more strategic given their less generous behavior.",
#     "Instead of donating my initial amount of 2 units, I will adjust my donation downward to make it less costly for myself, while still encouraging 0_3 to recognize the benefits of giving up a resource in the following rounds."
#   ],
#   "donation": 0.05
# }
#
#
# 0_3 donation:
# {
#   "thoughts": [
#     "I have 25.96925 units, and my strategy is to start with a minimal donation and adjust based on the generosity of my recipient.",
#     "In round 3, the recipient 0_2 received 0.1459% of their resource from 0_1, which indicates some willingness to share in the game.",
#     "In previous rounds, 0_2 received some donations but also contributed themselves, suggesting they might continue to reciprocate generosity.",
#     "Given 0_2's higher resource count (16.678088 units) and previous low donation percentages, I want to encourage generosity while balancing my resources.",
#     "I will donate 1 unit, which is sufficient to promote goodwill without jeopardizing my resource lead too much."
#   ],
#   "donation": 0.03854
# }
#
#
# 	Generation 0 Round 5
#
#
# 0_1 donation:
# {
#   "thoughts": [
#     "0_2 currently has a higher amount of units (17.84589339) compared to me (8.8300856), indicating they may have a generous nature.",
#     "Looking at 0_2's previous donations (which were very small, only 0.05% of their resources), it suggests they might not be inclined to give much.",
#     "Since I started with a 5 unit donation strategy but am now seeing a different pattern, I will adjust my donation to not exceed the proportions 0_2 has exhibited historically.",
#     "I want to ensure my donation is appealing enough to encourage 0_2 to reciprocate positively in the next rounds."
#   ],
#   "donation": 0.1
# }
#
#
# 0_3 donation:
# {
#   "thoughts": [
#     "0_0 has been a very low donor in previous rounds, giving only minimal percentages of their resources. This indicates that they might not be generous in reciprocation, as they have only given little to their past partners.",
#     "Since I currently have 27.404845105 units and 0_0 has 29.2853694, I should consider donating a small, but strategic amount. Given that my strategy involves adjusting my donations based on previous generosity, a low donation is advised here as a precaution.",
#     "If I give a very small percentage, I can test their generosity without sacrificing too much of my resources, while also being prepared for the reciprocation in the next round."
#   ],
#   "donation": 0.01
# }
#
#
# 0_0 donation:
# {
#   "thoughts": [
#     "Given my strategy to adjust donations based on the recipient's behavior, I notice 0_3 has a high resource count but donated a very small percentage previously.",
#     "Since they donated only 0.03854% of their resources in the last round, it suggests they might be conservative with their giving, implying they may not reciprocate generously.",
#     "To encourage better future cooperation, I will donate a moderate amount to show goodwill, while not being overly generous given their previous low percentages.",
#     "I aim to maintain a balance, donating enough to potentially encourage 0_3 to be more generous in subsequent rounds."
#   ],
#   "donation": 0.05
# }
#
#
# 0_2 donation:
# {
#   "thoughts": [
#     "0_1 has altered their donation behavior in the past rounds, indicating a somewhat low level of generosity with their recent donation of only 0.3%.",
#     "Given that they have less than 9 units left in this round, I can afford to give slightly above that minimum, making my donation impactful without risking loss for myself.",
#     "Since I have a good amount of resources (17.84589339), I want to donate enough to encourage reciprocity but not so much that it puts me at a disadvantage in the next rounds."
#   ],
#   "donation": 0.1
# }
#
#
# Evolving to generation 1
#
#
# Top half:
# player 0_3 with wallet 30.05933359395 and strategy: My strategy will be to start with a minimal donation of 1 unit in the first round, then adjust based on the generosity of the recipient in the previous round.
# player 0_0 with wallet 28.3691978321 and strategy: My strategy will be to start by donating 2 units in the first round, and adjust my donations based on the recipient's previous donation behavior in later rounds.
#
#
# 1_0 strategy:
# {
#   "thoughts": [
#     "Begin with a moderate donation to build goodwill.",
#     "Adjust future donations based on observed recipient generosity.",
#     "Aim for a balance between personal gain and cooperation in each round.",
#     "Maintain enough resources to survive and adapt."
#   ],
#   "strategy": "My strategy will be to start with a donation of 2 units in the first round, then adjust my donations based on the generosity shown by the recipient in the previous round."
# }
#
#
# 1_1 strategy:
# {
#   "thoughts": [
#     "In the first round, I should take a conservative approach since I have no information about the recipient's behavior.",
#     "I will donate a small amount to encourage cooperation and maximize potential returns.",
#     "In subsequent rounds, I will adjust the amount based on the recipient's previous donation behavior as indicated by their last donation to their partner.",
#     "If the recipient donated generously before, I will increase my donation to leverage the potential reciprocity."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round, then adjust my donations based on the recipient's previous donation in subsequent rounds."
# }
#
#
# 1_2 strategy:
# {
#   "thoughts": [
#     "Starting with a minimal donation increases my chance of maintaining resources.",
#     "I can adjust future donations based on the recipient's behavior.",
#     "Being cautious may help avoid large losses in initial rounds.",
#     "Learning from past rounds will guide my donation strategy more effectively."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round, and then I will adjust my donations up or down based on the recipient's most recent behavior."
# }
#
#
# 1_3 strategy:
# {
#   "thoughts": [
#     "Start with a moderate donation to gauge the recipient's response.",
#     "Adjust future donations based on the recipient's previous generosity.",
#     "Avoid giving too much initially to retain resources for future rounds.",
#     "Observe and adapt quickly based on the recipient's actions."
#   ],
#   "strategy": "My strategy will be to start by donating 2 units in the first round, and increase or decrease my donations based on the recipient's last round donation behavior."
# }
#
#
# Generation 1
#
#
# 	Generation 1 Round 1
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "1. I will start by donating 1 unit as per my strategy.",
#     "2. This is the first round, and I have 10 units, and I want to establish my strategy.",
#     "3. Donating 1 unit allows me to see how 1_0 behaves in the next round without risking too much of my resource."
#   ],
#   "donation": 0.1
# }
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "I will donate 1 unit, as per my strategy to start with a small donation in the first round.",
#     "This will establish a baseline for the expected reciprocity in the future rounds.",
#     "Since 1_3 has a full 10 units, a donation of 1 unit should not significantly harm my position as I will still have 9 units after this donation."
#   ],
#   "donation": 0.1
# }
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "Since I am the donor this round and my plan is to start with a donation of 2 units, I will stick to my strategy.",
#     "I should give up 2 units to 1_1. This is the initial amount I've decided to donate, which aligns with my strategy for the first round."
#   ],
#   "donation": 0.2
# }
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "I will start by donating 2 units as per my initial strategy.",
#     "This donation will be a moderate amount to encourage 1_2 to support me in the next round when I become the recipient.",
#     "I want to establish a cooperative relationship without giving too much away in the first round."
#   ],
#   "donation": 0.2
# }
#
#
# 	Generation 1 Round 2
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "I am currently a donor and have 13.0 units, while my recipient (1_0) has 10.0 units.",
#     "In the previous round, 1_0 only donated a very small amount (0.2% of 10, which is just 0.02 units).",
#     "Since 1_0's previous donation was minimal, I might assume they are not very generous.",
#     "To encourage more reciprocity without sacrificing too much of my resources, I will donate a small fixed amount of 1 unit as I planned in my strategy."
#   ],
#   "donation": 0.07692307692307693
# }
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "1_2 has a higher total of resources than I do, which indicates they might be less reliant on any small donations.",
#     "In the previous round, 1_2 only donated 0.1% of their resources, which is a minimal contribution indicating a likely cautious strategy.",
#     "Since I want to keep encouraging reciprocal donations but also maintain my own resource level, I should make a small donation to foster goodwill without risking too much of my own resources.",
#     "I will donate 1 unit again as per my original strategy since it has worked for me before."
#   ],
#   "donation": 0.07692307692307693
# }
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "In round 1, 1_3 donated a very small percentage (0.2%) of their resources, which indicates a low level of generosity or trust in their prior interaction.",
#     "Since 1_3's donation was minimal, I should be cautious about how much I donate this round as their generosity level is low.",
#     "To ensure that I still have a good amount of units for future rounds and to avoid giving away too much based on the recipient's past behavior, I will adjust my donation accordingly."
#   ],
#   "donation": 0.2
# }
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "I started with 10 units and donated 2 units in the first round. This time I am facing a recipient who has 13 units but only donated 0.1% of their resources previously, indicating they may not be inclined to share much. Since they have more units than me, I want to encourage cooperation without giving away too much of my resources.",
#     "Based on their last round donation, it seems they may not be very generous. Therefore, I want to balance between encouraging their cooperation and ensuring I keep enough resources for myself. I will aim to donate a small, reasonable amount that still allows me to retain a healthy amount of resources. Given the situation, I will choose to donate 1 unit."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 1 Round 3
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "1_1 has a larger resource pool (14.0 units) than me (13.0 units), which indicates they might have a stronger position in the game.",
#     "1_1's previous donation behavior was relatively low (0.0769% of 14 units), showing they might not be very generous or are cautious in their donations.",
#     "In my previous round, I aimed to start with a moderate donation to encourage reciprocation, and I want to keep up the same mindset to foster potential cooperation.",
#     "Given 1_1's previous low donation percentage, I should also consider keeping my donation moderate, around 2 units, to balance risk and maintaining goodwill."
#   ],
#   "donation": 0.15384615384615385
# }
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "I have 14.0 units now, and according to my strategy, I want to donate 1 unit in the first round to establish trust. In round 2, I was a recipient and 1_2 donated a very small percentage, which suggests they may not be inclined to give much. Since I am the donor this round, I need to decide on a reasonable donation that will still allow me to maximize my resources, while also being aware that giving too much may not be reciprocated well later on."
#   ],
#   "donation": 0.0714285714285714
# }
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "1_3 has 13.0 units, which indicates they may have been generous based on their donation history.",
#     "In round 2, 1_3 only donated 0.1% of their resources, which is a very low level of generosity. This could imply they are more focused on keeping their units than sharing.",
#     "To maintain my strategy of adjusting based on the generosity shown, I should be cautious in my donation.",
#     "Since their previous donation was minimal, I'll keep my donation low to protect my own resources while still attempting to encourage sharing."
#   ],
#   "donation": 0.1
# }
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "In round 1, 1_3 donated a small amount (0.2%) to 1_2, which indicates that they may not have a strong inclination to donate significantly. This means that 1_0 might be also following a similar strategy with a tendency towards minimal donations as seen in round 2.",
#     "Since 1_0 only donated 0.2% of their resources (which is 0.02 units), it appears they may be cautious about giving much away.",
#     "To promote cooperation and possibly encourage a better outcome for myself in the following rounds, I will offer a donation that is generous enough to show goodwill but not overly generous, keeping in mind the minimal donation from 1_0 in round 2.",
#     "I will decide to donate 1 unit, as this is aligned with my strategy of starting with a small but noticeable donation, sufficient to encourage reciprocation without putting myself at risk of losing too much. This should ideally set a positive tone for our interaction."
#   ],
#   "donation": 1.0
# }
#
#
# 	Generation 1 Round 4
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "1_0 has a significantly high amount of resource (37.0 units) compared to my 2.0 units, indicating they may be following a conservative donation strategy.",
#     "Since 1_0 donated only 0.1% of their resources in previous rounds, they might not reciprocate generously in this round.",
#     "Given that previous donors have also only given away small amounts, I should opt for a minimal donation to test the waters, keeping in mind the intention to adjust for future rounds."
#   ],
#   "donation": 0.05
# }
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "1_1 has a higher amount of resources (17.0 units), indicating they may be more generous or have benefitted from previous donations.",
#     "In the previous rounds, 1_1's donation behavior suggests they're relatively conservative, having only donated a small percentage of resources so far.",
#     "To encourage cooperation and reciprocity, I should donate enough to be generous but also maintain a competitive edge.",
#     "I will stick to my strategy of starting small, but since 1_1 has a decent amount, I will slightly increase my donation from the initial 2 units."
#   ],
#   "donation": 0.15384615384615385
# }
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "Since 1_2 currently has only 2 units, this indicates that their partners may have not donated significantly to them in the earlier rounds.",
#     "In the last round, 1_2 received a donation of only 0.2% from 1_3, showing that their previous partners may not have been very generous, so they might appreciate a donation more.",
#     "Based on my strategy of starting with a 1 unit donation in the first round, I feel it is reasonable to keep a similar donation scale. However, my current resources are higher, at 17 units, so giving away a fixed unit rather than a percentage might be beneficial.",
#     "To encourage reciprocity and maximize my resources, I will choose to give 1 unit."
#   ],
#   "donation": 0.058823529411764705
# }
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "In round 3, 1_3 donated a small percentage (approximately 0.15%) of their resources, which suggests they might not be highly generous or may be playing it safe. This indicates they might not reciprocate well if I donate too much.",
#     "Since I am 37.0 units wealthy and 1_3 is at 13.0 units, I have a significant advantage. I need to balance my donation to be generous enough to encourage reciprocation but not so much that I risk losing too much cash.",
#     "A reasonable donation would be a small percentage of my resources, around a bit more than what 1_3 donated, to set a standard for future rounds while also ensuring I protect my own standing."
#   ],
#   "donation": 0.05
# }
#
#
# 	Generation 1 Round 5
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "1_2 has only donated a very small percentage in previous rounds (0.05% last round), which suggests they are not generous.",
#     "Since I have a good amount of resources (14.7 units), I can afford to donate more than just the minimum while still ensuring I keep a solid amount for myself.",
#     "I will start by giving 1 unit to establish a more cooperative relationship, allowing 1_2 to receive 2 units back, which might encourage them to donate more in the next round."
#   ],
#   "donation": 0.06803
# }
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "1_0 has a significant amount of resources compared to my 20 units (35.35 units) which indicates they are likely to be a strong player.",
#     "1_0 donated only a very small percentage in the previous round (0.05% of their resources), suggesting they may be cautious or strategic in their donations.",
#     "My strategy is to adjust donations based on the recipient's previous behavior. Since 1_0's donation was low, I can also consider giving a small amount to keep some resources for myself while still contributing.",
#     "A donation of 1 unit aligns with my initial strategy from the first round and may be seen as generous enough to encourage reciprocity in future rounds."
#   ],
#   "donation": 0.05
# }
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "I have 3.9 units and I'm supposed to adjust my donation based on the recipient's behavior.",
#     "1_1 has 20.0 units, and previously donated only a small fraction to another player, which might suggest they are not very generous.",
#     "Since I must also preserve some resources for my next turn as recipient, I should balance my donation carefully against what 1_1 has shown in their donation behavior.",
#     "I will give a smaller amount to test their reciprocity since they have already shown limited generosity. A modest donation will demonstrate willingness without depleting my own resources too much."
#   ],
#   "donation": 0.1
# }
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "I am the donor in this round and I have more units (35.35) than my partner (1_3) who has 14.7 units.",
#     "1_3 has shown low generosity in their previous rounds, donating only around 0.15% of their total resources last round.",
#     "This suggests that 1_3 might not reciprocate well, thus I should be cautious in how much I donate to minimize my losses.",
#     "Following my strategy, I will make an initial donation. Given the low donation percentage from 1_3 earlier, I will donate a modest amount.",
#     "I will donate 2 units, similar to my initial strategy, which keeps a balance between generosity and safeguarding my resources."
#   ],
#   "donation": 0.0567
# }
#
#
# 	Generation 1 Round 6
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "1_1 has been donating very little (0.05% in round 5) and has received some (0.153846% in round 3).",
#     "Given their high resource count, it is probable that they may not reciprocate a larger donation.",
#     "To encourage giving, I should make a strategic donation that balances getting some return without giving away too much.",
#     "I will donate a small, yet noticeable amount that might entice them to give something back in the next round."
#   ],
#   "donation": 0.1
# }
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "1_2 has previously shown very low levels of generosity with their donations, maxing out at 1.0% in round 3, indicating they may not be willing to reciprocate.",
#     "Given their most recent donation of only 0.1% in round 5, it suggests that they are likely to conserve their resources and might not reciprocate a significant donation.",
#     "To avoid a situation where I over-donate and end up with less than I started, I should offer a minimal amount, ensuring I still benefit if they do not reciprocate adequately."
#   ],
#   "donation": 0.02
# }
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "In round 6, I need to consider how much I want to give to 1_0 based on their previous donation behaviors and my current resources. 1_0 has a relatively high resource amount (35.345655), indicating they might be generous in their next round as a recipient.",
#     "Looking at 1_0's previous donation of 0.0567% of their resources in round 5, this shows that they are somewhat reserved in their donations, possibly indicating they don't donate frequently or large amounts.",
#     "Considering I have 19.78 units, I want to make a donation that is enough to encourage 1_0 to reciprocate when I am their recipient next round. Giving a small percentage won't significantly hurt me and could benefit both of us in the long run.",
#     "I will choose to donate a slightly conservative amount, in this case around 0.1 units, which translates to about 0.505% of my current resources. This keeps me safe while also giving 1_0 a reason to possibly give back more in the next round."
#   ],
#   "donation": 0.00505
# }
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "I have a limited amount of resources to donate and I want to maximize my return in the next round as a recipient. Since I have 5.51 units, donating too much could leave me with too little in future rounds.",
#     "1_3 has a high amount of resources (17.708649 units) and previously donated a small amount (0.06803%) in the last round, which indicates that they may not be very generous in return.",
#     "Given these observations, I should donate a small but not insignificant amount to incentivize them to give back more in the next round while still keeping enough for myself."
#   ],
#   "donation": 0.1
# }
#
#
# Evolving to generation 2
#
#
# Top half:
# player 1_0 with wallet 34.8385199 and strategy: My strategy will be to start with a donation of 2 units in the first round, then adjust my donations based on the generosity shown by the recipient in the previous round.
# player 1_1 with wallet 23.221840800000003 and strategy: My strategy will be to donate 1 unit in the first round, then adjust my donations based on the recipient's previous donation in subsequent rounds.
#
#
# 2_0 strategy:
# {
#   "thoughts": [
#     "In the first round, I have no information to base my decision on, so I will start with a moderate donation.",
#     "For subsequent rounds, I will look at the recipient's previous donation and adjust my behavior based on their generosity.",
#     "If they donate a higher amount to their previous partner, I will increase my donation to encourage future cooperation.",
#     "If they donate less, I will either match it or slightly lower my donation to protect my resources."
#   ],
#   "strategy": "My strategy will be to start with a donation of 3 units in the first round, then adjust my donations based on the generosity shown by the recipient in the previous round."
# }
#
#
# 2_1 strategy:
# {
#   "thoughts": [
#     "Start with a conservative donation since there is no prior information about the recipient.",
#     "Observe the recipient's generosity in the first round and calibrate for the next pair.",
#     "Aim to create a cycle of mutual benefit by adjusting my donations based on their previous actions.",
#     "Balance giving enough to encourage reciprocity while retaining enough for my own score."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round, and then adjust my donations based on the recipient's previous round actions."
# }
#
#
# 2_2 strategy:
# {
#   "thoughts": [
#     "In the first round, I lack information on the recipient's behavior, so I should start with a reasonable donation to encourage collaboration.",
#     "In subsequent rounds, I will base my donations on the previous behavior of the recipient to incentivize them to be generous.",
#     "If the recipient donates generously, I will match or slightly increase my donation; if not, I will reduce my donation to minimize losses.",
#     "The goal is to build a cooperative relationship while also ensuring that I do not over-donate."
#   ],
#   "strategy": "My strategy will be to start with a donation of 3 units in the first round and adjust my donations in subsequent rounds based on the recipient's previous donation."
# }
#
#
# 2_3 strategy:
# {
#   "thoughts": [
#     "Begin with a moderate donation to test the waters.",
#     "Adjust my donations based on the recipient's generosity.",
#     "Pay attention to the donation patterns of previous partners.",
#     "Maintain a balance between being generous and maximizing my own units."
#   ],
#   "strategy": "My strategy will be to donate 2 units in the first round and adjust my donations based on the generosity shown by the recipient in the previous round."
# }
#
#
# Generation 2
#
#
# 	Generation 2 Round 1
#
#
# 2_1 donation:
# {
#   "thoughts": [
#     "I will donate 1 unit as per my strategy, which states to donate 1 unit in the first round.",
#     "Since 2_3 has 10 units, a small donation should be a safe choice to gauge their response.",
#     "This initial donation will help establish a baseline for how willing they are to reciprocate in the next round."
#   ],
#   "donation": 0.1
# }
#
#
# 2_0 donation:
# {
#   "thoughts": [
#     "I will start by implementing my strategy, which dictates an initial donation of 3 units.",
#     "Since I have 10 units, donating 3 units is reasonable and won't jeopardize my position.",
#     "This donation will allow me to potentially build a positive rapport with 2_2, increasing the chances of receiving more in subsequent rounds."
#   ],
#   "donation": 0.3
# }
#
#
# 2_2 donation:
# {
#   "thoughts": [
#     "Since this is the first round, I will stick to my initial strategy of donating 3 units.",
#     "I need to establish trust with my partner while also considering my own future gains.",
#     "Donating 3 now means that the recipient (2_1) will receive 6 units, which may encourage future reciprocation."
#   ],
#   "donation": 0.3
# }
#
#
# 2_3 donation:
# {
#   "thoughts": [
#     "I decided to donate 2 units in the first round as per my strategy.",
#     "I have a total of 10 units, and donating 2 units is a reasonable sacrifice that allows me to test the generosity of my partner 2_0.",
#     "If 2_0 reciprocates generously in the next round when I am the recipient, I can adjust my donations in future rounds accordingly."
#   ],
#   "donation": 0.2
# }
#
#
# 	Generation 2 Round 2
#
#
# 2_2 donation:
# {
#   "thoughts": [
#     "2_1 has a higher amount of resources (15.0 units) compared to my current 13.0 units, which suggests they are willing to be strategic in their donations.",
#     "Since 2_1 donated only a minimal amount (0.1%) in the previous round, they might not be great at sharing or they might be testing the waters.",
#     "I should offer a donation that is generous enough to encourage 2_1 to reciprocate in the next round while still retaining enough for myself to stay competitive.",
#     "Considering these factors, I will donate 3 units, as I did in round 1; this amount seems fair enough to build goodwill."
#   ],
#   "donation": 3.0
# }
#
#
# 2_0 donation:
# {
#   "thoughts": [
#     "In the previous round, 2_3 donated only 0.2% of their resources, which is quite low and indicates a selfish behavior. Given this information, I should adjust my donation accordingly to ensure that I preserve my resources while still offering some benefit to my partner.",
#     "Since 2_3 currently has 10 units and I have 11 units, I can afford to be somewhat generous without sacrificing too much of my own endowment.",
#     "I decide to give a small amount to test the waters, possibly around 1 unit, which will be significant for 2_3 but still allows me to retain enough resources for future rounds."
#   ],
#   "donation": 0.09090909090909091
# }
#
#
# 2_1 donation:
# {
#   "thoughts": [
#     "2_0 currently has 11.0 units, which means they have likely increased their resources from the previous rounds.",
#     "They donated only a small percentage (0.3%) in round 1, suggesting they might be conservative in their donations.",
#     "Since I have 15.0 units, I can afford to donate a little more generously to encourage cooperation.",
#     "I will give a larger amount than 0.3% to incentivize 2_0 to donate more in the next round when they become the donor."
#   ],
#   "donation": 0.1
# }
#
#
# 2_3 donation:
# {
#   "thoughts": [
#     "In the first round, I donated 2 units, which is 20% of my initial endowment. Looking at the current situation, my partner 2_2 has a total of 13.0 units, and they only donated a very small amount (0.3% of their resources) in their previous round, which indicates they are not very generous.",
#     "Since I am the donor this round and 2_2's past donation behavior suggests a lower willingness to reciprocate generosity, I should adjust my donation to a lower amount. I should still donate enough to encourage reciprocation but not too much that it risks my own total. A donation of 1 unit will be sufficient for this round."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 2 Round 3
#
#
# 2_2 donation:
# {
#   "thoughts": [
#     "2_1 has a significant amount of resources (39.5 units), suggesting they may be playing a cooperative strategy overall.",
#     "In round 2, 2_1 made a very small donation (0.1% of 39.5 units) to their partner, indicating a lack of willingness to donate.",
#     "To encourage future cooperation, I should make a modest donation that allows me to retain some resources while still showing generosity.",
#     "Since I have 2.0 units, I want to provide a modest donation that is more than what 2_1 offered in round 2, but also keeps enough resources for myself."
#   ],
#   "donation": 0.2
# }
#
#
# 2_1 donation:
# {
#   "thoughts": [
#     "2_0 has a total of 13.0 units and donated a very small amount (around 0.09 units) in the previous round, indicating they might not value contributions highly.",
#     "Since my resource amount is considerably larger (39.5 units), I can still afford to give away some units while maximizing my own future gains.",
#     "In round 1, 2_3 donated a little more than 0.02 units to 2_0, suggesting that 2_0 may be willing to contribute if they feel it's worthwhile.",
#     "Given 2_0's small donation in round 2 and their decent resource accumulation (13.0 units) without a robust track record of giving, I should choose a moderate donation.",
#     "To encourage reciprocity from 2_0 in the following round while ensuring I still retain a significant amount of resources, donating around 2 units seems appropriate."
#   ],
#   "donation": 0.05063291139240506
# }
#
#
# 2_3 donation:
# {
#   "thoughts": [
#     "In round 2, 2_2 donated only 3.0% of their resources, which translates to 0.06 units. This indicates a low level of generosity.",
#     "In round 1, 2_1's donation to 2_3 was also very low, at 0.1%. This may suggest a trend of minimal giving among these players.",
#     "Considering 2_2 currently has only 2.0 units, they might not be inclined to reciprocate generously after I donate.",
#     "Based on this information, to ensure I still retain a significant number of resources while encouraging generosity, I will keep my donation moderate."
#   ],
#   "donation": 0.2
# }
#
#
# 2_0 donation:
# {
#   "thoughts": [
#     "2_3 has received very low donations (0.1% in round 2, translating to only 0.011 units), suggesting they are not inclined to donate much. Since I have 13.0 units, I'm inclined to maintain a balance between generosity and my resource preservation.",
#     "Given that I'm in a favorable position with 13.0 units, I want to encourage 2_3 to return some donations in the future, but I also need to minimize my loss if they continue to be uncooperative.",
#     "I will stick to my strategy of adjusting based on the previous round recipient's behavior, but since 2_3's previous donation behavior shows a lack of generosity, I will simplify my approach and make a reasonable donation."
#   ],
#   "donation": 2.0
# }
#
#
# 	Generation 2 Round 4
#
#
# 2_1 donation:
# {
#   "thoughts": [
#     "2_2 has been donating very small amounts (0.2%, 0.1%, and 0.3%) in previous rounds.",
#     "Since they donated only 0.2% as a donor last round, this suggests they may not be likely to reciprocate generosity.",
#     "I have a significant amount of resources (38.3 units), so I need to decide on a donation that encourages cooperation but protects my advantage.",
#     "I will donate a small amount to test the waters, but since their donations have been minimal, I will keep my donation lower."
#   ],
#   "donation": 0.02
# }
#
#
# 2_2 donation:
# {
#   "thoughts": [
#     "I have 6.0 units of resource and I'm playing as a donor this round.",
#     "My strategy is to start with a donation of 3 units and adjust donations based on previous rounds.",
#     "2_0 only donated 2.0% of their resources, which shows they might not be a very generous player.",
#     "To maximize my resources, I should consider giving a reasonable amount that encourages reciprocation without overly sacrificing my own units.",
#     "Since I have 6.0 units, giving away too much might hurt me in the next round, so I will aim for a balanced donation."
#   ],
#   "donation": 0.5
# }
#
#
# 2_0 donation:
# {
#   "thoughts": [
#     "In the previous rounds, 2_3 showed minimal generosity, donating a very small percentage (0.2%) which is significantly lower than the amounts I was planning to donate (3 units at initial). I currently have 4.0 units, and given their low past donations, I cannot expect a favorable return on a large donation. Therefore, I should adjust my donation to be low as well, aiming to protect my resources while still contributing enough to encourage some reciprocation in the next round.",
#     "Considering the circumstances and my current resource level, I will donate a small amount to stay in the game but also retain enough units for myself. I will donate 1 unit."
#   ],
#   "donation": 0.25
# }
#
#
# 2_3 donation:
# {
#   "thoughts": [
#     "2_1 has a significantly high amount of resources (38.3 units), indicating they may be capable of giving generously.",
#     "2_1 donated a very small percentage (about 0.05%) of their resources last round, which may suggest they are cautious or strategic in their donations.",
#     "Since I have 34.8 units, I will adjust my donation based on the low generosity shown by 2_1 in the previous round. I should give a modest amount that encourages reciprocity but not so much that I sacrifice too much of my resources.",
#     "Considering these factors, I will donate a small percentage of my current units."
#   ],
#   "donation": 0.05
# }
#
#
# 	Generation 2 Round 5
#
#
# 2_3 donation:
# {
#   "thoughts": [
#     "In round 4, 2_2 only donated 0.5% of their resources, which indicates they are not very generous.",
#     "Given that I have a significant resource advantage over 2_2, I want to maintain a balance to not overly disadvantage myself.",
#     "Since 2_2 has shown low generosity, and to encourage reciprocity, I will donate a small yet meaningful amount, around 5% of my resources."
#   ],
#   "donation": 0.05
# }
#
#
# 2_1 donation:
# {
#   "thoughts": [
#     "In round 4, 2_3 donated only a minuscule amount (0.05% of 35.06), indicating they might be hesitant to donate or they are currently focused on maximizing their own resources.",
# ...
#     "Given my current amount, donating 1 unit (which is about 9.09%) seems like a reasonable starting point to maintain generous behavior while also considering 3_3's likely lower contribution tendency."
#   ],
#   "donation": 0.0909
# }
#
#
# 3_2 donation:
# {
#   "thoughts": [
#     "Since I donated 1 unit in the first round, I need to consider 3_1's previous donation behavior.",
#     "3_1 donated only 0.1% of their resources (which is 0.011 units) in the last round, indicating they were not very generous.",
#     "Given their low donation, I should adjust my strategy and not be too generous myself in this round.",
#     "I will donate slightly more than 0.1% of my resources to incentivize them without giving away too much for now."
#   ],
#   "donation": 0.05
# }
#
#
# 3_3 donation:
# {
#   "thoughts": [
#     "Considering my strategy to adjust donations based on the recipient's actions, I see that 3_2 donated a very small amount (0.1%) to their partner in round 1.",
#     "Given that 3_2 currently has 11.0 units, their previous low contribution suggests a reluctance to be generous, which may indicate that they might not reciprocate well if I donate a high amount.",
#     "Therefore, I should keep my donation moderate to encourage a better response while protecting my own resources for future rounds.",
#     "I will donate 1 unit, which meets my strategy's aim to begin with a small contribution and allows me to remain competitive. This amount is enough to provide a significant benefit to 3_2 while minimizing risk. But I want to avoid overcommitting right away."
#   ],
#   "donation": 0.09090909090909091
# }
#
#
# 	Generation 3 Round 3
#
#
# 3_2 donation:
# {
#   "thoughts": [
#     "3_1 has shown a willingness to accept a small donation (0.1% from 3_0 in previous rounds), which may indicate that they appreciate a bit of generosity.",
#     "Since 3_1 is currently at 1.1 units, their donation to 3_0 suggests they might be cautious but open to receiving more resources.",
#     "Given my strategy of starting with a small donation to assess their generosity, I will choose to donate a reasonable, minimal amount but still enough to encourage further cooperation."
#   ],
#   "donation": 0.05000000000000001
# }
#
#
# 3_1 donation:
# {
#   "thoughts": [
#     "In the previous round, 3_3 donated a very small percentage of their resources, which indicates a relatively uncooperative tendency. However, they did receive a small donation from 3_2, showing that they might be willing to accept some generosity.",
#     "Since I have only 1.1 units and need to maximize my resources while still being strategic, I should consider offering a donation that grants 3_3 an incentive to be more generous in future rounds, but not too much that I risk losing all of my resources."
#   ],
#   "donation": 0.1
# }
#
#
# 3_3 donation:
# {
#   "thoughts": [
#     "3_0 has a significantly larger resource compared to me, currently holding 32.0001 units. In round 1, they received a small donation from their partner, and in round 2, they reciprocated with an even smaller donation. This suggests that they may not be a generous donor.",
#     "Given that my strategy is to adjust donations based on the recipient's recent actions, I should play cautiously. Since their donations have been minimal, I should mirror this cautiousness, but still offer some contribution to foster goodwill.",
#     "I will donate a small amount to maintain my position in the game without putting myself at a disadvantage, while still trying to encourage potential future cooperation."
#   ],
#   "donation": 0.01
# }
#
#
# 3_0 donation:
# {
#   "thoughts": [
#     "3_2 has a higher resource count than I do, showing that they may have a stronger giving tendency.",
#     "In previous rounds, 3_2 donated a very small amount (0.05%), which indicates a potential low level of trust or willingness to give more.",
#     "To maintain a good balance and encourage cooperation, I will make a moderate donation that could encourage them to reciprocate in the next round.",
#     "Given that I have 32.0001 units, I may consider donating a noticeable but not excessive fraction to create a positive interaction."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 3 Round 4
#
#
# 3_2 donation:
# {
#   "thoughts": [
#     "I am playing as a donor this round, and I have 18.22752 units to give away.",
#     "My strategy is to start by donating a small amount and adjust based on the recipient's behavior.",
#     "3_3 has shown only minimal donation behavior in past rounds (0.01% and 0.1%), which indicates a conservative approach.",
#     "Since 3_3 currently has a higher resource count than mine, I will aim for a balance between generosity and not overextending myself."
#   ],
#   "donation": 0.05
# }
#
#
# 3_0 donation:
# {
#   "thoughts": [
#     "In this round, I need to decide how much to donate to 3_1 based on their donation behavior and my current strategy.",
#     "3_1 has made minimal donations in previous rounds, so chances are they might not return a generous contribution when they are the donor next round.",
#     "Since my goal is to maximize my resources over the rounds, I should keep my donation somewhat modest to ensure I have enough resources for the next round as a recipient.",
#     "I will consider donating slightly more than they donated in previous rounds to encourage a better response in the next round."
#   ],
#   "donation": 0.01
# }
#
#
# 3_1 donation:
# {
#   "thoughts": [
#     "In this round, I'll be a donor and I have 2.235 units.",
#     "My strategy is to adjust my donation based on the previous round's action of my recipient.",
#     "3_0 has shown a pattern of low donations (0.1% in round 3) which indicates a tendency to be less generous.",
#     "Considering their current resource level, 29.04 units, 0.1% would be 0.029 units, which is quite low.",
#     "Since they are not very generous, I don't want to give too much of my limited resources this time.",
#     "I will donate enough to encourage them to reciprocate, but not so much that I hurt my own position. I decide to donate 0.2 units."
#   ],
#   "donation": 0.0895641057920175
# }
#
#
# 3_3 donation:
# {
#   "thoughts": [
#     "3_2 currently has 18.23 units, which indicates they are likely a generous player I can work with.",
#     "In previous rounds, 3_2 has donated a very low percentage (0.05%) to 3_1, suggesting they may be cautious or strategic in their donations.",
#     "Since my strategy includes adjusting donations based on the recipient's actions, I need to decide a donation that still leaves me with enough units to participate effectively in future rounds.",
#     "Given I have about 12.1 units, I could set an initial donation to see if 3_2 reciprocates more favorably next round.",
#     "I will donate 1 unit to establish a baseline and see if this encourages generosity from 3_2 in the next round."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 3 Round 5
#
#
# 3_0 donation:
# {
#   "thoughts": [
#     "Based on my strategy, I will donate a small amount to maintain a positive interaction with 3_2, who has a significantly larger resource pool than I do.",
#     "3_2's previous donations were very minimal, indicating a potential reluctance to give, so I want to ensure that my donation is perceived positively and encourages reciprocation later.",
#     "Given the scenario, I plan to donate 1 unit again, as it is a consistent strategy and allows me to engage effectively without risking too much of my own resources."
#   ],
#   "donation": 0.0343
# }
#
#
# 3_2 donation:
# {
#   "thoughts": [
#     "3_0 has a lot of resources (29.15 units), but they've been very stingy in their donations (only 0.01% last round).",
#     "Given this behavior, they may not reciprocate generously, so I need to be cautious with my donation this round.",
#     "Since I need to maximize my resources, I'll limit my donation, ensuring I still have a substantial amount left for the next round."
#   ],
#   "donation": 0.05
# }
#
#
# 3_1 donation:
# {
#   "thoughts": [
#     "In round 4, 3_3 donated only 0.1% of their resources, indicating they are not overly generous. Based on this information, I should be cautious about how much I donate to them, as they may not reciprocate well in the next round.",
#     "Given I have 2.6156259435548415 units, donating too much could leave me vulnerable in subsequent rounds. I need to strike a balance between being a good donor and protecting my own resources for future rounds.",
#     "I will donate a small amount, which shows goodwill without risking too much of my own resources. I will round my donation to a simple number to simplify calculations."
#   ],
#   "donation": 0.2
# }
#
#
# 3_3 donation:
# {
#   "thoughts": [
#     "In round 4, 3_1 made a small donation, which indicates they are willing to give but may not prioritize it highly. In round 3, the donation from their partner was also low, suggesting a cautious approach on their part. Given that 3_1 has a small amount of resources, they might be in a position of scarcity, influencing their willingness to reciprocate favorably in the next round.",
#     "Since I have a good amount of 12.71 units, I can afford to make a donation that is meaningful but still cautious. I will donate enough to encourage reciprocity while keeping some resources for my next rounds.",
#     "I will decide to give them an amount that benefits both of us, such as 0.5 units, which is about 3.94% of my total. This is enough to show goodwill while still allowing me to retain a solid amount of resources."
#   ],
#   "donation": 0.5
# }
#
#
# 	Generation 3 Round 6
#
#
# 3_3 donation:
# {
#   "thoughts": [
#     "3_1 has a higher amount of resources than I do, indicating they might be less willing to reciprocate if I donate significantly. ",
#     "Previous donations from 3_1 have been quite low, suggesting that they may not have a generous donation strategy. ",
#     "Given my limited resources, it's vital to make an impact without risking too much. I'll start by matching their previous donations or slightly exceeding them to encourage a better response in future rounds.",
#     "Considering their donation history, donating 0.1 units (equivalent to about 1.35% of my resources) seems like a reasonable approach to show goodwill while still preserving some of my resources."
#   ],
#   "donation": 0.0135
# }
#
#
# 3_1 donation:
# {
#   "thoughts": [
#     "In round 5, 3_0 very minimally donated 0.0343% of their resources, indicating a lack of generosity.",
#     "My strategy is to adapt my donation based on the past donations of my partner. Given 3_0's low donation, I should donate conservatively.",
#     "As I have 14.805 units, I will calculate 1 unit as a reference for a reasonable and safe donation amount."
#   ],
#   "donation": 0.0675
# }
#
#
# 3_0 donation:
# {
#   "thoughts": [
#     "I have 30.12 units, and I need to decide my donation based on 3_2's previous donation behavior.",
#     "3_2 donated only a small percentage of their resources (0.05% in round 5), suggesting they might not be very generous.",
#     "To maximize my units and encourage reciprocation, I should consider donating a modest amount that could encourage a positive response in the next round.",
#     "Since I want to match or slightly increase my donation compared to previous rounds while staying impactful, I will donate a small fixed amount instead of a percentage."
#   ],
#   "donation": 0.033
# }
#
#
# 3_2 donation:
# {
#   "thoughts": [
#     "In this round, I need to consider the generosity shown by my partner 3_3 in their previous actions, which have been minor donations. They donated only 0.5% of their resources, suggesting they might not be very generous or are hesitant to give away much. Nonetheless, I want to encourage their potential generosity while ensuring I retain enough units for myself after this round.",
#     "I have 20.748991697132276 units, and to follow my strategy of donating based on the recipient's previous actions, I should consider a modest donation. Since 3_3 hasn't shown significant generosity, I will keep my donation relatively low, but I still want to give enough to maintain a cooperative dynamic.",
#     "I decide to donate 1 unit, a fixed amount that I initially planned to donate in early rounds, which allows me to signal my willingness to cooperate without jeopardizing my resource pool too much."
#   ],
#   "donation": 0.04830000702115435
# }
#
#
# Evolving to generation 4
#
#
# Top half:
# player 3_0 with wallet 31.128400510375414 and strategy: My strategy will be to donate 1 unit in the first round, and then either match or slightly increase my donations based on the recipient's most recent donation behavior.
# player 3_2 with wallet 21.73498611018431 and strategy: My strategy will be to donate 1 unit in the first round, then adjust based on the recipient's previous round actions, and increase my donation if they have shown generosity.
#
#
# 4_0 strategy:
# {
#   "thoughts": [
#     "Start by donating a small amount to establish trust.",
#     "Based on recipient's generosity in the prior round, decide whether to increase or maintain donation.",
#     "If the recipient was not generous, consider reducing my donation.",
#     "Aim to strike a balance between mutual benefit and resource retention."
#   ],
#   "strategy": "My strategy will be to donate 2 units in the first round and adjust my subsequent donations based on the recipient's prior generosity, increasing donations if they were generous and reducing if they were not."
# }
#
#
# 4_1 strategy:
# {
#   "thoughts": [
#     "Starting with a small initial donation helps build trust.",
#     "Observe the recipient's previous actions to assess their behavior.",
#     "If the recipient has donated, slightly increase my donation to encourage reciprocity.",
#     "Maintain flexibility to adjust my donations based on their trustworthiness."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round, then increase my donation based on the generosity of the recipient in the previous round."
# }
#
#
# 4_2 strategy:
# {
#   "thoughts": [
#     "Start by donating a small amount to encourage generosity from the recipient.",
#     "Observe the recipient's donation behavior in the previous round to decide my donation in the next round.",
#     "If the recipient appears generous, I will match or slightly increase my donation.",
#     "If they have been stingy, I will reduce my donation to preserve my resources."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round, then adjust my donations based on the recipient's previous round behavior, increasing if they donated previously."
# }
#
#
# 4_3 strategy:
# {
#   "thoughts": [
#     "I need to start with a conservative donation since I have no information about the recipient's behavior in the first round.",
#     "Observing the recipient's previous donation behavior will help guide my future donations to encourage mutual cooperation.",
#     "If the recipient has shown generosity, I'll increase my donation to maximize my return.",
#     "My goal is to build trust over rounds for potential higher earnings."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round, then adjust my donations based on the recipient's previous donation to encourage reciprocal behavior."
# }
#
#
# Final players:
# player 4_0 with wallet 10 and strategy: My strategy will be to donate 2 units in the first round and adjust my subsequent donations based on the recipient's prior generosity, increasing donations if they were generous and reducing if they were not.
# player 4_1 with wallet 10 and strategy: My strategy will be to donate 1 unit in the first round, then increase my donation based on the generosity of the recipient in the previous round.
# player 4_2 with wallet 10 and strategy: My strategy will be to donate 1 unit in the first round, then adjust my donations based on the recipient's previous round behavior, increasing if they donated previously.
# player 4_3 with wallet 10 and strategy: My strategy will be to donate 1 unit in the first round, then adjust my donations based on the recipient's previous donation to encourage reciprocal behavior.
