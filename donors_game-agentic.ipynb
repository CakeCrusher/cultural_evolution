# %% [markdown]
# ## Setup Telemetry

# %%
import os
import dotenv

dotenv.load_dotenv()

from phoenix.otel import register

OTEL_EXPORTER_OTLP_HEADERS = os.getenv("OTEL_EXPORTER_OTLP_HEADERS")
PHOENIX_CLIENT_HEADERS = os.getenv("PHOENIX_CLIENT_HEADERS")
PHOENIX_COLLECTOR_ENDPOINT = os.getenv("PHOENIX_COLLECTOR_ENDPOINT")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if not OTEL_EXPORTER_OTLP_HEADERS or not PHOENIX_CLIENT_HEADERS or not PHOENIX_COLLECTOR_ENDPOINT or not OPENAI_API_KEY:
    raise ValueError("Missing required environment variables")

endpoint = PHOENIX_COLLECTOR_ENDPOINT + "/v1/traces"

# %%
project_name = "donors_game"

tracer_provider = register(
    project_name=project_name,
    endpoint=endpoint
)

from openinference.semconv.resource import ResourceAttributes
from opentelemetry import trace
from opentelemetry.exporter.otlp.proto.http.trace_exporter import OTLPSpanExporter
from opentelemetry.sdk.resources import Resource
from opentelemetry.sdk.trace import TracerProvider
from opentelemetry.sdk.trace.export import SimpleSpanProcessor
from openinference.semconv.trace import SpanAttributes
from openinference.semconv.trace import OpenInferenceSpanKindValues
from opentelemetry import context as context_api



resource = Resource(attributes={
  ResourceAttributes.PROJECT_NAME: project_name
})

tracer_provider = TracerProvider(resource=resource)
trace.set_tracer_provider(tracer_provider=tracer_provider)
tracer = trace.get_tracer(__name__)
span_exporter = OTLPSpanExporter(endpoint=endpoint)
simple_span_processor = SimpleSpanProcessor(span_exporter=span_exporter)
trace.get_tracer_provider().add_span_processor(simple_span_processor)
# Out:
# Overriding of current TracerProvider is not allowed
# OpenTelemetry Tracing Details
# |  Phoenix Project: donors_game
# |  Span Processor: SimpleSpanProcessor
# |  Collector Endpoint: https://app.phoenix.arize.com/v1/traces
# |  Transport: HTTP
# |  Transport Headers: {'api_key': '****'}
# |
# |  Using a default SpanProcessor. `add_span_processor` will overwrite this default.
# |
# |  `register` has set this TracerProvider as the global OpenTelemetry default.
# |  To disable this behavior, call `register` with `set_global_tracer_provider=False`.

# %%
from openinference.instrumentation.openai import OpenAIInstrumentor
OpenAIInstrumentor().instrument(tracer_provider=tracer_provider)

import openai
client = openai.OpenAI(api_key=OPENAI_API_KEY)

# %% [markdown]
# ## Configurations, Typings, and Player Class

# %%
from pydantic import BaseModel, Field
from typing import Any, List, Optional
from time import sleep
import json


class DynamicGameState(BaseModel):
  generation: int
  round: int

class GameConfig(BaseModel):
  donation_multiplier: float = 2
  trace_depth: int = 3
  base_wallet: int = 10
  generations: int = 10
  rounds: int = 12
  players: int = 12
  cutoff_threshold: float = 0.5

class GameState(GameConfig, DynamicGameState):
  pass
  

class Decision(BaseModel):
  # agents data
  recipient_name: str
  donor_name: str
  # game state data
  dynamic_game_state: DynamicGameState
  # donation data
  donation_percent: float
  donation_amount: float
  # donor wallet data
  donor_wallet_before: float
  donor_wallet_after: float
  
  class Config:
    arbitrary_types_allowed = True

class StrategyBuilder(BaseModel):
  """Build the strategy"""
  thoughts: List[str] = Field(..., description="Briefly describe your thought process for the strategy to take for this round. KEEP THOUGHTS SHORT AND NO MORE THAN 4 THOUGHTS.")
  strategy: str = Field(..., description="The strategy to be used, must begin with 'My strategy will be'. KEEP THOUGHTS SHORT AND NO MORE THAN 4 THOUGHTS.")

class DonationBuilder(BaseModel):
  """Build the donation"""
  thoughts: List[str] = Field(..., description="Briefly describe your thought process for the donation to make for this round.")
  donation: float = Field(..., description="The percentage amount of resources to donate. MUST BE A FLOAT BETWEEN 0 AND 1.")

def structured_generation_wrapper(*args, **kwargs) -> dict:
  # sleep(.1)
  span = trace.get_current_span()
  args_to_log = {**kwargs, "response_format": kwargs["response_format"].model_json_schema()}
  span.set_attribute(SpanAttributes.INPUT_VALUE, json.dumps(args_to_log))
  res = client.beta.chat.completions.parse(**kwargs)
  span.set_attribute(SpanAttributes.OUTPUT_VALUE, res.model_dump_json())
  so = res.choices[0].message.parsed
  if not so:
    raise ValueError("No response from LLM")
  return so

class Player:
  def __init__(self, game_state: GameState, i: int, parents: List["Player"] = [], strategy: Optional[str] = None):
    self.name: str = f"{game_state.generation}_{i}"
    self.parents: List[Player] = parents
    self.history: List[Decision] = [] 
    self.wallet: int = game_state.base_wallet
    if strategy:
      self.strategy: str = strategy
    else:
      self.strategy: str = self.generate_strategy(game_state=game_state, parents=parents)
    
  def find_decision_in_round(self, round_number: int) -> Decision:
    for decision in self.history:
      if decision.dynamic_game_state.round == round_number:
        return decision
    raise ValueError(f"Decision in round {round_number} not found")

  
  # def clone(self):
  #   player = Player(name=self.name, parents=self.parents, strategy=self.strategy)
  #   player.wallet = self.wallet
  #   player.history = self.history
  #   return player



  def system_prompt(self, game_state: GameState):
    return f"""Each player is given an initial endowment of 10 units of a resource.
In each round, you are randomly paired with another individual.
One of you is a donor, and the other is a recipient.
The donor decides to give up some amount of the resource.
The recipient receives {game_state.donation_multiplier}x the number of units that the donor gave up.
If you were a donor in one round, you will be a recipient in the next round, and vice versa.
Your goal is to maximize the number of units you have after the final round.
After the game has finished, the best-performing half of agents will survive to the next generation, and continue playing."""

  def strategy_prompt(self, parents: List["Player"] = []):
    if parents: 
      parent_advice = "\n".join([f"\n\n{parent.name} with score {parent.wallet} strategy: {parent.strategy}" for parent in parents])
      generation_prompt = f"""How would you approach the game? Here is the advice of the best-performing 50% of the previous generation, along with their final scores.
{parent_advice}
Modify this advice to create your own strategy."""
    else: 
      generation_prompt = "Based on the description of the game, create a strategy that you will follow in  the game."
    
    return f"""Our name is {self.name}.

{generation_prompt}

As a donor, you will receive limited information about the recipient and their recent interactions: You will see what the recipient (let’s call them A) did in the immediately preceding round only.
You will also see what A’s partner from that round (let’s call them B) did in their preceding round.
This chain continues for at most three rounds back.
Important: You do NOT have access to multiple rounds of information about A directly.
You only know what A did in the single most recent round.

Example (assuming it’s now round 4): You are paired with A.
You know: In round 3, A donated X% to B.
You also know: In round 2, B donated Y% to C.
And finally: In round 1, C donated Z% to D.
Remember: This is all the information you have.
You don’t know what A did in rounds 1 or 2, only in round 3.

In the first round, there will be no information about the recipient’s previous behavior - think carefully about how much to donate in that case.
Before formulating your strategy, briefly think step by step about what would be a successful strategy in this game.
Then describe your strategy briefly without explanation in one sentence that starts: My strategy will be."""
  
  def donation_prompt(self, game_state: GameState, recipient: "Player", players: List["Player"]):
    def find_player(name: str) -> "Player":
      for player in players:
        if player.name == name:
          return player
      raise ValueError(f"Player {name} not found")
    
    def build_trace(depth: int):
      trace = ""
      current_recipient = recipient

      for i in range(depth):
        round_number = game_state.round - (i+1)
        if round_number < 1:
          break
        recipient_decision = current_recipient.find_decision_in_round(round_number)
        trace += f"In round {round_number}, {current_recipient.name} donated {recipient_decision.donation_percent}% of their resources to {recipient_decision.recipient_name}.\n"
        current_recipient: Player = find_player(recipient_decision.recipient_name)
      return trace
    
    trace = build_trace(game_state.trace_depth)

    # TODO: donor is invisible to recipient
    return f"""Your name is 2_4.
As you will recall, here is the strategy you decided to follow: {self.strategy}
This is generation {game_state.generation}.
It is now round {game_state.round}.
In this round, you have been paired with {recipient.name}.
They currently have {recipient.wallet} units of the valuable resource.
Here is what {recipient.name} and their earlier partners did in previous rounds: {trace}
You will take the role of donor. You currently have {self.wallet} units of the valuable resource.

How many units do you give up? Very briefly think step by step about how you apply your strategy in this situation and then provide your answer."""
  
  def generate_strategy(self, game_state: GameState, parents: List["Player"] = []) -> str:
    with tracer.start_as_current_span("generate_strategy") as span:
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.LLM.value)
      messages = [
        {"role": "system", "content": self.system_prompt(game_state=game_state)},
        {"role": "user", "content": self.strategy_prompt(parents=parents)},
      ]
      args = {
        "model": "gpt-4o-mini",
        "messages": messages,
        "response_format": StrategyBuilder
      }
      res = structured_generation_wrapper(**args)
      built_strategy = StrategyBuilder.model_validate(res)

      print(f"\n\n{self.name} strategy:\n{built_strategy.model_dump_json(indent=2)}")

      return built_strategy.strategy
  
  def generate_donation(self, game_state: GameState, recipient: "Player", players: List["Player"]) -> float:
    with tracer.start_as_current_span("generate_donation") as span:
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.LLM.value)
      messages=[
        {"role": "system", "content": self.system_prompt(game_state=game_state)},
        {"role": "user", "content": self.donation_prompt(game_state=game_state, recipient=recipient, players=players)},
      ]
      args = {
        "model": "gpt-4o-mini",
        "messages": messages,
        "response_format": DonationBuilder
      }
      res = structured_generation_wrapper(**args)
      built_donation = DonationBuilder.model_validate(res)

      print(f"\n\n{self.name} donation:\n{built_donation.model_dump_json(indent=2)}")

      return built_donation.donation
  
  def setup_donation(self, recipient: "Player", game_state: GameState, players: List["Player"], context: context_api.Context) -> Decision:
    token = context_api.attach(context)
    try:
      with tracer.start_as_current_span(f"execute_donation-{self.name}") as span:
        span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.AGENT.value)
        span.set_attribute(SpanAttributes.INPUT_VALUE, json.dumps(self.model_dump()))
        donation_percent = self.generate_donation(game_state, recipient, players)
        donation_amount = self.wallet * donation_percent

        # if the donor doesn't have enough funds, donate all of their funds
        if self.wallet - donation_amount < 0:
          donation_amount = self.wallet
        

        span.set_attribute(SpanAttributes.OUTPUT_VALUE, json.dumps({
          "donation_percent": donation_percent,
          "donation_amount": donation_amount,
        }))

        game_state_copy = GameState(**game_state.model_dump())
        decision = Decision(
          donor_name=self.name,
          recipient_name=recipient.name,
          dynamic_game_state=game_state_copy,
          donation_percent=donation_percent,
          donation_amount=donation_amount,
          donor_wallet_before=self.wallet,
          donor_wallet_after=self.wallet - donation_amount
        )
        
        return decision
    finally:
      context_api.detach(token)
    
  def execute_donation(self, recipient: "Player", game_state: GameState, donation: Decision):
    self.wallet -= donation.donation_amount
    recipient.wallet += donation.donation_amount * game_state.donation_multiplier

    self.history.append(donation)

  # get current user information as a dict
  def model_dump(self):
    return {
      "name": self.name,
      "parents": [parent.name for parent in self.parents],
      "history": [decision.model_dump() for decision in self.history],
      "wallet": self.wallet,
      "strategy": self.strategy
    }
  
  # function to make the player json serializable
  def __json__(self):
    return self.model_dump()

# %% [markdown]
# ### Test Player

# %%
# test by creating two players
game_state = GameState(generation=1, round=1)
player1 = Player(game_state=game_state, i=1)
player2 = Player(game_state=game_state, i=2)
# Out:
# 1_1 strategy:
# {
#   "thoughts": [
#     "In the first round, I should play conservatively since I have no information about the recipient's past behavior; thus, donating a small amount (e.g., 1 or 2 units) is a good start to minimize my loss while still potentially providing enough incentive for the recipient.",
#     "As I gather information in subsequent rounds, I will adjust my donation based on the previous actions of my partner. If they donated a significant amount to their past partner, I may choose to match that generosity to maintain reciprocity.",
#     "If I sense that the recipient has a history of being generous based on the actions of their most recent partner, I will consider increasing my donation in hopes of benefitting from their generosity in the next round.",
#     "On the other hand, if it appears my recipient has been stingy, I will be cautious and either maintain my smaller donation or stop donating altogether if I see a pattern of them taking resources without giving back."
#   ],
#   "strategy": "My strategy will be to start by donating a small percentage of my resources in the first round and adjust my donations based on the perceived generosity of my partner in subsequent rounds."
# }
#
#
# 1_2 strategy:
# {
#   "thoughts": [
#     "In the first round, since there is no prior activity to gauge the recipient's behavior, I will allocate a minimal amount to protect my resources.",
#     "In subsequent rounds, I will analyze the recipient's recent donation behavior to decide the trustworthiness of their actions.",
#     "If the recipient donated a significant amount in the last round, I will reciprocate with a higher donation to foster cooperation.",
#     "If the recipient contributed less, I will choose to donate less to mitigate my losses.",
#     "Ultimately, I want to maintain a balance where I gain resources while encouraging positive behaviors in my partners."
#   ],
#   "strategy": "My strategy will be to donate a small percentage in the first round and adjust my donations based on the recent donation behavior of my recipient in subsequent rounds."
# }

# %%
player1.execute_donation(player2, game_state, [player1, player2])
# Out:
# 1_1 donation:
# {
#   "thoughts": [
#     "Since it's the first round, my partner has no previous rounds of generosity to analyze. Therefore, I need to establish a baseline of trust. I will donate a small percentage of my current units to show goodwill, while still retaining enough for myself.",
#     "I will choose a small yet significant percentage to donate, aiming for a donation that allows me to maintain a favorable position for future rounds."
#   ],
#   "donation": 0.1
# }
# 0.1

# %%
print(player1.wallet)
print(player2.wallet)
# Out:
# 9.0
# 12.0

# %% [markdown]
# ## Orchestrator

# %%
from typing import Tuple
from typing import List
import numpy as np
from concurrent.futures import ThreadPoolExecutor

import random

class Orchestrator:
  def __init__(self, game_state: GameState, save_path: Optional[str] = None):
    with tracer.start_as_current_span("init_orchestrator") as span:
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
      span.set_attribute(SpanAttributes.INPUT_VALUE, game_state.model_json_schema())
      self.game_state = game_state
      self.players = [Player(game_state=game_state, i=i) for i in range(game_state.players)]

      dir_path = f"g{game_state.generations}_r{game_state.rounds}_p{game_state.players}/"
      if not save_path:
        save_path = f"g{game_state.generations}_r{game_state.rounds}_p{game_state.players}.json"
      self.save_path = "data/" + dir_path + save_path
      
      self.history = {}

  def find_player(self, name: str) -> Player:
    for player in self.players:
      if player.name == name:
        return player
    raise ValueError(f"Player {name} not found")
  
  def create_donor_recipient_pairs(self) -> List[Tuple[Player, Player]]:
    """
    Builds a random pairing so that no player is matched with themselves.
    Not strictly uniform over all derangements, but typically good enough.
    """
    n = len(self.players)
    available = list(range(n))
    result = [None] * n
    
    for i in range(n):
      # Exclude i from the candidates
      candidates = [x for x in available if x != i]
      
      # If there is no candidate (happens if i is the only one left in available),
      # we need to 'repair' by swapping with a previously assigned position.
      if not candidates:
        # Swap with any earlier position that isn't i
        # Because it implies we must have assigned some position j = i earlier
        # and it's causing a corner case now.
        for j in range(i):
          if result[j] != j:
            old_assignee = result[j]
            result[j] = i
            result[i] = old_assignee
            break

      else:
        choice = random.choice(candidates)
        result[i] = choice
        available.remove(choice)
    
    # Now result[i] = index of the player who receives from i.
    # Convert that into (donor, recipient) pairs:
    return [(self.players[i], self.players[result[i]]) for i in range(n)]
    
  def play_round(self):
    with tracer.start_as_current_span("play_round") as span:
      span.set_attribute(SpanAttributes.INPUT_VALUE, self.game_state.model_dump_json())
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
      pairs = self.create_donor_recipient_pairs()
      span.set_attribute(SpanAttributes.OUTPUT_VALUE, json.dumps([f"{donor.name} -> {recipient.name}" for donor, recipient in pairs]))
      # TODO: can be parallelized but need to keep wallets static untill the end

      current_context = context_api.get_current()

      with ThreadPoolExecutor() as executor:
          futures = [
              executor.submit(donor.setup_donation, recipient, self.game_state, self.players, current_context)
              for donor, recipient in pairs
          ]
          # Wait for all donations to complete
          results = [future.result() for future in futures]

      for result in results:
        donor = self.find_player(result.donor_name)
        recipient = self.find_player(result.recipient_name)
        donor.execute_donation(recipient, self.game_state, result)
          
      self.game_state.round += 1

  def evolve(self):
    with tracer.start_as_current_span("evolve") as span:
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.AGENT.value)
      span.set_attribute(SpanAttributes.INPUT_VALUE, self.game_state.model_dump_json())
      self.game_state.round = 1
      self.game_state.generation += 1
      print(f"\n\nEvolving to generation {self.game_state.generation}")
      # sort players by wallet
      self.players = sorted(self.players, key=lambda x: x.wallet, reverse=True)
      # get top half
      top_half = self.players[:int(len(self.players)*self.game_state.cutoff_threshold)]
      # clone players
      top_players_strings = "\n".join([f"player {player.name} with wallet {player.wallet} and strategy: {player.strategy}" for player in top_half])
      print(f"\n\nTop half:\n{top_players_strings}")
      self.players = [Player(game_state=self.game_state, i=i, parents=top_half) for i in range(self.game_state.players)]

  def save_state(self):
    self.history[f"g{self.game_state.generation}"] = [player.model_dump() for player in self.players]
    os.makedirs(os.path.dirname(self.save_path), exist_ok=True)
    data = self.game_state.model_dump()
    data["history"] = self.history
    with open(self.save_path, "w") as f:
      json.dump(data, f)

  def run(self) -> List[Player]:
    for generation_count in range(self.game_state.generations):
      with tracer.start_as_current_span(f"generation_{generation_count}") as span:
        span.set_attribute(SpanAttributes.INPUT_VALUE, self.game_state.model_dump_json())
        span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
        print(f"\n\nGeneration {self.game_state.generation}")
        for round_count in range(self.game_state.rounds):
          with tracer.start_as_current_span(f"round_{round_count}") as span:
            span.set_attribute(SpanAttributes.INPUT_VALUE, self.game_state.model_dump_json())
            span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
            print(f"\n\n\tGeneration {self.game_state.generation} Round {self.game_state.round}")
            self.play_round()
            self.save_state()
        if self.game_state.generation < self.game_state.generations:
          self.evolve()

    return self.players

# %% [markdown]
# ## Run Orchestrator

# %%
from opentelemetry import trace

game_state = GameState(generation=0, round=0, generations=10, rounds=12, players=12, cutoff_threshold=0.5)
with tracer.start_as_current_span(f"donors_game-g{game_state.generations}_r{game_state.rounds}_p{game_state.players}") as span:
  try:
    # game_state = GameState(generation=1, round=1, generations=2, rounds=3, players=2, cutoff_threshold=0.5)
    span.set_attribute(SpanAttributes.INPUT_VALUE, game_state.model_dump_json())
    span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
    orchestrator = Orchestrator(game_state, save_path="game_state.json")
    final_players = orchestrator.run()
  except Exception as e:
    span.set_status(trace.Status(trace.StatusCode.ERROR))
    span.record_exception(e)

final_players = sorted(final_players, key=lambda x: x.wallet, reverse=True)
top_players_strings = "\n".join([f"player {player.name} with wallet {player.wallet} and strategy: {player.strategy}" for player in final_players])
print(f"\n\nFinal players: \n{top_players_strings}")
# Out:
# Invalid type dict for attribute 'input.value' value. Expected one of ['bool', 'str', 'bytes', 'int', 'float'] or a sequence of those types
# 0_0 strategy:
# {
#   "thoughts": [
#     "In the first round, I should donate a small amount since I have no information about the recipient's behavior.",
#     "In subsequent rounds, I will base my donation on the recipient's previous donation to their partner.",
#     "If I see a generous act from the recipient, I will respond by donating slightly more, to encourage continued generosity.",
#     "If the recipient was stingy, I will minimize my donation, as it suggests a lack of reciprocation."
#   ],
#   "strategy": "My strategy will be to start with a small donation in the first round, and adjust my contributions based on the recipient's past donation behavior in subsequent rounds."
# }
#
#
# 0_1 strategy:
# {
#   "thoughts": [
#     "In the first round, I should donate a small amount to encourage cooperation without risking too much of my resource.",
#     "As the rounds progress, I can adjust my donations based on the recipient's previous behavior to optimize my gain.",
#     "I will look for patterns in the recipient's donations to gauge their generosity or selfishness.",
#     "I want to ensure my donation benefits me in the long run while also fostering a cooperative environment."
#   ],
#   "strategy": "My strategy will be to start by donating 2 units in the first round and adjust my donations based on the recipient's previous behavior in subsequent rounds."
# }
#
#
# 0_2 strategy:
# {
#   "thoughts": [
#     "In the first round, donations should be cautious due to lack of information.",
#     "As rounds progress, I will base my donations on the recipient's previous donation behavior to their last partner.",
#     "If the recipient has donated a significant amount, I will reciprocate with a reasonable donation to encourage cooperation.",
#     "I will aim for a balance between generous donations to increase my units in subsequent rounds and not giving away too much too early."
#   ],
#   "strategy": "My strategy will be to donate 2 units in the first round and adapt my donations based on the recipient's previous donation behavior in subsequent rounds."
# }
#
#
# 0_3 strategy:
# {
#   "thoughts": [
#     "In the first round, I will start with a balanced donation since I have no information on others' behaviors.",
#     "If the recipient donated significantly in the previous round, I will donate less in this round to maximize my gain.",
#     "If the recipient did not donate much, I will encourage cooperation by donating a reasonable amount to build trust.",
#     "I will adjust my donation based on the information available after each round to maximize future gains."
#   ],
#   "strategy": "My strategy will be to donate a small percentage of my endowment in the first round and adjust based on the recipient's previous donation behavior in subsequent rounds."
# }
#
#
# 0_4 strategy:
# {
#   "thoughts": [
#     "In the first round, donate a moderate amount to establish a good reciprocal behavior.",
#     "In subsequent rounds, base my donation on the amount received by the recipient in the previous round.",
#     "If the recipient donated a significant amount last round, reward them with a higher donation.",
#     "If they did not donate much, either donate similar or slightly less to maintain a balance."
#   ],
#   "strategy": "My strategy will be to start with a 5-unit donation in the first round and adjust my donations based on the recipient's previous behavior to promote cooperation."
# }
#
#
# 0_5 strategy:
# {
#   "thoughts": [
#     "In the first round, there's no prior information about the recipient, so a moderate donation makes sense to gauge their reciprocity.",
#     "Pay attention to how much the recipient donated to their last partner; this helps inform trustworthiness.",
#     "Strive to balance between maximizing my own resources and demonstrating generosity, which can lead to a higher total in the long run.",
#     "Adjust donations in future rounds based on observed behavior; be cautious with untrustworthy recipients."
#   ],
#   "strategy": "My strategy will be to start with a moderate donation (3 units) in the first round, adjust my donation based on the recipient's previous round donation, and aim for reciprocity in subsequent rounds."
# }
#
#
# 0_6 strategy:
# {
#   "thoughts": [
#     "In the first round, I need to play conservatively since I have no information about the recipient's previous actions.",
#     "After round one, I will adjust my donations based on whether the recipient was generous or stingy in the previous round.",
#     "If the recipient gave a significant amount to their partner, I will match that generosity; if they were stingy, I will donate less.",
#     "Ultimately, my goal is to foster a cooperative dynamic while maximizing my own resource gain."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round, and then adjust my donations based on the recipient's previous behavior in each subsequent round."
# }
#
#
# 0_7 strategy:
# {
#   "thoughts": [
#     "In the first round, without any prior information, I will donate a small amount to build trust.",
#     "During subsequent rounds, I will adjust my donation based on the recipient's past behavior.",
#     "If the recipient donated significantly in their last interaction, I will match or slightly exceed that.",
#     "If the recipient gave little or nothing, I will reduce my donation accordingly to protect my resources."
#   ],
#   "strategy": "My strategy will be to start with a small donation in the first round and adjust my contributions based on the recipient's previous behavior."
# }
#
#
# 0_8 strategy:
# {
#   "thoughts": [
#     "Start with a baseline donation to build trust without risking too much.",
#     "Adjust donation amount based on the recipient's previous round behavior.",
#     "If the recipient donated in their last round, consider matching or slightly increasing your donation to encourage reciprocity.",
#     "If no donation was made by the recipient in their last interaction, donate minimally to protect my resources."
#   ],
#   "strategy": "My strategy will be to start by donating 3 units in the first round, then adjust based on the recipient's previous round actions, aiming to establish trust while safeguarding my units."
# }
#
#
# 0_9 strategy:
# {
#   "thoughts": [
#     "In the first round, I will contribute a small amount to encourage future cooperation without risking my total resources.",
#     "In subsequent rounds, I will adjust my donation based on the recipient's last action, promoting collaboration if they donated generously before.",
#     "If I notice a pattern of low donations from them, I will reduce my contribution to protect my resource base.",
#     "I aim for a balance between generosity and self-preservation to ensure I maximize my resources over time."
#   ],
#   "strategy": "My strategy will be to start with a small donation in the first round and adapt my future donations based on the recipient's previous contributions."
# }
#
#
# 0_10 strategy:
# {
#   "thoughts": [
#     "In the first round, I have no information, so I will start by donating a small amount to gauge the recipient's response.",
#     "As I gather information on the recipient's past donations, I will adjust my donations based on their willingness to contribute in the previous rounds.",
#     "If the recipient donated generously in the last round, I will reciprocate with a higher donation to build trust and potentially benefit from larger returns later.",
#     "If the recipient donated minimally or nothing, I will donate less to protect my resources for future rounds."
#   ],
#   "strategy": "My strategy will be to start with a small donation in the first round and adjust my donations based on the recipient's past behavior in subsequent rounds."
# }
#
#
# 0_11 strategy:
# {
#   "thoughts": [
#     "In the first round, since I have no information, I will donate a small amount to test the waters.",
#     "If I see that the recipient (A) donated a substantial amount in their last round, I will reward that generosity in the next round.",
#     "If A donated little or nothing, I will reduce my donations in the following rounds to protect my resources.",
#     "Overall, I will adjust my donations according to the recipient's generosity to foster collaborative or reduce exploitative interactions."
#   ],
#   "strategy": "My strategy will be to start by donating 2 units in the first round, and adjust based on the recipient's previous donation behavior."
# }
#
#
# Generation 0
#
#
# 	Generation 0 Round 0
#
#
# 0_0 donation:
# {
#   "thoughts": [
#     "Since this is the first round and I want to start with a small donation, I will not give away too much resources to maintain a good balance for future rounds.",
#     "I will consider a donation that is significant enough to encourage a good response in future rounds but small enough to not hurt my initial resources too much.",
#     "A donation of 1 unit equates to 10% of my resources, which will allow the recipient to receive 2 units in return."
#   ],
#   "donation": 0.1
# }
#
#
# 0_4 donation:
# {
#   "thoughts": [
#     "I will start with my initial strategy of donating 5 units in this first round to show a willingness to cooperate. This should ideally encourage 0_11 to reciprocate in future rounds since they will gain a significant benefit from my donation."
#   ],
#   "donation": 0.5
# }
#
#
# 0_3 donation:
# {
#   "thoughts": [
#     "Since I am starting the game, I want to establish a cooperative strategy with 0_4 without risking too much of my resource right away.",
#     "I aim to donate a small percentage of my total endowment to encourage 0_4 to reciprocate in future rounds.",
#     "A donation of 10% of my endowment seems reasonable as it allows me to retain a significant amount while also providing some benefit to 0_4."
#   ],
#   "donation": 0.1
# }
#
#
# 0_2 donation:
# {
#   "thoughts": [
#     "I am the donor and I initially planned to donate 2 units based on my strategy.",
#     "Since 0_10 has 10 units, they have the full amount they started with.",
#     "I will stick to my original plan and donate 2 units to ensure I contribute substantively while still maintaining some resources for myself."
#   ],
#   "donation": 0.2
# }
#
#
# 0_6 donation:
# {
#   "thoughts": [
#     "I decided to donate 1 unit in the first round as per my strategy.",
#     "0_1 currently has 10 units, and I want to establish a positive relationship by donating.",
#     "Since it’s round 0, I haven’t observed 0_1's past donation behavior, so I will stick to my initial plan."
#   ],
#   "donation": 0.1
# }
#
#
# 0_10 donation:
# {
#   "thoughts": [
#     "This is the first round, so I should start with a small donation to test the waters.",
#     "Since I have no data on 0_8's past behavior, I will keep my donation limited but still significant enough to encourage cooperation in the future.",
#     "I will decide to donate a modest 10% of my total units."
#   ],
#   "donation": 0.1
# }
#
#
# 0_7 donation:
# {
#   "thoughts": [
#     "I will start with a small donation to establish goodwill and gauge the response from 0_3.",
#     "Since I currently have 10 units, a donation of 1 unit is reasonable, allowing both parties to benefit while still keeping a majority of my resources.",
#     "This initial action will provide insight into 0_3's behavior in the next round when I will be the recipient."
#   ],
#   "donation": 0.1
# }
#
#
# 0_1 donation:
# {
#   "thoughts": [
#     "I will start by donating 2 units, as I previously decided to begin with this amount before adjusting based on others' behavior. This approach allows me to contribute positively while keeping a significant portion of my resources for the next rounds.",
#     "Since it's the first round and I don't have information about 0_5's previous behaviors, starting with a moderate donation seems reasonable."
#   ],
#   "donation": 0.2
# }
#
#
# 0_8 donation:
# {
#   "thoughts": [
#     "I want to start by donating 3 units as per my strategy.",
#     "This amount is significant enough to potentially build trust with 0_6.",
#     "Since they have a full 10 units, donating 3 will allow them to gain 6 units and me to retain 7 units, which is still a strong position."
#   ],
#   "donation": 0.3
# }
#
#
# 0_5 donation:
# {
#   "thoughts": [
#     "I will start with my planned moderate donation of 3 units since it is the first round. This will show goodwill and set a positive precedent for reciprocity in future rounds. I want to ensure that the recipient, 0_0, gains a significant benefit from my donation, which could encourage them to be generous when our roles reverse.",
#     "By donating 3 units, I will still retain a good amount of resources (7 units) for myself to use in future rounds. This allows me to balance my own resource management with contributing positively to 0_0's experience."
#   ],
#   "donation": 0.3
# }
#
#
# 0_11 donation:
# {
#   "thoughts": [
#     "I need to donate a predetermined amount of 2 units as stated in my strategy for the first round.",
#     "I have a total of 10 units, so donating 2 units leaves me with 8 units.",
#     "By donating 2 units, 0_9 will receive 4 units (2x donation), which may encourage them to donate more in future rounds.",
#     "This donation will also allow me to gauge their response in subsequent rounds."
#   ],
#   "donation": 0.2
# }
#
#
# 0_9 donation:
# {
#   "thoughts": [
#     "Since this is the first round, I want to start with a small donation to test the waters with my partner 0_7.",
#     "I currently have 10 units, and I want to ensure that my donation is enough to encourage reciprocity in the next round while still keeping a portion for myself.",
#     "I will donate 10% of my total units, which is 1 unit. This is a conservative approach and allows my partner to benefit without risking too much of my resource."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 0 Round 1
#
#
# 0_9 donation:
# {
#   "thoughts": [
#     "Since I'm starting with a small donation, I want to give a modest amount to establish a collaborative dynamic with 0_8.",
#     "I currently have 13.0 units and they have 9.0 units, so I don't want to give too much and disadvantage myself in the long run.",
#     "I will choose to donate 10% of my resources, which is 1.3 units. This way, they will receive 2.6 units, and I still retain a significant portion of my resources."
#   ],
#   "donation": 0.1
# }
#
#
# 0_2 donation:
# {
#   "thoughts": [
#     "I am in round 1 and applying my initial strategy of donating 2 units.",
#     "The recipient 0_4 has 7 units, and since I need to adapt, I should start with my planned donation amount.",
#     "Donating 2 units makes sense as it aligns with my strategy and allows me to see the recipient's response without losing too much."
#   ],
#   "donation": 0.2
# }
#
#
# 0_3 donation:
# {
#   "thoughts": [
#     "I have 11.0 units and want to keep a good balance between helping my partner and maximizing my future gains.",
#     "Since it's the first round, I should start with a small donation to see how 0_1 will respond in the future rounds.",
#     "A donation of around 10% seems reasonable, as it allows me to test the waters without risking too much of my resource."
#   ],
#   "donation": 0.1
# }
#
#
# 0_4 donation:
# {
#   "thoughts": [
#     "Starting with my strategy of a 5-unit donation to promote cooperation.",
#     "Since I currently have 7.0 units, I can afford to donate 5 units while still retaining resources for the next round.",
#     "The recipient, 0_3, has 11.0 units, indicating they may have a higher endowment than me, but they might appreciate the donation for future cooperation."
#   ],
#   "donation": 0.7142857142857143
# }
#
#
# 0_10 donation:
# {
#   "thoughts": [
#     "Starting with a small donation allows me to observe how 0_0 reacts to receiving resources.",
#     "Since I have more units than the recipient, I can afford to donate a little without significantly harming my own position.",
#     "I will make a conservative donation to establish a good precedent for future rounds without risking too much at this early stage."
#   ],
#   "donation": 0.1
# }
#
#
# 0_6 donation:
# {
#   "thoughts": [
#     "I have decided to donate 1 unit in the first round as per my strategy.",
#     "Given that I have 15.0 units and 0_2 has 10.0 units, I can afford to donate without risking too much of my own resource.",
#     "Donating 1 unit will allow the recipient to receive 2 units, benefiting both of us in this round."
#   ],
#   "donation": 0.06666666666666667
# }
#
#
# 0_1 donation:
# {
#   "thoughts": [
#     "I want to start by donating according to my initial strategy, which is to give 2 units.",
#     "As I'm the donor this round, I will give 2 units from my current 10 units.",
#     "This should allow the recipient to gain a total of 4 units (2 units from me is doubled), which supports a cooperative behavior.",
#     "Since my aim is to balance my resource for future rounds, giving 2 units aligns with my strategy without severely depleting my resources."
#   ],
#   "donation": 0.2
# }
#
#
# 0_8 donation:
# {
#   "thoughts": [
#     "I have 9 units and my strategy is to donate 3 units to establish trust.",
#     "0_5 has more resources (11 units) than I do, which might indicate they are willing to give back in the future.",
#     "Since I want to ensure I get some positive results in future rounds based on trust, I'll stick to my initial plan of donating 3 units."
#   ],
#   "donation": 0.3333333333333333
# }
#
#
# 0_7 donation:
# {
#   "thoughts": [
#     "I should start with a small donation since it's the first round and I don't have previous information on 0_6's behavior.",
#     "Given that I have 11.0 units and they have 15.0, I might choose to donate a small percentage of my resources, as I want to encourage cooperation without giving up too much too soon.",
#     "Since I need to show some level of generosity, I'll opt for a modest donation that allows me to test how 0_6 reacts in future rounds."
#   ],
#   "donation": 0.1
# }
#
#
# 0_5 donation:
# {
#   "thoughts": [
#     "I have 11.0 units available and I initially planned to donate 3 units to establish a cooperative approach with my partner.",
#     "0_11 currently has 18.0 units, indicating they may be more willing or able to reciprocate a donation as they are relatively better off.",
#     "By donating 3 units, I can contribute to 0_11's resources while still retaining enough units to benefit in future rounds.",
#     "My goal is to encourage a pattern of giving and reciprocity, so I will stick to my plan and donate 3 units."
#   ],
#   "donation": 0.2727272727272727
# }
#
#
# 0_11 donation:
# {
#   "thoughts": [
#     "Since I have a higher number of units compared to my partner (0_9 has 13.0 and I have 18.0), I can afford to donate some units without putting myself at a severe disadvantage.",
#     "My initial strategy is to donate 2 units in the first round. This amount is enough to help my partner and potentially influence them positively for future rounds while still leaving me with a solid amount of resources to work with after the donation.",
#     "By donating 2 units, I will have 16 units left and my partner will receive 4 units (2 times the amount donated). This could increase my chances of receiving a better donation in the next round.",
#     "I plan to stick to my initial strategy and donate 2 units."
#   ],
#   "donation": 0.1111111111111111
# }
#
#
# 0_0 donation:
# {
#   "thoughts": [
#     "I have a slightly higher amount of resources compared to my partner 0_7, who has 11.0 units. As a donor, I want to maintain a competitive edge while also encouraging potential future cooperation. Starting with a small donation can also help gauge 0_7's response in the next round.",
#     "Considering my goal to maximize my units in the long run, I should balance giving enough to be beneficial for the other player without giving away too much. A donation that is not too large will still benefit 0_7 while keeping me in a stronger position overall."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 0 Round 2
#
#
# 0_0 donation:
# {
#   "thoughts": [
#     "In round 1, 0_7 donated only 0.1%, which suggests they are cautious or not fully committed to the donation strategy.",
#     "Given that they currently have 12.9 units, their past behavior implies they might not reciprocate significantly if I donate too much.",
#     "I want to keep the donation low to avoid losing too many resources while still contributing enough to encourage a positive interaction.",
#     "Therefore, I will donate a small amount, slightly higher than their last donation to demonstrate a willingness to cooperate."
#   ],
#   "donation": 0.05
# }
#
#
# 0_4 donation:
# {
#   "thoughts": [
#     "0_10 donated a very small amount (0.1%) in the previous round, indicating they may not be very cooperative or generous.",
#     "Since I have only 6.0 units and want to encourage cooperation, I need to balance my donation to avoid giving too much away while still being generous enough to promote future cooperation.",
#     "Based on their current number of units (15.7), I should probably make a moderate donation to encourage a larger response in the future, as I want to build trust despite their meager past donation."
#   ],
#   "donation": 0.5
# }
#
#
# 0_7 donation:
# {
#   "thoughts": [
#     "0_2 donated 0.2% in the previous round, which indicates they may be cautious in their giving.",
#     "I have a lead with my current 12.9 units, so I should balance generosity with maintaining a good resource base.",
#     "I'll start with a small donation to encourage reciprocity while testing 0_2's willingness to give more in the next round."
#   ],
#   "donation": 0.05
# }
#
#
# 0_10 donation:
# {
#   "thoughts": [
#     "Since I have more resources than 0_8, I want to establish a cooperation behavior by making a donation.",
#     "0_8 donated a small amount (0.33%) in the previous round, which suggests they are willing to engage in mutual donation but may not donate a large amount themselves.",
#     "I want to donate enough to encourage 0_8 to also donate in the following round, but not so much that I put myself at a significant disadvantage.",
#     "I will donate a small percentage to follow my strategy of starting small and observing their behavior.",
#     "I will donate approximately 2% of my current resources."
#   ],
#   "donation": 0.02
# }
#
#
# 0_3 donation:
# {
#   "thoughts": [
#     "0_4 has a relatively low resource count of 6.0 units, which suggests they may need help to recover.",
#     "Since 0_4 donated a significant percentage in the previous round, they might be more inclined to reciprocate in this round.",
#     "Given I have 19.9 units, I can afford to donate a small percentage to encourage future cooperation.",
#     "I will donate a small percentage that is enough to help 0_4 but still retains a large amount of my resources."
#   ],
#   "donation": 0.1
# }
#
#
# 0_2 donation:
# {
#   "thoughts": [
#     "0_9 has significantly more units (15.7) compared to my 10.0, indicating they may not be in need of resources.",
#     "In round 1, 0_9 only donated 0.1% of their resources, which is a negligible amount. This suggests they may not value donation highly, potentially indicating a more selfish strategy.",
#     "Given their low donation amount in the last round, I will remain modest in my donation to avoid losing too many units myself.",
#     "I will donate 2 units as I originally planned, as it is a fair amount that may encourage reciprocation or at least not discourage future generous behavior."
#   ],
#   "donation": 0.2
# }
#
#
# 0_5 donation:
# {
#   "thoughts": [
#     "0_11 has a higher resource count (22 units) than I do (14 units). Given that they only donated a small percentage in the previous round, I should consider that they might be looking to maximize their own resources.",
#     "Since I have a moderate amount of resources, I want to establish a sense of reciprocity but also keep some for myself. A minimal donation may not hurt my position, especially if I aim to return the favor in the next round.",
#     "Donating too much may leave me vulnerable in future rounds, but a small donation could be seen as a positive gesture to encourage reciprocity."
#   ],
#   "donation": 0.2142857142857143
# }
#
#
# 0_11 donation:
# {
#   "thoughts": [
#     "0_1 donated a very tiny amount (0.2% of their resources) in the previous round, which indicates they may not be very generous or expect high returns from donations.",
#     "Since I have a significant amount of resources (22.0 units) and I am aiming to build goodwill for the next round when I will be a recipient, I should increase my donation slightly while still ensuring I keep enough resources for myself.",
#     "Given that 0_1 has a little over 10 units now, they might appreciate a better offer, so I would like to donate more than what they previously gave but not too much to jeopardize my own stock.",
#     "I will donate 2 units again, as it will help maintain my strategy of generosity while allowing me to still retain a healthy balance."
#   ],
#   "donation": 0.09090909090909091
# }
#
#
# 0_8 donation:
# {
#   "thoughts": [
#     "0_6 currently has significantly more units (16.2) than I do (8.6).",
#     "In round 1, 0_6 donated a very small percentage (0.0666%) of their resources, which suggests they may not be very generous or they are trying to save for themselves.",
#     "Since I want to establish trust but also protect my own resources, I should decide on a donation that is meaningful yet keeps a substantial amount for myself.",
#     "Given 0_6's low donation, it may be wise to donate a bit more than they did as a gesture, but not too much since I need to keep enough to carry into the next rounds."
#   ],
#   "donation": 2.5
# }
#
#
# 0_6 donation:
# {
#   "thoughts": [
#     "I donated 1 unit in the first round, which was a direct and modest approach to encourage a cooperative spirit. In round 2, I'm the donor, and my paired recipient 0_0 has a substantial amount of resources (16.1 units).",
#     "0_0 donated only a tiny fraction (0.1%) in round 1, which suggests they may not prioritize reciprocity or generous contributions. Therefore, I should consider a cautious approach with my donation.",
#     "To promote cooperation but also protect my own resource count, I will donate less than my initial round but enough to demonstrate goodwill. I need to choose a donation that can still grant 0_0 a benefit while safeguarding my own resources."
#   ],
#   "donation": 0.05
# }
#
#
# 0_9 donation:
# {
#   "thoughts": [
#     "I have 15.7 units, and I need to decide how much to donate.",
#     "0_3 has a larger resource pool (19.9 units) and donated only a tiny percentage (0.1%) in their previous round, indicating a low willingness to share.",
#     "To encourage 0_3 to cooperate in future rounds, I want to contribute a donation that is noticeable but not excessive, as I also need to maximize my own units after this round.",
#     "Given that 0_3 is somewhat stingy in their donations, I will offer a small donation that shows I'm willing to cooperate, yet keeps a significant amount for myself."
#   ],
#   "donation": 0.1
# }
#
#
# 0_1 donation:
# {
#   "thoughts": [
#     "In round 1, 0_5 donated a small amount of their resources, indicating they are willing to cooperate but may not give much back in return.",
#     "Since I have a relatively higher amount of resources (10.2) compared to 0_5 (14), I want to encourage them to also donate back by showing generosity.",
#     "I will donate a modest amount but not too high, keeping in mind to maximize my gains in future rounds.",
#     "Based on my initial strategy of starting with a donation of 2 units, I will adjust that slightly to maintain balance."
#   ],
#   "donation": 0.2
# }
#
#
# 	Generation 0 Round 3
#
#
# 0_8 donation:
# {
#   "thoughts": [
#     "In round 1, my strategy was to donate 3 units but I currently have 0.628 units, so I cannot donate that amount.",
#     "Looking at 0_5, they have a significant amount of resources, suggesting they might reciprocate if I donate something.",
#     "Since I have only 0.628 units, I must donate all that I have to establish trust as per my strategy of donation to foster future cooperation."
#   ],
#   "donation": 1.0
# }
#
#
# 0_5 donation:
# {
#   "thoughts": [
#     "In round 2, 0_6 showed minimal altruism by donating only 0.05% of their resources, which is quite low given they have 32.59 units, suggesting they may not be inclined to share a lot.",
#     "Since I am trying to build reciprocity, I will not over-donate this round as their past donation suggests they may not respond positively to a large gift.",
#     "I have 15.08 units and will consider a moderate donation that allows me to maintain a healthy amount for future rounds, while encouraging 0_6 to donate more in future interactions."
#   ],
#   "donation": 0.2
# }
#
#
# 0_0 donation:
# {
#   "thoughts": [
#     "I have 16.915 units, and my goal is to maintain a balance between donating and retaining enough resources for future rounds.",
#     "0_11 has 26 units, which suggests they have been benefiting from their peers, indicating they may expect higher donations from me.",
#     "I noticed that in the previous rounds, 0_11 did not seem to donate much; therefore, I might consider a lower donation to gauge their response and set a precedent for mutual giving.",
#     "I will start with a small donation, around 5% of my resources, as this will allow me to contribute without significantly depleting my own holdings."
#   ],
#   "donation": 0.05
# }
#
#
# 0_2 donation:
# {
#   "thoughts": [
#     "0_4 has made a minimal donation of 0.5% in the last round, which indicates a low trust or willingness to give up resources.",
#     "Since I want to build trust and balance my resources, I should consider a small but significant donation.",
#     "I will donate 1 unit (approximately 10.76% of my current resources), which is more than 0.5%, showing a willingness to cooperate and hoping 0_4 will reciprocate in the next round."
#   ],
#   "donation": 0.1076
# }
#
#
# 0_9 donation:
# {
#   "thoughts": [
#     "0_2 has a relatively low donation percentage so far, which suggests they may not be very altruistic.",
#     "I will aim to give a small percentage to see if 0_2 reciprocates in the next round, allowing me to benefit more in future interactions.",
#     "Given that I have a strong resource position, I can afford to make a minimal donation without sacrificing too much.",
#     "A donation of around 5% should be a good starting point, allowing me to be generous while still maintaining a solid amount of resources."
#   ],
#   "donation": 0.05
# }
#
#
# 0_4 donation:
# {
#   "thoughts": [
#     "Looking at 0_1's previous donations, they donated very little (only 0.2% of their resources). This suggests that they may not be very cooperative or generous.",
#     "Since I have less resource value compared to 0_1, I need to strike a balance between donation and maintaining my units for future rounds.",
#     "I initially wanted to encourage cooperation, but given their past behavior, I should not donate too much.",
#     "I will donate a small percentage that could still benefit me if they reciprocate well in the next rounds."
#   ],
#   "donation": 0.1
# }
#
#
# 0_6 donation:
# {
#   "thoughts": [
#     "0_9 currently has 18.13 units, which is significantly less than my 32.59 units, indicating they might be in need of support.",
#     "In round 2, 0_9 donated a minimal amount (0.1%), suggesting they may not be inclined to give much in return.",
#     "Since they received only a small donation in round 1, they might not feel incentivized to reciprocate highly in this round.",
#     "Based on this information, I should consider donating an amount that balances between being generous but also preserves my units for future rounds."
#   ],
#   "donation": 0.05
# }
#
#
# 0_7 donation:
# {
#   "thoughts": [
#     "0_0 has a higher amount of resources (16.915 units) compared to my resources (13.865 units).",
#     "In the previous rounds, 0_0 donated a very small amount (0.05%), indicating a low level of generosity.",
#     "Since 0_0 seems to have a conservative approach to donating, I should also be careful not to give away too much of my resources, as they may not reciprocate well in the next round.",
#     "To maintain my position and increase my resources, I should make a small donation while still keeping most of my resources for future rounds."
#   ],
#   "donation": 0.02
# }
#
#
# 0_1 donation:
# {
#   "thoughts": [
#     "In the previous rounds, 0_3 donated a very small percentage (0.1%) of their resources to their partner in round 2, which indicates a possible tendency to donate minimally or keep most of their resources.",
#     "Given that 0_3 currently has a significant amount of resources (21.05 units), they likely expect partners to donate more than they did in the previous rounds.",
#     "Since I have a reasonable amount of units (12.16) and am looking to establish a good rapport, I will start with a moderate donation to gauge their response and potentially encourage them to donate more in future interactions.",
#     "I will choose to donate 2 units, which is not too aggressive but shows willingness to contribute."
#   ],
#   "donation": 0.1646807966431924
# }
#
#
# 0_10 donation:
# {
#   "thoughts": [
#     "In round 2, 0_7 donated a very small amount (0.05%) which indicates they are likely to be cautious and not very generous. Therefore, I should consider giving a slightly larger donation to incentivize them as a recipient.",
#     "Given that I have more units (21.386) than 0_7, I can afford to give a moderate amount while still maintaining a significant portion of my resources.",
#     "I want to balance my donation to encourage cooperation in future rounds but also keep enough units to ensure my own survival and growth. I'll aim for a donation that is noticeable enough to encourage 0_7 to reciprocate positively in the next round."
#   ],
#   "donation": 0.2
# }
#
#
# 0_11 donation:
# {
#   "thoughts": [
#     "In round 1, the previous recipient donated only a tiny percentage (0.3333%) of their resources, showing a lack of willingness to share.",
#     "In round 2, 0_10 donated even less (0.02%), indicating that they are likely not generous.",
#     "My goal is to maximize my resources while also trying to instill some form of reciprocity or encourage them to give in the future if we switch roles.",
#     "Given that previous donations from my opponent have been very small, I should decide on a donation that balances risk and my goal.",
#     "I will donate more than they have in the past to signal that I am willing to share, while keeping in mind not to give away too many units, since I should still retain a good amount for myself."
#   ],
#   "donation": 0.1
# }
#
#
# 0_3 donation:
# {
#   "thoughts": [
#     "Since I have a higher amount of resources (21.05 units) compared to 0_8 (0.628 units), this gives me an advantage in the donation scenario.",
#     "0_8 had a relatively small donation of only 2.5% in the last round. This suggests they are cautious in their donations and may expect reciprocal generosity.",
#     "To maximize my units while still contributing positively, I will donate a small percentage that is enough to maintain goodwill without significantly harming my own resource pool.",
#     "I will choose to donate a small percentage of my current resources, say around 10%, which will still leave me with a substantial amount."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 0 Round 4
#
#
# 0_5 donation:
# {
#   "thoughts": [
#     "0_11 currently has a significant amount of units (25.0915), which indicates they may be capable of generosity in future rounds.",
#     "In previous rounds, 0_11 has demonstrated minimal donations (only 0.1% of their resources), suggesting they might not reciprocate well even if I donate now.",
#     "Given my strategy aims for reciprocity, I will choose a moderate donation that won't harm my position but may entice further cooperation from 0_11 in subsequent rounds. My earlier donation was 3 units, so I will slightly decrease my donation based on 0_11's low previous donations."
#   ],
#   "donation": 0.15
# }
#
#
# 0_6 donation:
# {
#   "thoughts": [
#     "0_0 currently has 16.62385 units, indicating they have been somewhat generous as they have more resources than my starting point.",
#     "In previous rounds, 0_0 donated only a small percentage (0.05%), showing a tendency to keep most of their resources.",
#     "Since I'm adapting my strategy based on their previous behavior, I will make a smaller donation that reflects their low donation tendency.",
#     "A donation of 1 unit might encourage future reciprocation without risking too much of my own resources, as the benefit lies in maintaining a steady resource growth."
#   ],
#   "donation": 0.027
# }
#
#
# 0_9 donation:
# {
#   "thoughts": [
#     "0_5 has received very low donations from their previous partners, which indicates they are not aggressive donors.",
#     "Given that I have a substantial amount of resources (20.48 units), I can afford to make a small yet impactful donation to encourage generosity in the next round.",
#     "I want to align my donation strategy with their previous behavior and start with a modest donation to test the waters.",
#     "Since 0_5 currently has 13.32 units, a small percentage that does not heavily impact my outcome but shows willingness to help others could foster a better exchange in the future."
#   ],
#   "donation": 0.05
# }
#
#
# 0_3 donation:
# {
#   "thoughts": [
#     "I have 22.95 units, and my goal is to make a strategic donation based on the recipient's previous donation behavior.",
#     "0_9 has only donated a small percentage (0.1% and 0.05%) in earlier rounds, indicating a conservative approach.",
#     "Since I have a larger endowment than 0_9, I can afford to donate a small amount to encourage future cooperation and maximize my own units in subsequent rounds.",
#     "I will donate a slightly higher percentage than what 0_9 has donated previously, which shows I am willing to cooperate more than they have while still minimizing my own loss."
#   ],
#   "donation": 0.1
# }
#
#
# 0_0 donation:
# {
#   "thoughts": [
#     "Since I'm in round 4 and I have more units compared to 0_1, I can afford to donate a small but meaningful amount.",
#     "0_1 previously donated around 0.1647% of their units, indicating they are willing to donate, but it's still small.",
#     "I've been increasing my units while 0_1's donations demonstrate they may not be very generous, so I want to encourage a positive exchange without giving away too much.",
#     "Given my current amount and their past behavior, I will donate a small percentage to maintain a balance and encourage future cooperation."
#   ],
#   "donation": 0.05
# }
#
#
# 0_2 donation:
# {
#   "thoughts": [
#     "In round 3, 0_4 donated a very small amount (0.1% of their resources), indicating they might not be inclined to give generously.",
#     "Because 0_4 didn't donate much in the last round, it seems they may not be a very cooperative recipient.",
#     "With my strategy, I started by donating 2 units initially, but since I'm seeing less generosity from the recipient, I should consider a conservative approach this time."
#   ],
#   "donation": 0.2
# }
#
#
# 0_1 donation:
# {
#   "thoughts": [
#     "I will start by donating 2 units as per my strategy, which is based on the initial plan to give away a fixed amount in the first round and adjust later based on the recipient's interactions.",
#     "0_8 has a low amount of resource (4.21 units), so my donation could help maximize their resources, encouraging a cooperative dynamic.",
#     "Since I'm in round 4 and have more units than 0_8, a larger donation can also potentially influence how they will act in future rounds, steering them towards cooperation."
#   ],
#   "donation": 0.17305275957679436
# }
#
#
# 0_7 donation:
# {
#   "thoughts": [
#     "I observe that my partner, 0_3, has a significant amount of resources (22.95 units) compared to my own (22.14 units).",
#     "In the previous rounds, 0_3 donated a very small amount (0.1% of their resources). Given their conservative donation behavior, I should also start with a small donation to observe their response in the next round.",
#     "Since starting small is advised, I will donate a minimal amount to ensure that I still retain a majority of my resources."
#   ],
#   "donation": 0.05
# }
#
#
# 0_8 donation:
# {
#   "thoughts": [
#     "Having 4.21 units, I need to decide on a donation that establishes trust.",
#     "0_6 has more resources, indicating they may be willing to reciprocate if I donate a reasonable amount.",
#     "Since 0_6 has only donated a small fraction of their resources in previous rounds, I want to give a bit more than that to encourage a stronger response in the next round.",
#     "I will donate 1 unit this round, which is roughly 24% of my current endowment. This should be a decent amount to foster trust without completely depleting my resources."
#   ],
#   "donation": 0.24
# }
#
#
# 0_4 donation:
# {
#   "thoughts": [
#     "Considering my previous strategy of starting with a 5-unit donation, I have to adjust based on the behavior of 0_10.",
#     "0_10 has a relatively high amount of resources, but their past donations have been very minimal (0.2% and 0.05%).",
#     "To encourage cooperation, I should still donate but will need to be cautious with how much I give since 0_10's history suggests they may not reciprocate generously. ",
#     "I will consider a moderate amount that shows willingness to give but does not leave me too vulnerable. Donation should encourage them to give more next round."
#   ],
#   "donation": 0.2
# }
#
#
# 0_11 donation:
# {
#   "thoughts": [
#     "In the previous rounds, 0_7 has shown a tendency to give very little, donating 0.1% and receiving 0.05% from another player. This suggests they may not be very generous unless incentivized. Since I currently have more units than them, I want to dictate a favorable exchange in hopes of maximizing my future gains.",
#     "Based on that, starting with a modest donation should be sufficient to encourage a reciprocal behavior without giving away too much of my resources. I will lean on my strategy by donating a bit more than what they have previously given to others, so they see the potential benefits of giving back more in the following rounds. I will consider a donation of 1 unit, which is a small but significant contribution. This exceeds 0.1% of their total but doesn't overly diminish my resource base."
#   ],
#   "donation": 0.0399
# }
#
#
# 0_10 donation:
# {
#   "thoughts": [
#     "I see that 0_2 has donated 0.1076% of their resources in the previous round, indicating they are somewhat cooperative, but only moderately so. Therefore, I want to respond in kind without giving away too much.",
#     "I have a total of 22.3088 units, and 0_2 has 10.103396 units. If I donate too much, I risk losing my advantage in future rounds, so I should keep my donation small but meaningful.",
#     "Donating slightly more than 0_2's last donation would encourage them to donate more to me in the next round. Since 0_2 donated about 0.011 units (0.1076% of their current resources), I can round my donation to about 0.015 units to show cooperation."
#   ],
#   "donation": 0.00067179
# }
#
#
# 	Generation 0 Round 5
#
#
# 0_3 donation:
# {
#   "thoughts": [
#     "0_9 has been donating very small amounts in previous rounds, showing a tendency to give minimally.",
#     "Given their previous low donation behavior, I will follow my strategy of donating a small percentage this round.",
#     "Since 0_9 has a larger amount of resources, a small donation from me could still yield them a decent amount while keeping a substantial amount for myself."
#   ],
#   "donation": 0.01
# }
#
#
# 0_5 donation:
# {
#   "thoughts": [
#     "0_2 has an initial endowment of 10 units and currently has 8.112690457504 units, suggesting a conservative approach to donations.",
#     "In previous rounds, 0_2 donated only minimal amounts (0.2% previously), indicating they may not prioritize generosity. I should consider their low donations when deciding my own.",
#     "Since I currently have 13.370249999999999 units and can afford to donate without severely hurting my own resources, I will adhere to my strategy of a moderate donation, but slightly lower to align with their past behavior.",
#     "I will donate 1 unit, which is approximately 7.47% of my resources (1/13.37), aiming to encourage some reciprocity without feeling taken advantage of."
#   ],
#   "donation": 0.0747
# }
#
#
# 0_6 donation:
# {
#   "thoughts": [
#     "In previous rounds, 0_3 has shown to be a minimal donor, contributing only 0.1% of their resources. This suggests they may not reciprocate generosity. Therefore, I should consider a conservative strategy for my donation.",
#     "I want to ensure I remain competitive, so I need to balance my donation with the potential risk of 0_3 not giving back in the next round.",
#     "Given I have 38.0145025 units, I could aim for a small donation that reflects their previous behavior. A donation of 1 unit is reasonable, as it allows me to give something without overly compromising my own resources."
#   ],
#   "donation": 0.0262839523
# }
#
#
# 0_4 donation:
# {
#   "thoughts": [
#     "I should consider that 0_5 has a higher amount of resources than me, suggesting they may be a more selfish player, as they haven't donated much in previous rounds.",
#     "In their last donation, they gave only a tiny fraction (0.15%) of their resources, showing limited generosity.",
#     "To encourage any potential cooperation and to foster a better outcome for myself in future rounds, I should still offer a donation, but it can be modest due to their previous behavior.",
#     "I will therefore donate a small percentage to show willingness to cooperate while minimizing risk on my part."
#   ],
#   "donation": 0.1
# }
#
#
# 0_11 donation:
# {
#   "thoughts": [
#     "I will start by donating 2 units as per my strategy.",
#     "0_7 has a significantly higher amount of resources than I do, indicating that they may be less likely to donate generously based on their previous donation behaviors.",
#     "Given that 0_7 donated only 0.05% of their resources in the last round, it's likely they do not intend to give much back.",
#     "To incentivize a potential larger donation from 0_7 in the next round, I will make a slightly larger donation than my usual 2 units, while still keeping enough for myself."
#   ],
#   "donation": 0.1
# }
#
#
# 0_9 donation:
# {
#   "thoughts": [
#     "0_1 has 11.2165 units, which shows they have been somewhat generous in the previous rounds, indicating they might reciprocate my donation.",
#     "As a donor, I want to balance between a strategic donation that encourages 0_1 to donate back and ensuring I retain enough units for future rounds.",
#     "Given that 0_1 donated a small percentage previously, I will start with a similar small percentage to test their cooperation.",
#     "I decide to donate around 1% of my total units, which is a reasonable amount to give while still keeping sufficient units."
#   ],
#   "donation": 0.01
# }
#
#
# 0_8 donation:
# {
#   "thoughts": [
#     "0_11 has significantly more resources, which might indicate a cautious or non-generous approach. However, their previous donation is relatively small, suggesting they might not be following a highly cooperative strategy.",
#     "Given I currently have only 7.1983 units, I need to balance establishing trust while preserving enough resources for myself. Since I started with a donation of 3 units, I should scale it back now due to the prior performance of my partners.",
#     "I will donate around 1 unit, as this shows willingness to cooperate while keeping a majority of my resources."
#   ],
#   "donation": 0.13835615430118983
# }
#
#
# 0_7 donation:
# {
#   "thoughts": [
#     "0_6 has a relatively high amount of resources, indicating they might be willing to reciprocate if I donate a reasonable amount.",
#     "In previous rounds, 0_6 donated a small percentage (0.027%), which suggests they might be cautious with their donations.",
#     "I want to start with a small donation that is more than their previous contribution, to incentivize a positive response without jeopardizing my own resources too much.",
#     "I will calculate a donation that is reasonable but also strong enough to prompt a good response. Given they donated 0.027% with 38.0145025 units, I’ll donate slightly more but still keep a good portion of my resources."
#   ],
#   "donation": 0.08
# }
#
#
# 0_1 donation:
# {
#   "thoughts": [
# ...
#     "9_1 previously donated only a small percentage of their resources (0.5%), suggesting they may not be very generous.",
#     "To encourage 9_1 to donate more when they are the donor in the next round, I may want to give a reasonable amount to maintain a balance, demonstrating cooperation.",
#     "Considering I have 49.808052 units, a safe donation that shows goodwill without overly sacrificing my own resources may be around 1 unit, which is similar to my initial strategy."
#   ],
#   "donation": 0.0201
# }
#
#
# 9_5 donation:
# {
#   "thoughts": [
#     "I have 8.464 units, and I decided to donate 1 unit in the first round, so I will follow that strategy and evaluate what 9_11 did last round.",
#     "Looking at 9_11's donation history, they have been very cautious with their donations, giving only a minuscule amount last round.",
#     "Since they have only donated a very small percentage, they may expect low reciprocity. However, I want to encourage more giving without losing significant amounts myself.",
#     "I will give up 1 unit to maintain my strategy while providing enough incentive for 9_11 to donate more in future rounds."
#   ],
#   "donation": 0.11814449785111307
# }
#
#
# 9_7 donation:
# {
#   "thoughts": [
#     "9_4 has a relatively high amount of resources (17.46 units), suggesting they are doing well in the game.",
#     "In previous rounds, 9_4 donated only 0.05%, which indicates they might not be a very generous giver or they are playing conservatively.",
#     "Since I am currently at 52.01 units, donating too much could jeopardize my standing in future rounds if 9_4 is receiving without reciprocating.",
#     "I will donate a small amount relative to my total to encourage reciprocity in the next round. A reasonable donation might be approximately 1 unit, which has previously proven to be a good strategy for engagement."
#   ],
#   "donation": 0.0192
# }
#
#
# 9_11 donation:
# {
#   "thoughts": [
#     "In this round, I need to consider 9_2's last donation in round 11, which was very small (0.0224%).",
#     "Since my goal is to encourage a productive and reciprocal relationship, I want to give a meaningful amount without risking my own resources too heavily.",
#     "Given that I have 7.34 units, I should decide on a donation that both reflects goodwill and maintains a balance for my own strategy.",
#     "A donation of 1 unit would still allow me to have a decent amount left that can be leveraged in future rounds."
#   ],
#   "donation": 0.1368
# }
#
#
# 9_8 donation:
# {
#   "thoughts": [
#     "I will donate based on my strategy which involves donating 1 unit in the first round and adjusting future donations based on the recipient's previous donations.",
#     "Looking at 9_3's previous donations, they donated a very small percentage (0.0015%) of their large resource pool in the last round, which suggests they might be conservative in giving or less motivated to share.",
#     "Since I have only 4.3359 units available, I will calculate a small, yet meaningful donation to encourage reciprocation without jeopardizing my own survival.",
#     "I want to choose a donation that is a significant enough percentage of my total available resources to make a positive impact but still allows me to retain enough for future rounds."
#   ],
#   "donation": 0.25
# }
#
#
# 9_4 donation:
# {
#   "thoughts": [
#     "I currently have 17.4613 units, and I need to decide how much to donate to 9_5 based on their previous actions and my strategy.",
#     "9_5 donated 0.1125% of their resources in the last round, indicating a willingness to share, albeit not significantly. This suggests they might be more inclined to donate to me if I also show some generosity.",
#     "To encourage 9_5 to reciprocate in future rounds, I should make a donation that is noticeable enough but still preserves a majority of my resources. A small donation could solidify trust without compromising my own position too much.",
#     "Given that I have more than 17 units, donating 1 unit would represent a significant charitable gesture (about 5.73% of my resources). This amount is enough to show goodwill while still leaving me with ample units for future rounds."
#   ],
#   "donation": 0.0573
# }
#
#
# 9_3 donation:
# {
#   "thoughts": [
#     "In earlier rounds, I started by donating 1 unit, which is a very low percentage of the resource at that point.",
#     "Currently, I have 280.598300727694 units, making 1 unit a reasonable initial donation.",
#     "9_8's previous donations have been minimal (only 0.1% in round 11), which may indicate a cautious approach.",
#     "To encourage 9_8 to reciprocate positively and to help maximize resources, I can consider donating slightly more than 1 unit, while still being mindful of my own resources."
#   ],
#   "donation": 0.00357
# }
#
#
# 9_10 donation:
# {
#   "thoughts": [
#     "Considering that I have 27.11274598181476 units, I want to give a donation that is balanced and encourages reciprocity from 9_7. Based on their history, 9_7's past donations are quite low, so I need to ensure that my donation is still significant for them while leaving me with a reasonable amount.",
#     "Since 9_7 is currently doing well with 52.0141208268647 units, I want to give enough to motivate them to give back but not so much that I jeopardize my own standing for future rounds.",
#     "I decide to donate a percentage that reflects both my previous strategies and the context of the game: I trust that a donation of 3 units will be appreciated, as it represents around 11% of my current resources, creating a potential return of 6 units for me in the next round."
#   ],
#   "donation": 0.11026
# }
#
#
# Evolving to generation 10
#
#
# Top half:
# player 9_3 with wallet 281.7645181572753 and strategy: My strategy will be to donate 1 unit in the first round, and then adjust future donations based on the recipient's last donation.
# player 9_0 with wallet 107.07322404519687 and strategy: My strategy will be to donate 2 units in the first round, and then adjust future donations based on the last action taken by the recipient.
# player 9_7 with wallet 56.99435245089869 and strategy: My strategy will be to donate 1 unit in the first round, then adjust my future donations based on the last donation of the recipient.
# player 9_9 with wallet 53.09573237701157 and strategy: My strategy will be to donate 1 unit in the first round and adjust future donations based on the previous donation of the recipient.
# player 9_2 with wallet 44.99772697305596 and strategy: My strategy will be to donate 1 unit in the first round and then adjust future donations based on the recipient's last donation to encourage continued cooperation.
# player 9_1 with wallet 44.79954014022102 and strategy: My strategy will be to donate 1 unit in the first round and adjust my future donations based on the recipient's most recent donation.
#
#
# 10_0 strategy:
# {
#   "thoughts": [
#     "Start by donating a small amount to encourage possible reciprocation in later rounds.",
#     "Adjust future donations based on the latest information available about the recipient's previous behavior.",
#     "Strive for a balance between risk and reward; too high donations might hurt in subsequent rounds.",
#     "Aim to build a reputation of cooperation while still being strategic about resource allocation."
#   ],
#   "strategy": "My strategy will be to donate 2 units in the first round, and then adjust future donations based on the recipient's last donation to encourage cooperation."
# }
#
#
# 10_1 strategy:
# {
#   "thoughts": [
#     "I need to start with a conservative donation to mitigate risk since I don't have information on the recipient's past behaviors.",
#     "Small donations in the first round allow for adjustment based on observed behaviors in subsequent rounds.",
#     "I will focus on encouraging cooperation, as this can maximize returns over multiple rounds.",
#     "Adapting my donations based on the last action of the recipient will help build a positive interaction."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round and adjust future donations based on the recipient's last donation."
# }
#
#
# 10_2 strategy:
# {
#   "thoughts": [
#     "Starting with no prior knowledge, a small initial donation is safe.",
#     "Observing the recipient's last donation will guide my future actions.",
#     "A pattern of adjustment based on recipients may encourage reciprocal behavior.",
#     "Maintaining a balance between donating and conserving resources is key."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round, then adjust my future donations based on the last donation made by the recipient."
# }
#
#
# 10_3 strategy:
# {
#   "thoughts": [
#     "Start with a conservative donation to gauge the recipient's willingness to cooperate.",
#     "Observe the recipient's previous donation before making my next donation.",
#     "Adapt my strategy depending on whether the recipient reciprocates positively or negatively.",
#     "Aim to build trust and maximize resource exchange over rounds."
#   ],
#   "strategy": "My strategy will be to donate 2 units in the first round, then adapt my donations based on the recipient's last donation."
# }
#
#
# 10_4 strategy:
# {
#   "thoughts": [
#     "In the first round, I should start with a small donation as I have no information about the recipient's behavior.",
#     "I will adjust my donations based on the recipient's last donation to promote cooperation.",
#     "I should aim to maximize my own units while encouraging reciprocal giving from my partner.",
#     "Through observing the donation patterns, I can devise a strategy that balances giving and self-preservation."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round and then adjust my future donations based on the recipient's last donation."
# }
#
#
# 10_5 strategy:
# {
#   "thoughts": [
#     "I should start with a small donation to encourage cooperation.",
#     "I will adjust my donations based on the recipient's last action to promote ongoing giving.",
#     "It's important to maintain a balance between giving and retaining resources for myself.",
#     "If the recipient donates less, I will also decrease my donation to protect my resources."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round and adjust my future donations based on the recipient's last donation."
# }
#
#
# 10_6 strategy:
# {
#   "thoughts": [
#     "Observing the donations of others indicates that small, consistent contributions tend to foster cooperation.",
#     "Starting with a small donation allows for adjustment based on the recipient's behavior in the next round.",
#     "Tracking the recipient's last action is critical for deciding future contributions, aiming to encourage reciprocal donations.",
#     "Balancing between donating enough to benefit and retaining resources for future rounds is key."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round, observe the recipient's last donation, and adjust future donations accordingly."
# }
#
#
# 10_7 strategy:
# {
#   "thoughts": [
#     "Start by donating a small amount to establish cooperation without risking too much of my endowment.",
#     "Observe the recipient's last donation in future rounds to gauge their willingness to reciprocate.",
#     "Adjust my donations based on their behavior to maximize returns while maintaining a fair exchange.",
#     "Be adaptable to the information available from the previous rounds of the recipient and their partners."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round, then adjust future donations based on the recipient's last donation, aiming for a balance between cooperation and maximizing my own resource."
# }
#
#
# 10_8 strategy:
# {
#   "thoughts": [
#     "Observe the recipient's previous donation behavior for potential cooperation.",
#     "Start with a low donation in the first round to mitigate risk of loss.",
#     "Adapt my strategy to encourage a reciprocal donation from the recipient.",
#     "Aim for a balance between being generous and protecting my own resource."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round and then adjust future donations based on the last donation from the recipient as a signal for cooperation."
# }
#
#
# 10_9 strategy:
# {
#   "thoughts": [
#     "Begin with a small donation to gauge recipient's response.",
#     "Adjust future donations based on the recipient's last action.",
#     "Encourage cooperation by showing willingness to share resources.",
#     "Aim for a balance between giving and preserving my own units."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round and adjust my future donations based on the recipient's last donation."
# }
#
#
# 10_10 strategy:
# {
#   "thoughts": [
#     "Start with a conservative donation since there's no prior behavior to base decisions on.",
#     "Observe the recipient's donation relative to what I give, to establish a pattern of cooperation.",
#     "Adapt my future donations based on the most recent action of the recipient to encourage reciprocation.",
#     "Aim for a balance between generosity and maintaining my resource for future rounds."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round and adjust future donations based on the last action taken by the recipient."
# }
#
#
# 10_11 strategy:
# {
#   "thoughts": [
#     "Start with a small donation to test the waters and encourage cooperation.",
#     "Adjust future donations based on the recipient's recent behavior to maximize benefits.",
#     "Keep track of the recipient's past donation to gauge their cooperation inclination.",
#     "Aim for a balance between generosity and resource conservation for sustainability."
#   ],
#   "strategy": "My strategy will be to donate 1 unit in the first round and adjust future donations based on the last donation made by the recipient."
# }
#
#
# Final players:
# player 10_0 with wallet 10 and strategy: My strategy will be to donate 2 units in the first round, and then adjust future donations based on the recipient's last donation to encourage cooperation.
# player 10_1 with wallet 10 and strategy: My strategy will be to donate 1 unit in the first round and adjust future donations based on the recipient's last donation.
# player 10_2 with wallet 10 and strategy: My strategy will be to donate 1 unit in the first round, then adjust my future donations based on the last donation made by the recipient.
# player 10_3 with wallet 10 and strategy: My strategy will be to donate 2 units in the first round, then adapt my donations based on the recipient's last donation.
# player 10_4 with wallet 10 and strategy: My strategy will be to donate 1 unit in the first round and then adjust my future donations based on the recipient's last donation.
# player 10_5 with wallet 10 and strategy: My strategy will be to donate 1 unit in the first round and adjust my future donations based on the recipient's last donation.
# player 10_6 with wallet 10 and strategy: My strategy will be to donate 1 unit in the first round, observe the recipient's last donation, and adjust future donations accordingly.
# player 10_7 with wallet 10 and strategy: My strategy will be to donate 1 unit in the first round, then adjust future donations based on the recipient's last donation, aiming for a balance between cooperation and maximizing my own resource.
# player 10_8 with wallet 10 and strategy: My strategy will be to donate 1 unit in the first round and then adjust future donations based on the last donation from the recipient as a signal for cooperation.
# player 10_9 with wallet 10 and strategy: My strategy will be to donate 1 unit in the first round and adjust my future donations based on the recipient's last donation.
# player 10_10 with wallet 10 and strategy: My strategy will be to donate 1 unit in the first round and adjust future donations based on the last action taken by the recipient.
# player 10_11 with wallet 10 and strategy: My strategy will be to donate 1 unit in the first round and adjust future donations based on the last donation made by the recipient.
