# %%
from pydantic import BaseModel, Field
from typing import Any, List, Optional

class GameState(BaseModel):
  generation: int
  round: int
  
  # configs
  donation_multiplier: float = 2
  trace_depth: int = 3
  base_wallet: int = 10
  generations: int = 10
  rounds: int = 12
  players: int = 12
  cutoff_threshold: float = 0.5




class Decision(BaseModel):
  recipient_snapshot: Any
  game_state_snapshot: GameState
  donation_percent: float
  
  class Config:
    arbitrary_types_allowed = True

class StrategyBuilder(BaseModel):
  """Build the strategy"""
  thoughts: List[str] = Field(..., description="Briefly describe your thought process for the strategy to take for this round.")
  strategy: str = Field(..., description="The strategy to be used, must begin with 'My strategy will be'.")

class DonationBuilder(BaseModel):
  """Build the donation"""
  thoughts: List[str] = Field(..., description="Briefly describe your thought process for the donation to make for this round.")
  donation: float = Field(..., description="The percentage amount of resources to donate. MUST BE A FLOAT BETWEEN 0 AND 1.")


class Player:
  def __init__(self, game_state: GameState, i: int, parents: List["Player"] = [], strategy: Optional[str] = None):
    self.name: str = f"{game_state.generation}_{i}"
    self.parents: List[Player] = parents
    self.history: List[Decision] = [] 
    self.wallet: int = game_state.base_wallet
    if strategy:
      self.strategy: str = strategy
    else:
      self.strategy: str = self.generate_strategy(game_state=game_state, parents=parents)

  
  def clone(self):
    player = Player(name=self.name, parents=self.parents, strategy=self.strategy)
    player.wallet = self.wallet
    player.history = self.history
    return player



  def system_prompt(self, game_state: GameState):
    return f"""Each player is given an initial endowment of 10 units of a resource.
In each round, you are randomly paired with another individual.
One of you is a donor, and the other is a recipient.
The donor decides to give up some amount of the resource.
The recipient receives {game_state.donation_multiplier}x the number of units that the donor gave up.
If you were a donor in one round, you will be a recipient in the next round, and vice versa.
Your goal is to maximize the number of units you have after the final round.
After the game has finished, the best-performing half of agents will survive to the next generation, and continue playing."""

  def strategy_prompt(self, parents: List["Player"] = []):
    if parents: 
      parent_advice = "\n".join([f"\n\n{parent.name} with score {parent.wallet} strategy: {parent.strategy}" for parent in parents])
      generation_prompt = f"""How would you approach the game? Here is the advice of the best-performing 50% of the previous generation, along with their final scores.
{parent_advice}
Modify this advice to create your own strategy."""
    else: 
      generation_prompt = "Based on the description of the game, create a strategy that you will follow in  the game."
    
    return f"""Our name is {self.name}.

{generation_prompt}

As a donor, you will receive limited information about the recipient and their recent interactions: You will see what the recipient (let’s call them A) did in the immediately preceding round only.
You will also see what A’s partner from that round (let’s call them B) did in their preceding round.
This chain continues for at most three rounds back.
Important: You do NOT have access to multiple rounds of information about A directly.
You only know what A did in the single most recent round.

Example (assuming it’s now round 4): You are paired with A.
You know: In round 3, A donated X% to B.
You also know: In round 2, B donated Y% to C.
And finally: In round 1, C donated Z% to D.
Remember: This is all the information you have.
You don’t know what A did in rounds 1 or 2, only in round 3.

In the first round, there will be no information about the recipient’s previous behavior - think carefully about how much to donate in that case.
Before formulating your strategy, briefly think step by step about what would be a successful strategy in this game.
Then describe your strategy briefly without explanation in one sentence that starts: My strategy will be."""
  
  def donation_prompt(self, game_state: GameState, recipient: "Player"):
    def build_trace(depth: int):
      trace = ""
      current_recipient = recipient
      for _ in range(depth):
        if not current_recipient.history:
          break
        trace += f"In round {current_recipient.history[0].game_state_snapshot.round}, {current_recipient.name} donated {current_recipient.history[0].donation_percent}% of their resources to {current_recipient.history[0].recipient_snapshot.name}.\n"
        current_recipient = current_recipient.history[0].recipient_snapshot
      return trace
    
    trace = build_trace(game_state.trace_depth)

    # TODO: donor is invisible to recipient
    return f"""Your name is 2_4.
As you will recall, here is the strategy you decided to follow: {self.strategy}
This is generation {game_state.generation}.
It is now round {game_state.round}.
In this round, you have been paired with {recipient.name}.
They currently have {recipient.wallet} units of the valuable resource.
Here is what {recipient.name} and their earlier partners did in previous rounds: {trace}
You will take the role of donor. You currently have {self.wallet} units of the valuable resource.

How many units do you give up? Very briefly think step by step about how you apply your strategy in this situation and then provide your answer."""
  
  def generate_strategy(self, game_state: GameState, parents: List["Player"] = []) -> str:
    res = client.beta.chat.completions.parse(
      model="gpt-4o-mini",
      messages=[
        {"role": "system", "content": self.system_prompt(game_state=game_state)},
        {"role": "user", "content": self.strategy_prompt(parents=parents)},
      ],
      response_format=StrategyBuilder
    )
    built_strategy = res.choices[0].message.parsed

    print(f"\n\n{self.name} strategy:\n{built_strategy.model_dump_json(indent=2)}")

    return built_strategy.strategy
  
  def generate_donation(self, game_state: GameState, recipient: "Player") -> float:
    res = client.beta.chat.completions.parse(
      model="gpt-4o-mini",
      messages=[
        {"role": "system", "content": self.system_prompt(game_state=game_state)},
        {"role": "user", "content": self.donation_prompt(game_state=game_state, recipient=recipient)},
      ],
      response_format=DonationBuilder
    )
    built_donation = res.choices[0].message.parsed

    print(f"\n\n{self.name} donation:\n{built_donation.model_dump_json(indent=2)}")

    return built_donation.donation
  
  def execute_donation(self, recipient: "Player", game_state: GameState):
    donation_percent = self.generate_donation(game_state, recipient)
    donation_amount = self.wallet * donation_percent
    self.wallet -= donation_amount
    recipient.wallet += donation_amount * game_state.donation_multiplier

    game_state_copy = GameState(**game_state.model_dump())
    recipient_copy = Player(game_state=game_state_copy, i = recipient.name.split("_")[1], parents=recipient.parents, strategy=recipient.strategy)
    decision = Decision(recipient_snapshot=recipient_copy, game_state_snapshot=game_state_copy, donation_percent=donation_percent)

    self.history.append(decision)
    
    return donation_percent

# %%
# test by creating two players
game_state = GameState(generation=1, round=1)
player1 = Player(game_state=game_state, i=1)
player2 = Player(game_state=game_state, i=2)
# Out:
# 1_1 strategy:
# {
#   "thoughts": [
#     "In the first round, as there is no prior information about the recipient's behavior, I will start with a small donation to test their willingness to reciprocate in the future rounds. As I gain information about their past behavior, I will adjust my donation strategy accordingly, potentially increasing it if they have shown a tendency to be generous, or decreasing it if they have been selfish. The key is to leverage the twofold return of donations while also protecting my own resources if the recipient is not likely to reciprocate."
#   ],
#   "strategy": "My strategy will be to start by donating 2 units in the first round and then adjust my donations based on the generosity displayed by my recipient in their previous round."
# }
#
#
# 1_2 strategy:
# {
#   "thoughts": [
#     "In the first round, I have no prior information about my recipient's behavior, so I should donate a moderate amount to encourage cooperation and signal trust, without risking too much of my own resources.",
#     "As I receive more information in the following rounds about the recipient's previous donations, I will adjust my donation amount accordingly, being more generous to those who have donated more in their past and more conservative with those who have not.",
#     "If I see that the recipient donated a large amount in the previous round, I may choose to donate less than the previous donor's amount to preserve my resources while still benefitting from the recipient's generosity.",
#     "In cases where I observe a pattern of low donations from my partner's partners, I may choose to either donate less or hold more back in future rounds."
#   ],
#   "strategy": "My strategy will be to start by donating 3 units in the first round to promote a positive interaction, then adjust my donations based on the recipient's previous behavior, aiming to reward those who donate more."
# }

# %%
player1.execute_donation(player2, game_state)
# Out:
# 1_1 donation:
# {
#   "thoughts": [
#     "I recall my strategy is to donate 2 units in the first round.",
#     "Since I have 10 units and this is my first round, I will stick to my original plan without any adjustments, as I have no prior information about 1_2's behavior.",
#     "Donating 2 units will potentially yield a good return depending on how 1_2 behaves in future rounds."
#   ],
#   "donation": 0.2
# }
# 0.2

# %%
print(player1.wallet)
print(player2.wallet)
# Out:
# 8.0
# 14.0

# %%
from typing import Tuple
from typing import List
import numpy as np


class Orchestrator:
  def __init__(self, game_state: GameState):
    self.game_state = game_state
    self.players = [Player(game_state=game_state, i=i) for i in range(game_state.players)]
  
  def create_donor_recipient_pairs(self) -> List[Tuple[Player, Player]]:
    # each player should be both a donor and recipient and it should be randomized 
    pairs: List[Player] = []
    donors_map = {}
    recipient_pool: List[Player] = self.players.copy()
    donor_pool: List[Player] = self.players.copy()
    for donor in donor_pool:
      recipient = np.random.choice(recipient_pool)
      while recipient == donor or donors_map.get(recipient.name, "") == donor.name:
        recipient = np.random.choice(recipient_pool)
      pairs.append((donor, recipient))
      recipient_pool.remove(recipient)
    
    return pairs
  
  def play_round(self):
    pairs = self.create_donor_recipient_pairs()
    for donor, recipient in pairs:
      donor.execute_donation(recipient, self.game_state)
    self.game_state.round += 1

  def evolve(self):
    self.game_state.round = 1
    self.game_state.generation += 1
    print(f"\n\nEvolving to generation {self.game_state.generation}")
    # sort players by wallet
    self.players = sorted(self.players, key=lambda x: x.wallet, reverse=True)
    # get top half
    top_half = self.players[:int(len(self.players)*self.game_state.cutoff_threshold)]
    # clone players
    top_players_strings = "\n".join([f"player {player.name} with wallet {player.wallet} and strategy: {player.strategy}" for player in top_half])
    print(f"\n\nTop half:\n{top_players_strings}")
    self.players = [Player(game_state=self.game_state, i=i, parents=top_half) for i in range(self.game_state.players)]

  def run(self) -> List[Player]:
    for _ in range(self.game_state.generations):
      print(f"\n\nGeneration {self.game_state.generation}")
      for _ in range(self.game_state.rounds):
        print(f"\n\n\tGeneration {self.game_state.generation} Round {self.game_state.round}")
        self.play_round()
      if self.game_state.generation < self.game_state.generations:
        self.evolve()
    
    return self.players

# %%
game_state = GameState(generation=1, round=1, generations=4, rounds=6, players=4, cutoff_threshold=0.5)
orchestrator = Orchestrator(game_state)
final_players = orchestrator.run()

final_players = sorted(final_players, key=lambda x: x.wallet, reverse=True)
top_players_strings = "\n".join([f"player {player.name} with wallet {player.wallet} and strategy: {player.strategy}" for player in final_players])
print(f"\n\nFinal players: \n{top_players_strings}")
# Out:
# 1_0 strategy:
# {
#   "thoughts": [
#     "As a donor in the initial round, I have no information about the recipient A. I should consider starting with a conservative donation to avoid losing too many units early on. In subsequent rounds, my donation will be influenced by A's previous behavior, where if A donated generously, I will match that generosity or slightly increase it, and if A donated poorly, I may choose to donate less. The strategy should focus on building trust and cooperation, as reciprocation could maximize my resources over multiple rounds."
#   ],
#   "strategy": "My strategy will be to start with a small donation of 1 unit in the first round and adjust my donation in subsequent rounds based on A's previous round's behavior, aiming to build trust or retaliate as necessary."
# }
#
#
# 1_1 strategy:
# {
#   "thoughts": [
#     "In the first round, I cannot gauge the recipient's past behavior, so I will donate a small amount to test their willingness to reciprocate in the next round.",
#     "In subsequent rounds, I will analyze the recipient's most recent donation behavior and decide to donate a proportionate amount based on that observation.",
#     "If the recipient gave a high percentage in their previous round, I will also donate a higher amount, promoting mutual benefit; if they donated little, I will reduce my contribution to mitigate loss."
#   ],
#   "strategy": "My strategy will be to start with a conservative donation of 1 unit in the first round and adjust my donations in subsequent rounds based on the previous donation percentage of the recipient."
# }
#
#
# 1_2 strategy:
# {
#   "thoughts": [
#     "In the first round, since there is no prior information about the recipient, I will give a minimal donation to maintain my resources while still participating in the altruism of the game.",
#     "In subsequent rounds, I will analyze the recipient's donation behavior. If they donated significantly in the previous round, I will be more inclined to reciprocate generously, while if they donated minimally, I will only give a small amount or withhold donations entirely to protect my resources.",
#     "I will aim to build trust with generous donors while being cautious around those who are not contributing, ensuring that my final resource count is maximized."
#   ],
#   "strategy": "My strategy will be to donate minimally in the first round and then adjust my donations based on the recipient's past donation behavior, aiming for reciprocity or conservation depending on their actions."
# }
#
#
# 1_3 strategy:
# {
#   "thoughts": [
#     "In the first round, I have no information about the recipient's past behavior. Therefore, I should choose a conservative donation strategy to avoid losing too many resources without knowing if the recipient will reciprocate in the future.",
#     "For subsequent rounds, I will analyze the recipient's previous donation behavior to better predict their willingness to share and adjust my donations accordingly. If they have donated a decent amount in their last round, I will consider matching that to encourage reciprocation; if they have donated very little, I may choose to donate less myself.",
#     "I will aim to balance my donations by being generous enough to maximize my gain but also cautious enough not to sacrifice too many units when paired with less charitable recipients."
#   ],
#   "strategy": "My strategy will be to donate 5 units in the first round, and then adjust my donations based on the recipient's previous round donation behavior in subsequent rounds."
# }
#
#
# Generation 1
#
#
# 	Generation 1 Round 1
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "Since this is the first round, I want to establish trust with my partner, 1_2. Even though I don't know their previous behavior towards donations, starting with a small donation seems prudent.",
#     "I aim to donate 1 unit as per my strategy to encourage reciprocity later on.",
#     "If 1_2 reacts positively, I can increase my donation in future rounds."
#   ],
#   "donation": 0.1
# }
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "Starting with my strategy, I planned to donate conservatively in the first round.",
#     "Given that I have 10 units, I will donate 1 unit as initially intended.",
#     "This donation will allow 1_3 to receive 2 units as a result of my contribution.",
#     "I aim to create a cooperative dynamic while ensuring I maintain enough resources for future rounds."
#   ],
#   "donation": 0.1
# }
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "1_1 donated only 0.1% of their resources previously, suggesting they might not be very generous.",
#     "Given that I was going to donate minimally in the first round, I want to establish a baseline where I can observe their behavior.",
#     "Since I currently have 12.0 units, minimizing risk while still contributing helps me gather information for future rounds.",
#     "Choosing a small amount, like 0.5% of my current resources, balances my strategy of being cautious while potentially encouraging some reciprocal behavior."
#   ],
#   "donation": 0.005
# }
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "Since I am following my strategy to donate 5 units in the first round, and I currently have 12 units, I will proceed with donating the full 5 units. This aligns with my strategy and allows me to gauge the recipient's behavior in future rounds based on their response to my donation."
#   ],
#   "donation": 0.4166666666666667
# }
#
#
# 	Generation 1 Round 2
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "1_2 has more units than I do, which may make them less inclined to reciprocate a donation. However, they donated a very small amount in the previous round (0.005% of their resources).",
#     "Since I started with a small donation of 1 unit in round 1 and I currently have 19 units, I want to maintain a good relationship while also being cautious, considering 1_2's small donation behavior.",
#     "To build trust, I will increase my donation slightly more than I did in the first round. I will make it a token amount that they might appreciate but won't significantly harm my standing."
#   ],
#   "donation": 0.05
# }
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "I am playing as the donor in this round and I need to decide how much to donate based on my strategy.",
#     "In round 1, 1_3 donated approximately 0.42 unit (which is about 4.17% of their resources) to 1_0, indicating they are somewhat cooperative but not overly generous.",
#     "Since I have 9.12 units, if I take a conservative approach according to my initial strategy, I should maintain a similar low donation to what 1_3 previously donated.",
#     "A donation of around 0.42 units would be a little over 4% of my current resources, which aligns with my conservative approach and allows me to keep most of my resources for the next rounds.",
#     "I decide to donate 0.5 units as this is slightly higher than their previous donation and allows me to maintain my resource base while encouraging cooperation. I want to be seen as generous to create goodwill."
#   ],
#   "donation": 0.5
# }
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "1_1 donated very minimally in the previous round (only 0.1%), indicating a conservative approach.",
#     "Since they only have 4.56 units now, their minimal donation suggests they likely value conserving their resources over significant giving.",
#     "Given that I currently have a surplus (13.84 units), I can afford to be slightly generous, but not too much, as I want to avoid being taken advantage of.",
#     "I should donate a small amount that encourages 1_1 to reciprocate in future rounds but also allows me to conserve enough resources for my own benefit."
#   ],
#   "donation": 0.1
# }
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "1. I have 16.12 units and need to decide how much to donate based on the behavior of 1_0.",
#     "2. In the previous round, 1_0 donated only a small amount (0.1% of their resources) to their partner, which indicates they might be more conservative with donations.",
#     "3. Since I want to maximize my resources and I have a decent amount right now, I can be slightly generous to encourage a reciprocal donation in the next round.",
#     "4. However, since I don't want to give too much away as 1_0 is not likely to donate more than they already did, I'll stick with a moderate donation amount. A donation of 5 units initially was a solid plan but considering their low donation, a slightly reduced donation is safer. I decide to donate 3 units instead."
#   ],
#   "donation": 0.1869
# }
#
#
# 	Generation 1 Round 3
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "1. I have a significant amount of units to donate, which gives me flexibility in my choices.",
#     "2. 1_3 has shown willingness to donate a fractional amount in the previous round, indicating they might be cooperative or open to mutual benefit.",
#     "3. Given my goal of building trust, I should consider a donation that encourages reciprocity without risking too much of my resource balance.",
#     "4. A donation of 1 unit positioned between both players' resource sizes could create positive interactions; it's substantial enough to be meaningful but not too much to deplete my stocks."
#   ],
#   "donation": 0.0415
# }
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "1_0 has a higher resource count (23.08 units) compared to my current (7.33 units), indicating they may be less inclined to donate back in the next round if I donate too generously now.",
#     "1_0 donated only 0.1% of their resources in round 1, which shows they are quite conservative in their donations.",
#     "Since I want to encourage a positive feedback loop for future donations, I want to donate enough to be beneficial but not so much that I deplete my own resources too significantly.",
#     "A donation of about 1 unit aligns with my established strategy of being conservative, as I can then analyze what 1_0 does in response. Keeping 6.33 units for myself still leaves room for a good resource base moving forward."
#   ],
#   "donation": 0.1365
# }
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "1_1 has donated very minimally in the previous round (only 0.1% of their resources).",
#     "Since I am in the role of donor this round, I want to encourage 1_1 to donate more in the next round by showing some generosity but still protect my resources.",
#     "Given they have a lower amount than I do, I will donate a small amount which allows them to gain more without risking too much of my own endowment."
#   ],
#   "donation": 0.05
# }
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "In round 1, 1_2 donated a very small amount (0.005%) of their resources, which indicates that they are likely not very generous or might be conservative in their donations.",
#     "They currently have 11.8332 units, which suggests they are still attached to their resources and may prioritize keeping them over sharing.",
#     "Given their previous minimal donation, I should consider being cautious with my own donation to ensure my resource balance remains healthy, but also aim to encourage positive interactions.",
#     "I will donate a smaller amount than my initial 5 units, as the limited donation by 1_2 suggests a strong need for self-preservation."
#   ],
#   "donation": 0.2
# }
#
#
# 	Generation 1 Round 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[75], line 3
#       1 game_state = GameState(generation=1, round=1, generations=4, rounds=6, players=4, cutoff_threshold=0.5)
#       2 orchestrator = Orchestrator(game_state)
# ----> 3 final_players = orchestrator.run()
#       5 final_players = sorted(final_players, key=lambda x: x.wallet, reverse=True)
#       6 top_players_strings = "\n".join([f"player {player.name} with wallet {player.wallet} and strategy: {player.strategy}" for player in final_players])
#
# Cell In[71], line 50, in Orchestrator.run(self)
#      48 for _ in range(self.game_state.rounds):
#      49   print(f"\n\n\tGeneration {self.game_state.generation} Round {self.game_state.round}")
# ---> 50   self.play_round()
#      51 if self.game_state.generation < self.game_state.generations:
#      52   self.evolve()
#
# Cell In[71], line 27, in Orchestrator.play_round(self)
#      26 def play_round(self):
# ---> 27   pairs = self.create_donor_recipient_pairs()
#      28   for donor, recipient in pairs:
#      29     donor.execute_donation(recipient, self.game_state)
#
# Cell In[71], line 20, in Orchestrator.create_donor_recipient_pairs(self)
#      18 recipient = np.random.choice(recipient_pool)
#      19 while recipient == donor or donors_map.get(recipient.name, "") == donor.name:
# ---> 20   recipient = np.random.choice(recipient_pool)
#      21 pairs.append((donor, recipient))
#      22 recipient_pool.remove(recipient)
#
# KeyboardInterrupt:
