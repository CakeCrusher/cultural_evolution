# %% [markdown]
# ## Setup Telemetry

# %%
import os
import dotenv

dotenv.load_dotenv()

from phoenix.otel import register

OTEL_EXPORTER_OTLP_HEADERS = os.getenv("OTEL_EXPORTER_OTLP_HEADERS")
PHOENIX_CLIENT_HEADERS = os.getenv("PHOENIX_CLIENT_HEADERS")
PHOENIX_COLLECTOR_ENDPOINT = os.getenv("PHOENIX_COLLECTOR_ENDPOINT")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if not OTEL_EXPORTER_OTLP_HEADERS or not PHOENIX_CLIENT_HEADERS or not PHOENIX_COLLECTOR_ENDPOINT or not OPENAI_API_KEY:
    raise ValueError("Missing required environment variables")

endpoint = PHOENIX_COLLECTOR_ENDPOINT + "/v1/traces"

# %%
project_name = "donors_game"

tracer_provider = register(
    project_name=project_name,
    endpoint=endpoint
)

from openinference.semconv.resource import ResourceAttributes
from opentelemetry import trace
from opentelemetry.exporter.otlp.proto.http.trace_exporter import OTLPSpanExporter
from opentelemetry.sdk.resources import Resource
from opentelemetry.sdk.trace import TracerProvider
from opentelemetry.sdk.trace.export import SimpleSpanProcessor
from openinference.semconv.trace import SpanAttributes
from openinference.semconv.trace import OpenInferenceSpanKindValues


resource = Resource(attributes={
  ResourceAttributes.PROJECT_NAME: project_name
})

tracer_provider = TracerProvider(resource=resource)
trace.set_tracer_provider(tracer_provider=tracer_provider)
tracer = trace.get_tracer(__name__)
span_exporter = OTLPSpanExporter(endpoint=endpoint)
simple_span_processor = SimpleSpanProcessor(span_exporter=span_exporter)
trace.get_tracer_provider().add_span_processor(simple_span_processor)
# Out:
# Overriding of current TracerProvider is not allowed
# Overriding of current TracerProvider is not allowed
# OpenTelemetry Tracing Details
# |  Phoenix Project: donors_game
# |  Span Processor: SimpleSpanProcessor
# |  Collector Endpoint: https://app.phoenix.arize.com/v1/traces
# |  Transport: HTTP
# |  Transport Headers: {'api_key': '****'}
# |
# |  Using a default SpanProcessor. `add_span_processor` will overwrite this default.
# |
# |  `register` has set this TracerProvider as the global OpenTelemetry default.
# |  To disable this behavior, call `register` with `set_global_tracer_provider=False`.

# %%
from openinference.instrumentation.openai import OpenAIInstrumentor
OpenAIInstrumentor().instrument(tracer_provider=tracer_provider)

import openai
client = openai.OpenAI(api_key=OPENAI_API_KEY)

# %% [markdown]
# ## Configurations, Typings, and Player Class

# %%
from pydantic import BaseModel

class A(BaseModel):
    a: int

class B(BaseModel):
    b: int

class AB(A, B):
    pass

class C(BaseModel):
    a: A
    c: int

ab = AB(a=1, b=2)

c = C(
    a=ab,
    c=3
)

c.model_dump()
# Out:
# {'a': {'a': 1}, 'c': 3}

# %%
from pydantic import BaseModel, Field
from typing import Any, List, Optional
from time import sleep
import json


class DynamicGameState(BaseModel):
  generation: int
  round: int

class GameConfig(BaseModel):
  donation_multiplier: float = 2
  trace_depth: int = 3
  base_wallet: int = 10
  generations: int = 10
  rounds: int = 12
  players: int = 12
  cutoff_threshold: float = 0.5

class GameState(GameConfig, DynamicGameState):
  pass
  

class Decision(BaseModel):
  # recipient data
  recipient_name: str
  recipient_wallet: float
  # game state data
  dynamic_game_state: DynamicGameState
  # donation data
  donation_percent: float
  donation_amount: float
  # donor wallet data
  donor_wallet_before: float
  donor_wallet_after: float
  
  class Config:
    arbitrary_types_allowed = True

class StrategyBuilder(BaseModel):
  """Build the strategy"""
  thoughts: List[str] = Field(..., description="Briefly describe your thought process for the strategy to take for this round.")
  strategy: str = Field(..., description="The strategy to be used, must begin with 'My strategy will be'.")

class DonationBuilder(BaseModel):
  """Build the donation"""
  thoughts: List[str] = Field(..., description="Briefly describe your thought process for the donation to make for this round.")
  donation: float = Field(..., description="The percentage amount of resources to donate. MUST BE A FLOAT BETWEEN 0 AND 1.")

def structured_generation_wrapper(*args, **kwargs) -> dict:
  # sleep(.1)
  span = trace.get_current_span()
  args_to_log = {**kwargs, "response_format": kwargs["response_format"].model_json_schema()}
  span.set_attribute(SpanAttributes.INPUT_VALUE, json.dumps(args_to_log))
  res = client.beta.chat.completions.parse(**kwargs, max_completion_tokens=1000)
  span.set_attribute(SpanAttributes.OUTPUT_VALUE, res.model_dump_json())
  so = res.choices[0].message.parsed
  if not so:
    raise ValueError("No response from LLM")
  return so

class Player:
  def __init__(self, game_state: GameState, i: int, parents: List["Player"] = [], strategy: Optional[str] = None):
    self.name: str = f"{game_state.generation}_{i}"
    self.parents: List[Player] = parents
    self.history: List[Decision] = [] 
    self.wallet: int = game_state.base_wallet
    if strategy:
      self.strategy: str = strategy
    else:
      self.strategy: str = self.generate_strategy(game_state=game_state, parents=parents)
    
  def find_decision_in_round(self, round_number: int) -> Decision:
    for decision in self.history:
      if decision.dynamic_game_state.round == round_number:
        return decision
    raise ValueError(f"Decision in round {round_number} not found")

  
  # def clone(self):
  #   player = Player(name=self.name, parents=self.parents, strategy=self.strategy)
  #   player.wallet = self.wallet
  #   player.history = self.history
  #   return player



  def system_prompt(self, game_state: GameState):
    return f"""Each player is given an initial endowment of 10 units of a resource.
In each round, you are randomly paired with another individual.
One of you is a donor, and the other is a recipient.
The donor decides to give up some amount of the resource.
The recipient receives {game_state.donation_multiplier}x the number of units that the donor gave up.
If you were a donor in one round, you will be a recipient in the next round, and vice versa.
Your goal is to maximize the number of units you have after the final round.
After the game has finished, the best-performing half of agents will survive to the next generation, and continue playing."""

  def strategy_prompt(self, parents: List["Player"] = []):
    if parents: 
      parent_advice = "\n".join([f"\n\n{parent.name} with score {parent.wallet} strategy: {parent.strategy}" for parent in parents])
      generation_prompt = f"""How would you approach the game? Here is the advice of the best-performing 50% of the previous generation, along with their final scores.
{parent_advice}
Modify this advice to create your own strategy."""
    else: 
      generation_prompt = "Based on the description of the game, create a strategy that you will follow in  the game."
    
    return f"""Our name is {self.name}.

{generation_prompt}

As a donor, you will receive limited information about the recipient and their recent interactions: You will see what the recipient (let’s call them A) did in the immediately preceding round only.
You will also see what A’s partner from that round (let’s call them B) did in their preceding round.
This chain continues for at most three rounds back.
Important: You do NOT have access to multiple rounds of information about A directly.
You only know what A did in the single most recent round.

Example (assuming it’s now round 4): You are paired with A.
You know: In round 3, A donated X% to B.
You also know: In round 2, B donated Y% to C.
And finally: In round 1, C donated Z% to D.
Remember: This is all the information you have.
You don’t know what A did in rounds 1 or 2, only in round 3.

In the first round, there will be no information about the recipient’s previous behavior - think carefully about how much to donate in that case.
Before formulating your strategy, briefly think step by step about what would be a successful strategy in this game.
Then describe your strategy briefly without explanation in one sentence that starts: My strategy will be."""
  
  def donation_prompt(self, game_state: GameState, recipient: "Player", players: List["Player"]):
    def find_player(name: str) -> "Player":
      for player in players:
        if player.name == name:
          return player
      raise ValueError(f"Player {name} not found")
    
    def build_trace(depth: int):
      trace = ""
      current_recipient = recipient

      for i in range(depth):
        round_number = game_state.round - (i+1)
        if round_number < 1:
          break
        recipient_decision = current_recipient.find_decision_in_round(round_number)
        trace += f"In round {round_number}, {current_recipient.name} donated {recipient_decision.donation_percent}% of their resources to {recipient_decision.recipient_name}.\n"
        current_recipient: Player = find_player(recipient_decision.recipient_name)
      return trace
    
    trace = build_trace(game_state.trace_depth)

    # TODO: donor is invisible to recipient
    return f"""Your name is 2_4.
As you will recall, here is the strategy you decided to follow: {self.strategy}
This is generation {game_state.generation}.
It is now round {game_state.round}.
In this round, you have been paired with {recipient.name}.
They currently have {recipient.wallet} units of the valuable resource.
Here is what {recipient.name} and their earlier partners did in previous rounds: {trace}
You will take the role of donor. You currently have {self.wallet} units of the valuable resource.

How many units do you give up? Very briefly think step by step about how you apply your strategy in this situation and then provide your answer."""
  
  def generate_strategy(self, game_state: GameState, parents: List["Player"] = []) -> str:
    with tracer.start_as_current_span("generate_strategy") as span:
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.LLM.value)
      messages = [
        {"role": "system", "content": self.system_prompt(game_state=game_state)},
        {"role": "user", "content": self.strategy_prompt(parents=parents)},
      ]
      args = {
        "model": "gpt-4o-mini",
        "messages": messages,
        "response_format": StrategyBuilder
      }
      res = structured_generation_wrapper(**args)
      built_strategy = StrategyBuilder.model_validate(res)

      print(f"\n\n{self.name} strategy:\n{built_strategy.model_dump_json(indent=2)}")

      return built_strategy.strategy
  
  def generate_donation(self, game_state: GameState, recipient: "Player", players: List["Player"]) -> float:
    with tracer.start_as_current_span("generate_donation") as span:
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.LLM.value)
      messages=[
        {"role": "system", "content": self.system_prompt(game_state=game_state)},
        {"role": "user", "content": self.donation_prompt(game_state=game_state, recipient=recipient, players=players)},
      ]
      args = {
        "model": "gpt-4o-mini",
        "messages": messages,
        "response_format": DonationBuilder
      }
      res = structured_generation_wrapper(**args)
      built_donation = DonationBuilder.model_validate(res)

      print(f"\n\n{self.name} donation:\n{built_donation.model_dump_json(indent=2)}")

      return built_donation.donation
  
  def execute_donation(self, recipient: "Player", game_state: GameState, players: List["Player"]):
    with tracer.start_as_current_span(f"execute_donation-{self.name}") as span:
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.AGENT.value)
      span.set_attribute(SpanAttributes.INPUT_VALUE, json.dumps(self.model_dump()))
      donation_percent = self.generate_donation(game_state, recipient, players)
      donation_amount = self.wallet * donation_percent

      # if the donor doesn't have enough funds, donate all of their funds
      if self.wallet - donation_amount < 0:
        donation_amount = self.wallet
      
      self.wallet -= donation_amount
      recipient.wallet += donation_amount * game_state.donation_multiplier
      span.set_attribute(SpanAttributes.OUTPUT_VALUE, json.dumps({
        "donation_percent": donation_percent,
        "donation_amount": donation_amount,
      }))

      game_state_copy = GameState(**game_state.model_dump())
      decision = Decision(
        recipient_name=recipient.name,
        recipient_wallet=recipient.wallet,
        dynamic_game_state=game_state_copy,
        donation_percent=donation_percent,
        donation_amount=donation_amount,
        donor_wallet_before=self.wallet + donation_amount,
        donor_wallet_after=self.wallet
      )

      self.history.append(decision)
      
      return donation_percent
  
  # get current user information as a dict
  def model_dump(self):
    return {
      "name": self.name,
      "parents": [parent.name for parent in self.parents],
      "history": [decision.model_dump() for decision in self.history],
      "wallet": self.wallet,
      "strategy": self.strategy
    }
  
  # function to make the player json serializable
  def __json__(self):
    return self.model_dump()

# %% [markdown]
# ### Test Player

# %%
# test by creating two players
game_state = GameState(generation=1, round=1)
player1 = Player(game_state=game_state, i=1)
player2 = Player(game_state=game_state, i=2)
# Out:
# 1_1 strategy:
# {
#   "thoughts": [
#     "In the first round, I should play conservatively since I have no information about the recipient's past behavior; thus, donating a small amount (e.g., 1 or 2 units) is a good start to minimize my loss while still potentially providing enough incentive for the recipient.",
#     "As I gather information in subsequent rounds, I will adjust my donation based on the previous actions of my partner. If they donated a significant amount to their past partner, I may choose to match that generosity to maintain reciprocity.",
#     "If I sense that the recipient has a history of being generous based on the actions of their most recent partner, I will consider increasing my donation in hopes of benefitting from their generosity in the next round.",
#     "On the other hand, if it appears my recipient has been stingy, I will be cautious and either maintain my smaller donation or stop donating altogether if I see a pattern of them taking resources without giving back."
#   ],
#   "strategy": "My strategy will be to start by donating a small percentage of my resources in the first round and adjust my donations based on the perceived generosity of my partner in subsequent rounds."
# }
#
#
# 1_2 strategy:
# {
#   "thoughts": [
#     "In the first round, since there is no prior activity to gauge the recipient's behavior, I will allocate a minimal amount to protect my resources.",
#     "In subsequent rounds, I will analyze the recipient's recent donation behavior to decide the trustworthiness of their actions.",
#     "If the recipient donated a significant amount in the last round, I will reciprocate with a higher donation to foster cooperation.",
#     "If the recipient contributed less, I will choose to donate less to mitigate my losses.",
#     "Ultimately, I want to maintain a balance where I gain resources while encouraging positive behaviors in my partners."
#   ],
#   "strategy": "My strategy will be to donate a small percentage in the first round and adjust my donations based on the recent donation behavior of my recipient in subsequent rounds."
# }

# %%
player1.execute_donation(player2, game_state, [player1, player2])
# Out:
# 1_1 donation:
# {
#   "thoughts": [
#     "Since it's the first round, my partner has no previous rounds of generosity to analyze. Therefore, I need to establish a baseline of trust. I will donate a small percentage of my current units to show goodwill, while still retaining enough for myself.",
#     "I will choose a small yet significant percentage to donate, aiming for a donation that allows me to maintain a favorable position for future rounds."
#   ],
#   "donation": 0.1
# }
# 0.1

# %%
print(player1.wallet)
print(player2.wallet)
# Out:
# 9.0
# 12.0

# %% [markdown]
# ## Orchestrator

# %%
import numpy as np
np.random.permutation([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from typing import Tuple
from typing import List
import numpy as np

class Orchestrator:
  def __init__(self, game_state: GameState):
    with tracer.start_as_current_span("init_orchestrator") as span:
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
      span.set_attribute(SpanAttributes.INPUT_VALUE, game_state.model_json_schema())
      self.game_state = game_state
      self.players = [Player(game_state=game_state, i=i) for i in range(game_state.players)]

  def find_player(self, name: str) -> Player:
    for player in self.players:
      if player.name == name:
        return player
    raise ValueError(f"Player {name} not found")
  
  def create_donor_recipient_pairs(self) -> List[Tuple[Player, Player]]:
      # Create a random permutation of players for donors
      donors = np.random.permutation(self.players)
      # Create another random permutation for recipients
      recipients = np.random.permutation(self.players)
      
      # If any player is paired with themselves, regenerate recipient order
      repeat_count = 0
      while any(d == r for d, r in zip(donors, recipients)):
          recipients = np.random.permutation(self.players)
          repeat_count += 1
          if repeat_count > len(self.players)*3:
            raise ValueError("Failed to create donor-recipient pairs")
      
      # Create the pairs
      pairs = list(zip(donors, recipients))
      return pairs
  
  def play_round(self):
    with tracer.start_as_current_span("play_round") as span:
      span.set_attribute(SpanAttributes.INPUT_VALUE, self.game_state.model_dump_json())
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
      pairs = self.create_donor_recipient_pairs()
      span.set_attribute(SpanAttributes.OUTPUT_VALUE, json.dumps([f"{donor.name} -> {recipient.name}" for donor, recipient in pairs]))
      # TODO: can be parallelized but need to keep wallets static untill the end
      for donor, recipient in pairs:
        donor.execute_donation(recipient, self.game_state, self.players)
      self.game_state.round += 1

  def evolve(self):
    with tracer.start_as_current_span("evolve") as span:
      span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.AGENT.value)
      span.set_attribute(SpanAttributes.INPUT_VALUE, self.game_state.model_dump_json())
      self.game_state.round = 1
      self.game_state.generation += 1
      print(f"\n\nEvolving to generation {self.game_state.generation}")
      # sort players by wallet
      self.players = sorted(self.players, key=lambda x: x.wallet, reverse=True)
      # get top half
      top_half = self.players[:int(len(self.players)*self.game_state.cutoff_threshold)]
      # clone players
      top_players_strings = "\n".join([f"player {player.name} with wallet {player.wallet} and strategy: {player.strategy}" for player in top_half])
      print(f"\n\nTop half:\n{top_players_strings}")
      self.players = [Player(game_state=self.game_state, i=i, parents=top_half) for i in range(self.game_state.players)]

  def run(self) -> List[Player]:
    for generation_count in range(self.game_state.generations):
      with tracer.start_as_current_span(f"generation_{generation_count}") as span:
        span.set_attribute(SpanAttributes.INPUT_VALUE, self.game_state.model_dump_json())
        span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
        print(f"\n\nGeneration {self.game_state.generation}")
        for round_count in range(self.game_state.rounds):
          with tracer.start_as_current_span(f"round_{round_count}") as span:
            span.set_attribute(SpanAttributes.INPUT_VALUE, self.game_state.model_dump_json())
            span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
            print(f"\n\n\tGeneration {self.game_state.generation} Round {self.game_state.round}")
            self.play_round()
        if self.game_state.generation < self.game_state.generations:
          self.evolve()
    
    return self.players

# %% [markdown]
# ## Run Orchestrator

# %%
from opentelemetry import trace

with tracer.start_as_current_span("donors_game") as span:
  try:
    game_state = GameState(generation=1, round=1, generations=4, rounds=6, players=4, cutoff_threshold=0.5)
    # game_state = GameState(generation=1, round=1, generations=2, rounds=3, players=2, cutoff_threshold=0.5)
    span.set_attribute(SpanAttributes.INPUT_VALUE, game_state.model_dump_json())
    span.set_attribute(SpanAttributes.OPENINFERENCE_SPAN_KIND, OpenInferenceSpanKindValues.CHAIN.value)
    orchestrator = Orchestrator(game_state)
    final_players = orchestrator.run()
  except Exception as e:
    span.set_status(trace.Status(trace.StatusCode.ERROR))
    span.record_exception(e)

final_players = sorted(final_players, key=lambda x: x.wallet, reverse=True)
top_players_strings = "\n".join([f"player {player.name} with wallet {player.wallet} and strategy: {player.strategy}" for player in final_players])
print(f"\n\nFinal players: \n{top_players_strings}")
# Out:
# Invalid type dict for attribute 'input.value' value. Expected one of ['bool', 'str', 'bytes', 'int', 'float'] or a sequence of those types
# 1_0 strategy:
# {
#   "thoughts": [
#     "In the first round, I have no information about the recipient's previous behavior, so I will donate a small but noticeable amount to help build a cooperative reputation and encourage reciprocity in future rounds.",
#     "In subsequent rounds, I will base my donation on the observed behavior of the recipient. If they donated a significant amount to their previous partner, I will also give generously to maintain cooperation; if they donated little, I will reduce my donation accordingly to protect my own resources.",
#     "I will prioritize cooperation and mutual benefit, but remain cautious and adjust my strategy based on how much my partners are willing to give."
#   ],
#   "strategy": "My strategy will be to donate 3 units in the first round to build a cooperative foundation and adjust my donation in later rounds based on the recipient's giving behavior."
# }
#
#
# 1_1 strategy:
# {
#   "thoughts": [
#     "In the first round, since I have no information about the recipient's past actions, I should start with a conservative donation to preserve my resources while still encouraging cooperation.",
#     "Since I will be switching roles in the next round, I must think about how to create a positive precedent for the next round as a recipient, so I might want to give something reasonable.",
#     "In subsequent rounds, I will analyze the recipient's previous donation. If they donated a significant amount last round, I will give more to reciprocate trust. If they chose to give very little, I will minimize my donation.",
#     "Overall, I want to create a balance between helping my partner and maximizing my own resource retention."
#   ],
#   "strategy": "My strategy will be to donate 2 units in the first round and adjust my donation based on the recipient's previous behavior in subsequent rounds."
# }
#
#
# 1_2 strategy:
# {
#   "thoughts": [
#     "In the initial round, since there is no prior information about the recipient, I will opt for a moderate donation to establish a baseline of cooperation and assess the recipient's response.",
#     "As I collect information in subsequent rounds about the recipient's past donations, I will adapt my donation amount according to their behavior, rewarding high donations and being conservative with low ones.",
#     "The objective is to find a balance that maximizes my own resources while still incentivizing good behavior from my partner."
#   ],
#   "strategy": "My strategy will be to donate 3 units in the first round, and then adjust my donations based on the recipient's previous behavior, increasing my donations for generous recipients and decreasing them for those who do not reciprocate."
# }
#
#
# 1_3 strategy:
# {
#   "thoughts": [
#     "In the first round, I have no information about the recipient, so I will start by donating a small, safe percentage to foster cooperation and see how the recipient reacts. In subsequent rounds, I will adjust my donation based on the recipient's past behavior to maximize my returns while also maintaining a level of cooperation. If I see that the recipient donated a significant amount in the previous round, I will be inclined to donate more as a reciprocative gesture. Conversely, if the recipient did not donate, I will limit my donation to protect my own resources."
#   ],
#   "strategy": "My strategy will be to donate 20% of my resources in the first round and adjust my donations in subsequent rounds based on the recipient's previous donation behavior."
# }
#
#
# Generation 1
#
#
# 	Generation 1 Round 1
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "I am in the first round and according to my strategy, I decided to donate 3 units to establish cooperation.",
#     "Giving up 3 units will allow the recipient to receive 6 units, encouraging them to reciprocate in future rounds.",
#     "This donation aligns with my plan to foster a cooperative foundation since both I and the recipient start with equal resources and I want to create a positive dynamic."
#   ],
#   "donation": 0.3
# }
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "I am currently in round 1 as a donor.",
#     "I have decided to donate 3 units in this round as per my strategy for the first round.",
#     "Even though the recipient (1_1) has 10 units, my strategy starts with an initial donation of 3 units.",
#     "This way, I can establish a baseline for the interaction and observe how they reciprocate in the next round."
#   ],
#   "donation": 0.1875
# }
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "I will stick to my initial strategy of donating 2 units in the first round, regardless of previous behavior since I have not yet assessed it from this player.",
#     "Donating 2 units today will allow me to observe how my partner reacts in terms of their behavior in the next round, where I will be the recipient."
#   ],
#   "donation": 0.125
# }
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "Since I have decided to donate 20% of my resources in the first round, I calculate 20% of my 14.0 units, which is 2.8 units.",
#     "I will donate this amount to maximize my effectiveness as a donor and set the stage for further interactions based on the recipient's behavior."
#   ],
#   "donation": 0.2
# }
#
#
# 	Generation 1 Round 2
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "In this round, I'm paired with 1_1, who has 14.0 units and donated very little (0.125%) in the previous round.",
#     "Since 1_1's donation was minimal, I can interpret them as a non-generous player.",
#     "Based on my strategy, I'll decrease my donation in response to their low past donation behavior.",
#     "I want to be cautious, so I decide to give a small amount, rather than my full usual donation. To maintain a good balance, I will donate 1 unit."
#   ],
#   "donation": 0.07692307692307693
# }
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "1_2 has more units than me, which indicates they might be aiming to accumulate more resources.",
#     "In their last round, 1_2 donated a very small percentage (0.1875%), suggesting they might not prioritize generosity.",
#     "Given their past behavior, I should be cautious and not donate too much, as they may not reciprocate well.",
#     "Since I have an initial strategy of donating a fixed amount of 2 units in the first round of my turn, I will stick to that donation amount in order to create a base for future rounds."
#   ],
#   "donation": 0.125
# }
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "1_3 has a relatively high total amount of resources (11.2 units) and only donated a very small percentage (0.2%) to their partner in the previous round, indicating a low level of cooperation.",
#     "Given my strategy to build a cooperative foundation, I should maintain a reasonable donation that encourages a positive response but also protects my own resources.",
#     "I will decide to donate 3 units again, as this aligns with my initial strategy and demonstrates a strong commitment to cooperation."
#   ],
#   "donation": 0.23809523809523808
# }
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "Since I am acting as the donor this round, I need to decide how much to donate based on the previous behavior of my recipient, 1_0, and my own resources.",
#     "1_0 donated only 0.3% of their resources last round, which shows that they might not be very generous.",
#     "Given that I have 17.2 units, my usual strategy is to donate 20% of my resources, which would amount to 3.44 units (20% of 17.2). However, considering 1_0's past behavior, a smaller donation may be more appropriate to encourage them to donate more in the next round.",
#     "I should balance my desire to maximize my units and encourage the same from 1_0. Therefore, I will donate a smaller amount than my original strategy for this round."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 1 Round 3
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "1_2 has more units than me, indicating they could likely sustain a cooperative response. ",
#     "I need to adjust my donation based on 1_2’s previous behavior, which shows low giving (0.07692307692307693% of their resources).",
#     "To incentivize reciprocity while not overextending myself, I should give a modest amount that encourages positive interaction, balancing my own resource retention."
#   ],
#   "donation": 0.1
# }
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "I have 15.48 units and will be donating this round. Based on my strategy, I need to evaluate 1_0's previous donation behavior. They donated approximately 0.24% last round, which suggests they were somewhat generous, indicating they might reciprocate in future rounds.",
#     "Considering this, I want to contribute significantly to encourage them to return the favor in forthcoming rounds. However, I also need to ensure that I preserve enough of my own resources for future rounds.",
#     "A donation of around 20% could be too much, given that I want to maintain a strong position long-term. Instead, I will aim to donate about 15%, which is a compromise between being generous to encourage reciprocity while maintaining my resources."
#   ],
#   "donation": 0.15
# }
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "1_3 has a relatively high resource count of 13.158 units, which suggests they may be willing to share or expect donations given their previous low donations.",
#     "In round 2, 1_3 only donated 0.1% of their resources, which is quite minimal, indicating they might not be very cooperative or generous in their donations.",
#     "Since I have 14.0 units, I should consider a conservative donation that reflects their previous low donation and maintains a balance for my future rounds.",
#     "Based on my strategy of starting donations at 2 units initially, I will adjust this downward in response to 1_3's past behavior, aiming to donate 1 unit this round."
#   ],
#   "donation": 0.07142857142857142
# }
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "In round 1, 1_1 received a small donation from 1_2, and in round 2, they barely donated anything to 1_2 (only 0.125% of their resources), which is quite minimal. This indicates that 1_1 is not very generous or is conservative in their giving behavior. Since they currently have more resources than I do, I must be cautious with my donation to ensure I maintain a good amount for future rounds while still contributing enough to entice 1_1 to reciprocate in upcoming rounds.",
#     "Considering this context, I will choose to donate a small percentage that is still beneficial but doesn't deplete my resources significantly. I will donate 1 unit to maintain my advantage."
#   ],
#   "donation": 0.0534
# }
#
#
# 	Generation 1 Round 4
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "1. In this round, I'm the donor, and I have 15.158 units of the resource.",
#     "2. My strategy is to donate 20% of my resources in the first round, and adjust based on the recipient's past donations in subsequent rounds.",
#     "3. Since I need to assess the behavior of my opponent, I note that 1_1 has been donating very little compared to their total resources in previous rounds.",
#     "4. In round 3, 1_1 only donated about 0.0714% of their resources, indicating they might not be willing to share much back.",
#     "5. Given this information, I believe it makes sense to be cautious. I should donate enough to incentivize some cooperation without risking too much.",
#     "6. Therefore, I will decide to donate a smaller percentage than my initial 20% to allow for potential future rounds."
#   ],
#   "donation": 0.1
# }
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "1. I have 18.0189344 units, which gives me some flexibility in my donation.",
#     "2. 1_2 has a much larger resource pool (17.6143328 units) than the amounts they donated in previous rounds (0.0534%, 0.125%, 0.1875%).",
#     "3. I need to assess their previous donations to determine their generosity and willingness to cooperate.",
#     "4. Since 1_2's donations have been quite low, it's likely they are not very altruistic, so I need to be strategic about my donation.",
#     "5. I will stick to my plan and donate a modest amount that allows me to retain enough units for my future rounds, while still being beneficial to them to potentially encourage reciprocity later.",
#     "6. I decide to donate 1 unit, as it is a significant but not overly generous amount given the situation."
#   ],
#   "donation": 0.0555
# }
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "1_0 has a relatively high resource count (16.38 units), suggesting they might not be inclined to reciprocate significantly since they have more than my initial resources.",
#     "1_0's previous donations were very low (only 0.1% of their resources in round 3), which indicates they may not be very generous.",
#     "In accordance with my strategy to adjust my donations based on prior behavior, I plan to donate less this round because of their low donation history. I need to balance my donation to avoid excessive loss while still encouraging cooperation."
#   ],
#   "donation": 0.05
# }
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "1_3 seems to have a history of low donations, indicating they may not prioritize reciprocity.",
#     "They only donated a small percentage in previous rounds, indicating they might be self-interested.",
#     "Since my strategy was to start with a cooperative foundation, I should aim to donate enough to encourage them while not sacrificing much to my own resource pool.",
#     "Given 1_3's relatively high resource count, I can afford to donate a bit more to potentially influence them positively."
#   ],
#   "donation": 0.15
# }
#
#
# 	Generation 1 Round 5
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "1_0 has a higher initial resource count than I do, indicating they may have donated earlier to receive more.",
#     "In the previous rounds, 1_0 made small donations, suggesting they are not strongly altruistic and may not reciprocate well.",
#     "Given their minimal donations, I should be cautious and reduce my donation to avoid losing too much of my own resources."
#   ],
#   "donation": 0.05
# }
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "1_1 has a substantial amount of units compared to the previous rounds, indicating that they may not be inclined to donate freely due to their higher resource pool.",
#     "1_1's donation patterns show that they have been quite conservative with their donations in previous rounds, donating only very small percentages.",
#     "To build a cooperative foundation, I want to ensure that my donation is meaningful but not excessively generous given 1_1's behavior.",
#     "Since I originally planned to donate 3 units in the first round and have adjusted my strategy based on the recipient's behavior, I will consider donating a fraction of my total current units to encourage future cooperation while not being overly generous."
#   ],
#   "donation": 0.1
# }
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "1_2 has been donating very little (0.05% and 0.077%) in previous rounds, indicating they may be a low donor. This suggests they may not be a generous recipient in this round.",
#     "I already decided to donate 20% in the first round; however, due to 1_2's low donation behavior, I may want to adjust my strategy.",
#     "Donating a small amount might not encourage a good return, but donating too much would be risky if they continue to under-donate.",
#     "Given that they have a higher resource amount (17.70), I could afford to be a bit generous while testing their willingness to reciprocate."
#   ],
#   "donation": 0.1
# }
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "In previous rounds, 1_3 has shown a tendency to donate a very small percentage of their resources (0.1% of 17.23 units is approximately 0.017 units).",
#     "Since 1_3 has a higher resource count than me, they might be less incentivized to donate significantly unless encouraged.",
#     "To maintain a balanced approach, I will donate a small yet meaningful amount that reflects my strategy of adjusting donations based on the recipient's behavior.",
#     "Since their recent donation behavior suggests they are not inclined to give away much, I will donate an amount that could potentially motivate them to reciprocate in the next round."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 1 Round 6
#
#
# 1_0 donation:
# {
#   "thoughts": [
#     "1_3 has a relatively high amount of resources, which means they might be more willing to reciprocate if I donate generously. Their previous donation behavior shows they have been quite stingy, donating only 0.1% previously.",
#     "Since my goal is to build a cooperative relationship, I will opt to donate a larger amount rather than none. I’ll consider donating around 3 units again, which matches my initial strategy of fostering cooperation.",
#     "However, given that 1_3 has shown little willingness to donate much previously, I might want to adjust my donation to slightly lower than 3 to test their reaction without overcommitting my resources."
#   ],
#   "donation": 0.2
# }
#
#
# 1_2 donation:
# {
#   "thoughts": [
#     "1_1's previous donations are quite low, indicating they are either reluctant to give or strategically holding back. Therefore, their reciprocity cannot be trusted based on previous behaviors. My goal is to maximize my units while also reflecting their low donation tendency. Thus, I should restrict my donation this round to maintain a strong resource position, considering I have more resources than them. I can leverage my larger resource reserve but should do so cautiously to avoid significant losses."
#   ],
#   "donation": 0.1
# }
#
#
# 1_3 donation:
# {
#   "thoughts": [
#     "Given that 1_2 has a significantly higher amount of resources (19.37) than their previous donation behavior (0.05%), it suggests they may have a low donation rate. However, they are also likely aware of the benefits they gain from donations, given how they've maintained their resources.",
#     "Since my goal is also to optimize my own resources, I should determine a donation amount that balances the potential gain for 1_2 while still keeping enough for myself. Based on their low previous donation, I want to encourage them to donate more next round if I'm a recipient.",
#     "Considering 1_2's pattern, I will donate a moderate amount. A donation of approximately 15% seems appropriate; it's significant enough to potentially motivate them but not so high as to jeopardize my own resource pool."
#   ],
#   "donation": 0.15
# }
#
#
# 1_1 donation:
# {
#   "thoughts": [
#     "1_0 has shown a pattern of minimal donations (0.1%, 0.0555%, 0.0534%), which indicates they might not be very generous.",
#     "Given my current holdings (22.76 units) compared to 1_0's (12.57 units), I have a definite advantage. I want to encourage cooperation but also protect my resources.",
#     "I will donate an amount that is enough to incentivize 1_0 to give in the future, but not so much that it harms my position."
#   ],
#   "donation": 0.1
# }
#
#
# Evolving to generation 2
#
#
# Top half:
# player 1_2 with wallet 27.662474101614244 and strategy: My strategy will be to donate 3 units in the first round, and then adjust my donations based on the recipient's previous behavior, increasing my donations for generous recipients and decreasing them for those who do not reciprocate.
# player 1_3 with wallet 23.473077866659363 and strategy: My strategy will be to donate 20% of my resources in the first round and adjust my donations in subsequent rounds based on the recipient's previous donation behavior.
#
#
# 2_0 strategy:
# {
#   "thoughts": [
#     "In the first round, since there is no information about the recipient, I will donate a modest amount of resources to establish a foundation for reciprocity.",
#     "In subsequent rounds, I will adapt my donations based on the recipient's previous behavior, rewarding generous donations with increased contributions and being cautious with those who do not reciprocate."
#   ],
#   "strategy": "My strategy will be to donate 2 units in the first round and adjust my donations based on the recipient's previous behavior in subsequent rounds."
# }
#
#
# 2_1 strategy:
# {
#   "thoughts": [
#     "In the initial round, I will donate a moderate amount since I have no prior information on the recipient's behavior to avoid being overly generous or too stingy.",
#     "In subsequent rounds, I will analyze the recipient's previous donation behavior, adjusting my own donations accordingly: if the recipient was generous, I will respond with increased donations; if they were stingy, I will reduce my donations.",
#     "To encourage cooperation and maximize my score in the long run, I will strive to establish a pattern of reciprocity, promoting a positive interaction."
#   ],
#   "strategy": "My strategy will be to donate 4 units in the first round, then adjust my donations based on the recipient's recent donation behavior, increasing for generous partners and decreasing for uncooperative ones."
# }
#
#
# 2_2 strategy:
# {
#   "thoughts": [
#     "In the first round, I will start with a moderate donation since I have no prior information about my partner's behavior. This will show my willingness to cooperate while keeping enough resources to invest in future rounds. After the first round, I will analyze the donation behavior of my partner and their previous partners to decide how much to donate in subsequent rounds. If my partner donated generously, I will reward them with a similar donation to foster mutual cooperation. If they were stingy, I will minimize my donation to protect my resources."
#   ],
#   "strategy": "My strategy will be to donate 4 units in the first round, and adjust my donations based on the recipient's previous behaviors, increasing for generous donors and decreasing for those who do not reciprocate."
# }
#
#
# 2_3 strategy:
# {
#   "thoughts": [
#     "In the first round, since I have no information about the recipient's prior behavior, I should donate a small amount to test their willingness to reciprocate. A donation of around 2 units could be a good start as it balances the potential reward and risk.",
#     "In subsequent rounds, I will observe the donor behavior based on the recipient's recent actions. If they donated a significant amount, I can afford to be more generous in the next round, promoting a cycle of cooperation. Conversely, if they gave little, I will restrict my donation to encourage them to contribute more in future interactions."
#   ],
#   "strategy": "My strategy will be to donate 2 units in the first round, then adjust my donations based on the recipient's last round donation, increasing my donation for generous recipients and decreasing it for less generous ones."
# }
#
#
# Generation 2
#
#
# 	Generation 2 Round 1
#
#
# 2_0 donation:
# {
#   "thoughts": [
#     "I will donate the 2 units as planned for the first round because that is part of my established strategy.",
#     "I need to observe how 2_3 responds to my donation in the next round to inform my future decisions.",
#     "Considering 2_3 has 10 units, my donation of 2 units could show generosity and potentially influence their future donations."
#   ],
#   "donation": 0.2
# }
#
#
# 2_3 donation:
# {
#   "thoughts": [
#     "I am paired with 2_0 who has 8.0 units. My strategy indicates that I will donate 2 units in the first round. This amount is manageable for me as I still have 14.0 units left after the donation.",
#     "Since this is my first round of donation in this generation, I will stick to my initial plan and donate exactly 2 units regardless of 2_0's history since I don’t have information about their past donation behavior that may influence my decision.",
#     "Therefore, I will go ahead and donate 2 units."
#   ],
#   "donation": 0.14285714285714285
# }
#
#
# 2_1 donation:
# {
#   "thoughts": [
#     "I remember my strategy is to donate 4 units in the first round.",
#     "My partner, 2_2, has 10 units, indicating they might be cooperative.",
#     "Since this is my first round, I will stick to my plan and donate 4 units."
#   ],
#   "donation": 0.4
# }
#
#
# 2_2 donation:
# {
#   "thoughts": [
#     "I have a total of 18 units and want to start with my planned donation of 4 units. My strategy is to focus on being generous in the first round, while also observing the recipient's behavior for future rounds.",
#     "2_1 has 6 units, which indicates they might be in need of resources, and could reciprocate positively in the next round if I donate generously now.",
#     "Since I can afford to give 4 units without putting myself at risk, I will proceed with the planned donation."
#   ],
#   "donation": 0.222
# }
#
#
# 	Generation 2 Round 2
#
#
# 2_1 donation:
# {
#   "thoughts": [
#     "2_2 has a higher number of units (14.004) compared to my units (13.992), indicating they can afford to be generous or may expect high returns.",
#     "In round 1, 2_2 donated only a small amount (0.222%) to their partner, which suggests they may not be inclined to donate much in general.",
#     "Since my strategy is to reward generous behavior but 2_2's donation was minimal, it may imply they're not a cooperative player.",
#     "However, I don't want to punish them too harshly, as they may also give if I contribute a reasonable amount.",
#     "I will therefore donate a moderate amount to test 2_2's generosity: I choose to give 3 units."
#   ],
#   "donation": 0.214
# }
#
#
# 2_2 donation:
# {
#   "thoughts": [
#     "I need to evaluate how generous 2_1 was in the previous round.",
#     "2_1 donated only 0.4% of their resources, which is quite low and suggests they are not very generous.",
#     "Since 2_1 might not reciprocate generosity, I will aim for a conservative donation this round.",
#     "I want to maintain a good amount of my resources while still providing some benefit to 2_1."
#   ],
#   "donation": 0.1
# }
#
#
# 2_0 donation:
# {
#   "thoughts": [
#     "I need to decide on a donation amount based on 2_3's previous behavior in round 1. They donated a small percentage (0.14285714285714285%) of their resources, which indicates a level of generosity.",
#     "Since 2_3 currently has 12.0 units, their donation in the previous round (which is less than 0.02 units) suggests they might not be very altruistic. Therefore, I should be cautious about donating too much.",
#     "Given that I initially planned to donate 2 units, I will reduce my donation to a safer amount, considering 2_3's previous small donation. However, I want to maintain a balance that encourages cooperation, so I will donate 1 unit this time."
#   ],
#   "donation": 0.08333333333333333
# }
#
#
# 2_3 donation:
# {
#   "thoughts": [
#     "2_0 has 11.0 units, which means they have been somewhat generous, donating 0.2% in the previous round.",
#     "Since 2_0's previous donation was low, it suggests they may not be very willing to donate much in this situation.",
#     "To encourage them to be more generous in the next round, I should donate a moderate amount that shows I'm willing to cooperate.",
#     "Since I have 14.0 units, I could donate around 2 units as I initially planned, which is a fair amount without depleting my resources too much."
#   ],
#   "donation": 0.14285714285714285
# }
#
#
# 	Generation 2 Round 3
#
#
# 2_1 donation:
# {
#   "thoughts": [
#     "In the previous rounds, 2_0 has shown low generosity with a small donation of 0.0833% last round, indicating possibly self-centered behavior.",
#     "Since they received a slightly higher percentage donation from 2_3, this might indicate that other players have been more generous or cooperative, but the low donation from 2_0 suggests a lack of cooperation.",
#     "Given that this is round 3, I want to maintain some level of cooperation but also protect myself against potential exploitation.",
#     "I will consider donating a smaller amount, perhaps around 3 units, as it allows a reasonable benefit to the recipient while not significantly risking my own resource size. I can adjust future donations based on their future behaviors as well."
#   ],
#   "donation": 0.20000000000000004
# }
#
#
# 2_0 donation:
# {
#   "thoughts": [
#     "In round 1, 2_2 donated a small percentage of resources to 2_1, indicating that 2_1 is willing to receive donations but may not be a generous donor themselves based on the low percentage and their current resource level.",
#     "In round 2, 2_1 donated even less (0.214% of their resources) to 2_2. With their current resources of 11.996981759999999, they donated only about 0.0257 units. This suggests that 2_1 is not particularly inclined to give away a significant amount of their resources either.",
#     "Since my strategy includes donating a fixed amount initially and adjusting later based on behavior, I will consider giving a similar small donation. However, since I currently have a significant advantage over 2_1 with my 20.998490880000002 units, I can afford to be slightly more generous than their past donations."
#   ],
#   "donation": 0.05
# }
#
#
# 2_3 donation:
# {
#   "thoughts": [
#     "2_2 has shown a tendency to donate little (0.1% in round 2).",
#     "Since 2_2 is not a generous donor, I should be cautious and not give away too many units.",
#     "I want to maintain a strategic balance; since their last donation was low, I'll reduce my donation amount accordingly.",
#     "Given my current resource total of 12.0, I will calculate a reasonable percentage to give that reflects their uncooperative behavior."
#   ],
#   "donation": 0.1
# }
#
#
# 2_2 donation:
# {
#   "thoughts": [
#     "I need to decide on a donation amount based on my strategy and the behavior of my partner in previous rounds.",
#     "2_3 has a history of receiving a very small donation (0.14285714285714285% of their resources) compared to what they received previously (0.2% from 2_0). This indicates that 2_3 may not be very generous or reciprocal in donations.",
#     "Since I have a relatively high amount of resources (20.3933184 units), I can afford to be a bit more generous than I initially planned.",
#     "I will donate a reasonable percentage of my resources to encourage positive interactions in the following rounds, while also taking into account 2_3's past behaviors."
#   ],
#   "donation": 0.2
# }
#
#
# 	Generation 2 Round 4
#
#
# 2_0 donation:
# {
#   "thoughts": [
#     "My strategy is to donate 2 units in the first round and adjust in later rounds based on the recipient's behavior. Since I'm the donor this round, 2_2 has a considerably high amount of resources (16.31465472 units) and has shown a willingness to donate very little (0.2% last round). This suggests that they may be conservative with their donations, which means they might not reciprocate significantly in the next round if I donate a lot now.",
#     "Given this information, I will still donate a moderate amount to maintain a positive interaction without giving up too much of my resources. I will choose to donate 5 units, which balances my need to stay competitive while still showing a willingness to help 2_2."
#   ],
#   "donation": 0.25
# }
#
#
# 2_1 donation:
# {
#   "thoughts": [
#     "2_0 has a significant amount of resources, indicating they are likely to be more selfish based on their low donations in previous rounds.",
#     "Given that 2_0 only donated 0.05% in the last round, this suggests they are not inclined to cooperate generously.",
#     "I should donate less to avoid being taken advantage of, especially since they haven't shown willingness to reciprocate. I will start with a modest donation that reflects their previous behavior."
#   ],
#   "donation": 0.02
# }
#
#
# 2_3 donation:
# {
#   "thoughts": [
#     "In round 4, I'm donating to 2_1, who currently has more resources than I do.",
#     "2_1's previous donation was very low (0.2% of their resources), which shows they are likely to be less generous.",
#     "Since they are less generous, I should decrease my own donation to avoid giving away too much of my resources.",
#     "To keep a balance and ensure I retain more units for my own future, I will choose to donate a small amount instead."
#   ],
#   "donation": 0.05
# }
#
#
# 2_2 donation:
# {
#   "thoughts": [
#     "I have 26.2889 units and I'm paired with 2_3, who has 18.0095 units.",
#     "2_3 has shown very low generosity in the previous rounds, donating only 0.1% of their resources.",
#     "Given the lack of generosity from 2_3, I should avoid being too generous myself, as it may not result in a favorable outcome for my resources.",
#     "To balance being generous enough to encourage future reciprocation while protecting my resources, I will donate a small amount."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 2 Round 5
#
#
# 2_2 donation:
# {
#   "thoughts": [
#     "2_1 has a relatively high resource level compared to my own, indicating they may not be very generous based on their past donations.",
#     "In round 4, 2_1 donated only 0.02%, which suggests they are quite stingy.",
#     "Considering this, I should lower my donation to incentivize a better response in future rounds instead of giving them too much now.",
#     "I will opt for a conservative approach and donate a small amount, around 1 unit, to balance my resource effectively while still providing a benefit to 2_1."
#   ],
#   "donation": 0.0423
# }
#
#
# 2_1 donation:
# {
#   "thoughts": [
#     "2_2 has been consistently donating only 0.1% of their resources in previous rounds, which indicates that they may not be very cooperative or generous. Given that their current resource level is relatively high (22.66 units), they are likely to expect me to donate to them while offering little in return.",
#     "Since I want to maximize my resources, I should adjust my donation downwards to reflect 2_2's previous behavior. Instead of sticking to my original plan of giving up 4 units, I should donate less since 2_2 has shown a lack of generosity in past rounds.",
#     "To incentivize 2_2 while still protecting my resource pool, I will opt for a smaller donation, specifically around 5% of my current resources."
#   ],
#   "donation": 0.05
# }
#
#
# 2_3 donation:
# {
#   "thoughts": [
#     "2_0 has been generous in their previous rounds, making small donations (0.25%, 0.2%, and 0.142857% of their resources). This suggests they might be open to reciprocation and might donate back if I make a reasonable donation now.",
#     "I want to encourage this generosity while also ensuring I maintain a good resource level myself, so I need to find a balance in my donation.",
#     "Since I have 23.2672485696 units and they currently have 15.525297985920004 units, I'll consider donating a small percentage but more than what they've given to encourage ongoing reciprocity.",
#     "Based on my total resources, a donation of around 1 unit appears reasonable. This would not excessively deplete my resources while still providing a significant benefit to 2_0."
#   ],
#   "donation": 0.04296
# }
#
#
# 2_0 donation:
# {
#   "thoughts": [
#     "2_3 has a significant amount of resources (22.27 units) and has not been very generous in their previous donations (only 0.05% in round 4).",
#     "Since I want to maximize my units in the long run, I should be cautious about how much I donate to 2_3 because I need to ensure I still have a decent amount left for future rounds.",
#     "Given that 2_3's recent behavior suggests they may not reciprocate well, I should limit my donation to maintain my own resource base while still being somewhat cooperative."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 2 Round 6
#
#
# 2_1 donation:
# {
#   "thoughts": [
#     "2_2 has a high amount of resources (24.43 units), suggesting they are somewhat generous but have recently donated very little (0.0423% of their resources).",
#     "Since they have only donated a small amount, it indicates slightly uncooperative behavior, warranting a cautious approach.",
#     "Given my previous strategy of adjusting donations based on partner behavior, I will donate less than I originally planned, aiming to maintain my resource advantage while still providing some incentive for 2_2 to reciprocate if they decide to be generous.",
#     "Donating around 1 unit will keep me competitive and incentivize cooperation without giving away too much."
#   ],
#   "donation": 0.0593
# }
#
#
# 2_2 donation:
# {
#   "thoughts": [
#     "2_3 has a significantly higher resource amount than I do, which indicates they may have been generous in previous rounds despite only donating a small percentage. It suggests they may be strategic in their donations.",
#     "Based on my previous strategy, I want to incentivize 2_3 to be generous back to me in the next round by proving that I'm willing to share substantially in this round.",
#     "Given that 2_3's previous donation amounts were quite low, I should consider a moderate donation that shows I'm serious about cooperation but doesn't leave me too resource-poor for the following rounds.",
#     "My donation will be consistent with inducing a positive response from 2_3 in future rounds while still retaining enough resources for myself."
#   ],
#   "donation": 0.15
# }
#
#
# 2_0 donation:
# {
#   "thoughts": [
#     "2_1 has a higher resource total than I do and has shown very low levels of donation in previous rounds.",
#     "Given their donation history, it seems that they are not very generous, which could mean they might not reciprocate favorably in the future.",
#     "To maximize my resources while still being somewhat cooperative, I'll keep my donation low but still enough to encourage potential reciprocation in future rounds."
#   ],
#   "donation": 0.01
# }
#
#
# 2_3 donation:
# {
#   "thoughts": [
#     "I need to assess 2_0's donation behavior based on their past actions.",
#     "2_0 donated only 0.1% of their resources in round 5, which shows they are not very generous.",
#     "Since I want to encourage more generous behavior, I'll make a modest donation myself but not too much given their low previous donation."
#   ],
#   "donation": 0.01
# }
#
#
# Evolving to generation 3
#
#
# Top half:
# player 2_3 with wallet 33.36339517372971 and strategy: My strategy will be to donate 2 units in the first round, then adjust my donations based on the recipient's last round donation, increasing my donation for generous recipients and decreasing it for less generous ones.
# player 2_2 with wallet 22.462178193567063 and strategy: My strategy will be to donate 4 units in the first round, and adjust my donations based on the recipient's previous behaviors, increasing for generous donors and decreasing for those who do not reciprocate.
#
#
# 3_0 strategy:
# {
#   "thoughts": [
#     "Start with a moderate donation in the first round since there's no previous information about the recipient's behavior.",
#     "Observe how much the recipient donated in their last round, which gives insight into their tendency to reciprocate or not.",
#     "If the recipient was generous in their last round, increase my donation to show trust and foster cooperation.",
#     "If the recipient was stingy, decrease my donation to minimize losses while still participating in the game."
#   ],
#   "strategy": "My strategy will be to donate 3 units in the first round and adjust my donations based on the recipient's last round donation, increasing my donation for generous recipients and decreasing it for less generous ones."
# }
#
#
# 3_1 strategy:
# {
#   "thoughts": [
#     "In the first round, I have no information about the recipient's behavior, so I need to balance a generous approach with care to avoid giving away too much too early.",
#     "For the first round, I will donate a moderate amount to build goodwill but retain enough to secure a solid position in the next rounds.",
#     "As a recipient in the second round, I will observe the donor's previous round actions to gauge their generosity and adjust my donation accordingly in future rounds.",
#     "In general, I will adjust my donations based on perceived generosity, rewarding those who give more and being more cautious with those who give less."
#   ],
#   "strategy": "My strategy will be to donate 3 units in the first round, then adjust my donations in future rounds based on the most recent donor's behavior, increasing my donation for generous donors and reducing it for those who donate less."
# }
#
#
# 3_2 strategy:
# {
#   "thoughts": [
#     "In the first round, I need to balance risk and reward since I have no prior information on my partner. A donation that is neither too high nor too low would be optimal to gauge their response, so I will start with a donation of 3 units. In subsequent rounds, I will analyze the recipient's recent donation behavior. If they donated a significant amount to their previous partner, I will increase my donation because they are likely to be generous. If they donated little, I will scale back my donation to protect my resources."
#   ],
#   "strategy": "My strategy will be to donate 3 units in the first round and adjust my donations based on the recipient's last round behavior, increasing if they were generous and decreasing if they were not."
# }
#
#
# 3_3 strategy:
# {
#   "thoughts": [
#     "In the first round, I'll start with a moderate donation since I have no prior information about the recipient.",
#     "As I progress through the rounds, I'll base my next donations on what the recipient did in the last round, rewarding generosity and punishing lack of reciprocation.",
#     "I'll adopt a strategy that encourages cooperation while protecting my own resources."
#   ],
#   "strategy": "My strategy will be to donate 3 units in the first round, then increase my donation by 1 unit if the recipient donated at least 3 units in the last round; if not, I will donate either the same amount or decrease back to 2 units."
# }
#
#
# Generation 3
#
#
# 	Generation 3 Round 1
#
#
# 3_2 donation:
# {
#   "thoughts": [
#     "I will donate 3 units as per my strategy since it's the first round and I haven't observed 3_0's past behavior in this generation yet."
#   ],
#   "donation": 0.3
# }
#
#
# 3_0 donation:
# {
#   "thoughts": [
#     "I have a strategy to donate 3 units in the first round.",
#     "Since I currently have 16 units, donating 3 leaves me with 13, which is still a healthy amount.",
#     "Adjusting donations based on the recipient's past behavior is planned for future rounds, but for this round, I will stick to my initial plan."
#   ],
#   "donation": 0.1875
# }
#
#
# 3_1 donation:
# {
#   "thoughts": [
#     "I have 16 units and I planned to donate 3 units in the first round based on my strategy.",
#     "3_3 has 10 units, which indicates they might not be too risk-averse.",
#     "Since I have a favorable resource position, I can afford to stick to my initial donation plan of 3 units this round."
#   ],
#   "donation": 0.1875
# }
#
#
# 3_3 donation:
# {
#   "thoughts": [
#     "I am currently the donor in this round and I have 16.0 units of the resource. My strategy starts with a donation of 3 units in the first round. My partner, 3_2, has 7.0 units, which indicates they are likely to need some resource to increase their units, but their past donation behavior is unknown to me. Since I need to adhere to my strategy which states to donate 3 units in the first round, I will stick to this donation amount regardless of the partner's current resource status."
#   ],
#   "donation": 0.1875
# }
#
#
# 	Generation 3 Round 2
#
#
# 3_0 donation:
# {
#   "thoughts": [
#     "3_1 has a total of 13 units which is more than my strategy's initial donor, suggesting they might not be very generous since they only donated 0.1875% in round 1 (which is minimal).",
#     "Since 3_1 donated only a very small amount previously, it indicates they may not contribute much if they are in the role of donor next round.",
#     "To encourage potential generosity without losing too much, I will choose a modest donation that shows willingness to share but isn’t overly generous given 3_1's previous behavior."
#   ],
#   "donation": 0.2
# }
#
#
# 3_1 donation:
# {
#   "thoughts": [
#     "I have 18.2 units and my partner, 3_3, has given a small donation of 0.1875% in the last round, which indicates they are not very generous with their donations. Since they have 13 units and didn't give much before, I will consider giving a moderate amount to encourage reciprocity without overly sacrificing my own resources.",
#     "By donating a reasonable amount, I might prompt 3_3 to increase their donation next round, as they see I am willing to share significantly despite their low initial giving."
#   ],
#   "donation": 0.15
# }
#
#
# 3_2 donation:
# {
#   "thoughts": [
#     "3_0 donated only a small amount (0.1875% of their resources) in the previous round, which means they were not very generous.",
#     "Since they are likely to be cautious with their resources, I should adjust my donation accordingly this round.",
#     "Given that I have 13.0 units, I want to strike a balance between being generous and preserving my own units; hence, I will donate a small amount."
#   ],
#   "donation": 0.1
# }
#
#
# 3_3 donation:
# {
#   "thoughts": [
#     "I need to recall my strategy: I will donate 3 units in the first round, but in the current round, my donation depends on what the recipient (3_2) donated last round.",
#     "3_2 donated only 0.3% of their resources in round 1, which is not even close to the 3 units I would expect as a minimum donation.",
#     "Given that 3_2's donation was quite low, I should decrease my donation. I will choose to donate either the same amount (3 units) or decrease back to 2 units as per my strategy. Since their donation was minimal, it makes more sense to reduce my contribution to 2 units to ensure I maximize my resources while still contributing."
#   ],
#   "donation": 0.1084
# }
#
#
# 	Generation 3 Round 3
#
#
# 3_3 donation:
# {
#   "thoughts": [
#     "I need to assess how much to donate based on my strategy.",
#     "In round 1, 3_3 donated 0.1875% to 3_2, which is a very small donation and indicates that 3_3 may not be generous.",
#     "In round 2, 3_1 donated only 0.15% of their resources to 3_3, suggesting that 3_1 is also not a generous donor.",
#     "Since both previous donations were minimal, according to my strategy, I should either donate the same amount or decrease my donation back to 2 units.",
#     "My current strategy tells me that because 3_1 did not donate at least 3 units last round, I should not increase my donation."
#   ],
#   "donation": 0.12175887999999999
# }
#
#
# 3_0 donation:
# {
#   "thoughts": [
#     "In round 2, 3_2 only donated 0.1% of their resources, which indicates they are not very generous.",
#     "Given that 3_2 has more units than me, they may expect higher donations from me if paired with a less generous recipient.",
#     "To incentivize 3_2 to donate more in subsequent rounds, I should consider donating a smaller amount to balance the interactions and not overly rely on them.",
#     "I will choose to donate less than I initially planned, as evidence suggests 3_2 is not likely to reciprocate generously."
#   ],
#   "donation": 0.25
# }
#
#
# 3_2 donation:
# {
#   "thoughts": [
#     "3_3 has more units than me, suggesting they might be less inclined to be generous as they are already better off.",
#     "3_3 donated a very small percentage of their resources in their last round (0.1084%), indicating a lack of generosity.",
#     "Since my strategy involves adjusting my donations based on the recipient's past behavior, I'll donate a minimal amount to avoid weakening my own position excessively while still maintaining a cooperative stance."
#   ],
#   "donation": 0.01
# }
#
#
# 3_1 donation:
# {
#   "thoughts": [
#     "3_0 has 9.75 units and donated a very small amount (0.2% of resources) in the last round, indicating they are somewhat reluctant to give.",
#     "Given that I have a relatively high amount of resources (19.48 units), I want to ensure I'm still generous to encourage reciprocal generosity, especially given their past behavior.",
#     "Based on my strategy, I will donate a smaller amount than my initial 3 units since 3_0's previous donation was minimal and might indicate a more conservative approach. I want to be slightly generous but not overly so, to ensure I maintain a good balance."
#   ],
#   "donation": 0.2
# }
#
#
# 	Generation 3 Round 4
#
#
# 3_3 donation:
# {
#   "thoughts": [
#     "In round 3, 3_0 donated a very small amount (0.25% of their resources) which is approximately 0.0438 units;",
#     "In round 2, 3_2 donated even less (0.1% of their resources) to 3_0;",
#     "In round 1, 3_0's donation was also minimal (0.1875% which was about 0.033 units);",
#     "Given that 3_0 has consistently donated very low amounts, it indicates they might not have a strong inclination to donate generously in this game.",
# ...
#   ],
#   "donation": 0.2
# }
#
#
# 4_0 donation:
# {
#   "thoughts": [
#     "I am paired with 4_1 who has 7.0 units.",
#     "Since this is my first round as a donor and I want to follow my initial strategy, I will donate 4 units as planned.",
#     "This donation is consistent with my intention to support the recipient effectively while maintaining a good amount of resources for myself."
#   ],
#   "donation": 0.2439
# }
#
#
# 	Generation 4 Round 2
#
#
# 4_3 donation:
# {
#   "thoughts": [
#     "4_0 has shown a low donation in the previous round (0.2439% of their resources).",
#     "Since this is only round 2 and 4_0 hasn't established a pattern of cooperating (as their last donation was minimal), I should be cautious in my donation.",
#     "Following my strategy, I will maintain a conservative approach in my donation as 4_0's previous actions do not incentivize greater giving."
#   ],
#   "donation": 0.1
# }
#
#
# 4_0 donation:
# {
#   "thoughts": [
#     "First, I need to assess the previous behavior of my partner, 4_3, who donated only a small portion (0.2% of their resources) in the first round. This suggests they may not be inclined to donate significantly, indicating a potential low trust or cooperative spirit.",
#     "Since my strategy is to increase my donation if they donate at least 6 units, I should consider their likelihood of giving a reasonable amount based on their past behavior. With their current endowment of 11.52 units, they were unwilling to give much before.",
#     "Given their low donation in round 1, I decide to remain conservative in my donation this round to minimize potential losses, while still contributing enough to benefit from the multiplier effect if they do give back more than I donate."
#   ],
#   "donation": 0.26656
# }
#
#
# 4_1 donation:
# {
#   "thoughts": [
#     "Since I'm the donor this round, I need to decide how much to donate based on the recipient's previous behavior. 4_2 donated only 0.3% of their resources in the previous round, which is only about 0.04 units. This indicates that they may not be very generous. According to my strategy, I had initially thought about donating 3 units in the first round, but since the recipient's previous donation was low, I will reduce my donation accordingly.",
#     "My strategy suggests that I should maintain my donation or decide on a lower amount in response to their low contribution. Since they gave such a small amount (0.04 units), I will adjust my donation to 2 units this round. This keeps my response cautious and allows me to conserve resources for future rounds."
#   ],
#   "donation": 2.0
# }
#
#
# 4_2 donation:
# {
#   "thoughts": [
#     "4_1 has a total of 0 units and previously donated only 0.3% of their resources (which translates to 0.03 units) in round 1. This indicates that 4_1 might not be inclined to give, as they haven't had any resources to share except a minimal amount.",
#     "Since I have 42.99984 units, I can afford to be generous while also trying to ensure my own benefit in future rounds. By donating a reasonable amount, I'm likely incentivizing 4_1 to donate to me in the next round.",
#     "Given their previous donation percentage and current resource levels, I will donate a small but significant amount, enough to encourage giving in the future, while also keeping a substantial amount for myself."
#   ],
#   "donation": 0.1
# }
#
#
# 	Generation 4 Round 3
#
#
# 4_1 donation:
# {
#   "thoughts": [
#     "In this round, I have 8.599968 units and will follow my strategy.",
#     "I need to determine if my previous round partner, 4_0, was generous with their donation.",
#     "In round 2, 4_0 donated only 0.26656% of their resources, which is approximately 0.029 units.",
#     "Since they did not donate at least 3 units in the previous round, I should reduce my donation to 2 units."
#   ],
#   "donation": 0.23333315
# }
#
#
# 4_0 donation:
# {
#   "thoughts": [
#     "I have 14.985606984278398 units and I need to decide how much to donate to 4_3 who has a substantial amount (19.4954965248 units).",
#     "They donated only a tiny fraction (0.1% of their resources) in the last round, indicating a cautious approach to donating.",
#     "Since I am following a strategy where I increase my donation if the recipient donates at least 6 units, I need to assess what to do now: 4_3 is likely to expect a contribution due to their large resource base, but they haven't been very generous in the past.",
#     "Since 4_3 hasn't shown willingness to donate in larger amounts based on previous behavior, I will therefore keep my donation at a moderate level so as not to sacrifice too many of my units."
#   ],
#   "donation": 0.2666023900623477
# }
#
#
# 4_2 donation:
# {
#   "thoughts": [
#     "In round 2, 4_1 donated 2.0% of their resources (about 0.1319 units) to 4_2, which is relatively low considering their total resources. This indicates a less generous behavior. My strategy dictates that since 4_1 showed lower generosity, I should decrease my donation accordingly.",
#     "Since I currently have 38.699856 units, I want to maintain a balance between maximizing my resources and encouraging 4_1 to be more generous in future rounds. Therefore, I will consider giving a small amount, as they may not reciprocate high generosity.",
#     "Given their previous donation behavior and my strategy, I decide to give 1 unit, which is about 2.58% of my total resources. This allows me to keep a significant portion while still being helpful enough to encourage 4_1 to give more in the next round."
#   ],
#   "donation": 0.0258
# }
#
#
# 4_3 donation:
# {
#   "thoughts": [
#     "In round 1, I decided to donate 2 units, which is a baseline for my strategy. Now in round 3, my opponent, 4_2, has shown minimal donation behavior in previous rounds (0.1% and 0.3%).",
#     "Since 4_2's donations have been low, it's likely that they are not highly altruistic. Thus, I should be cautious about making a large donation myself.",
#     "Given 4_2's previous behavior and their current resource level of 37.7013 units, I will maintain a conservative approach and donate a smaller amount this round. I will choose to slightly decrease my donation from the initial 2 units."
#   ],
#   "donation": 0.05
# }
#
#
# 	Generation 4 Round 4
#
#
# 4_1 donation:
# {
#   "thoughts": [
#     "In this round, I am the donor and I have 8.5902229462608 units.",
#     "I need to analyze the donation pattern of my partner, 4_2.",
#     "4_2 has been donating very little in the previous rounds, indicating a cautious strategy.",
#     "In round 3, 4_2 donated only 0.0258% of their resources, which is negligible given their large resource pool.",
#     "Since 4_2 did not donate at least 3 units previously, according to my strategy, I will reduce or maintain my previous donation.",
#     "I will maintain my donation at 3 units because it's my initial strategy to promote goodwill, even if the recipient might not donate a lot. If they prove to be generous, I can increase it in the next round."
#   ],
#   "donation": 0.3498172065659493
# }
#
#
# 4_2 donation:
# {
#   "thoughts": [
#     "4_3 has a relatively high resource count (26.11), and they have exhibited minimal generosity (only donating 0.05% in the previous round).",
#     "Given their low donation rate, it indicates a more self-interested player, which means I shouldn't give too much to ensure I maintain a good resource reserve.",
#     "I should consider matching their previous behavior slightly, offering enough to stay competitive but not overly generous to avoid losing a significant amount.",
#     "Based on their behavior, donating 3 units feels appropriate as it is a moderate contribution that keeps a good balance for a competitive play."
#   ],
#   "donation": 0.0646152336881947
# }
#
#
# 4_0 donation:
# {
#   "thoughts": [
#     "I start with 10.99 units, which gives me a comfortable cushion for donating.",
#     "My strategy states that I will donate 4 units in the first round, considering this is round 4, I need to analyze the previous donations from 4_1 to adjust accordingly.",
#     "4_1 has 5.5852 units. In round 3 they donated 0.23333315% of their resources, which is a very low amount.",
#     "Given that previous donations have generally been low (0.2% and 0.26656%), I can expect that 4_1 might not be willing to donate much back if I give a significant amount.",
#     "However, I want to incentivize 4_1 to give at least something back, so I will donate more than their previous percentages, aiming for a slightly higher than normal donation but not excessive."
#   ],
#   "donation": 0.25
# }
#
#
# 4_3 donation:
# {
#   "thoughts": [
#     "In this round, I'm the donor and I need to decide how many units to give up to maximize my end resource after the final rounds.",
#     "I have 32.11564723155349 units, and my strategy from earlier rounds suggests I typically donate 2 units in the first round but since I'm in the fourth round, I should evaluate past donations of my partner, 4_0.",
#     "4_0 donated 0.2666023900623477% of their resources in round 3, which is a low donation given their endowment of 8.242806259301076 units. This means they might not be inclined to reciprocate significantly.",
#     "In the previous rounds, it appears they haven't donated much, indicating a possibly more selfish strategy. Being cautious, I should not increase my donation too much but rather keep it moderate to safeguard my resources for future rounds.",
#     "I’ll donate 2 units as per my previous strategy since their last donation was still under 2 units proportional to their holdings."
#   ],
#   "donation": 0.06219218858010454
# }
#
#
# 	Generation 4 Round 5
#
#
# 4_3 donation:
# {
#   "thoughts": [
#     "In the previous rounds, 4_2 donated very small amounts (0.0646% and 0.1%) of their resources, which is significantly less than what I am planning for my donations.",
#     "Given they have a substantial amount of resources (43.45798062518777), their previous donation size indicates they might be cautious about giving away resources and may not expect much in return.",
#     "Since my strategy dictates to increase my donation by 1 unit if my recipient donated 2 or more units in their last round, and seeing their past donations have been very low, I should maintain or decrease my donation.",
#     "To adopt a more cautious approach based on 4_2's low donation behavior, I will decide to donate 2 units."
#   ],
#   "donation": 2.0
# }
#
#
# 4_0 donation:
# {
#   "thoughts": [
#     "I have 12.23749103729485 units and I'm the donor this round. Based on my strategy, I need to consider the behavior of 4_1 in previous rounds.",
#     "4_1 has shown willingness to donate, with their last donation being around 0.35% of their resources, which indicates they might be open to giving.",
#     "Since they have 11.08 units now, a donation of 2.0% in earlier rounds suggests their willingness to share, so I consider donating a moderate amount.",
#     "I want to increase the donation compared to my last round. Given that they might be inclined to donate, I will donate 4 units, which is a solid amount to encourage reciprocity."
#   ],
#   "donation": 0.3270293335336035
# }
#
#
# 4_2 donation:
# {
#   "thoughts": [
#     "In this round, I am the donor, and my partner, 4_3, has 0.0 units, which means they cannot reciprocate even if they wanted to. Given their behavior in previous rounds, they have exhibited low donation percentages. However, I believe in adjusting based on context.",
#     "Since they have no units, I will donate a small amount to help them recover and possibly encourage more generous behavior in future rounds. My goal remains to maximize my units rather than take a risk of donating too much now.",
#     "I will choose to donate 3 units as I initially planned, as it maintains my strategy's consistency."
#   ],
#   "donation": 3.0
# }
#
#
# 4_1 donation:
# {
#   "thoughts": [
#     "In this round, I am the donor, and I have 19.084456400388476 units of the resource.",
#     "I observe that 4_0 has 8.23547249924487 units, and based on their previous donations, they donated very little in the last round (only 0.25% which is quite small) and have not shown a consistent trend of generous donations.",
#     "Given that 4_0's past donations were minimal, it might indicate a lack of trust or willingness to give more resources in the hopes of receiving additional units later.",
#     "To ensure I maximize my resources and still aid the recipient while also being strategic, I decide to donate 3 units. This is in line with my initial strategy and allows me to test what kind of interaction we will have this round."
#   ],
#   "donation": 3.0
# }
#
#
# 	Generation 4 Round 6
#
#
# 4_1 donation:
# {
#   "thoughts": [
#     "I have 0 units of the resource, so I cannot donate any units.",
#     "Given that my strategy involves increasing or decreasing donations based on the recipient's past behavior, I cannot apply that here since I have no resources to donate.",
#     "Since I cannot donate any units, I will make a donation of 0 units."
#   ],
#   "donation": 0.0
# }
#
#
# 4_0 donation:
# {
#   "thoughts": [
#     "4_3 has a very high amount of resources compared to the usual range, indicating they are potentially employing a more selfish or strategically cautious approach.",
#     "In the previous rounds, 4_3's donations to others have been quite low (only 2% and 0.05%). This implies that they may not be highly generous.",
#     "Considering that 4_3 didn't give much in the previous rounds, I should be cautious about how much I donate this round.",
#     "Since I'm supposed to donate based on their previous donations, and they donated low amounts, I will donate a smaller percentage as a balance between being generous and protecting my assets."
#   ],
#   "donation": 0.1
# }
#
#
# 4_3 donation:
# {
#   "thoughts": [
#     "I am playing as the donor this round.",
#     "4_1 currently has 0 units, which means they cannot donate anything and are completely dependent on my generosity.",
#     "Since my strategy involves increasing donations based on the recipient's past behavior and 4_1 did not donate anything in their last round (I can't base my decision on them), I need to decide how much to donate.",
#     "Since 4_1 is at 0 units, I might consider making a meaningful donation but limit it to avoid being overly generous since they cannot reciprocate.",
#     "Given that I have 216.67 units, donating 6 units would give 12 to 4_1, making it a pivotal moment as it greatly increases their resource while preserving enough for me."
#   ],
#   "donation": 0.02769380605081515
# }
#
#
# 4_2 donation:
# {
#   "thoughts": [
#     "I can see that my partner 4_0 has a decent amount of resources (41.76 units) and has recently donated a small percentage (0.33%) to their previous partner.",
#     "Since I am in a position to influence their resources positively, I want to make a donation that encourages them to continue being generous. My previous strategy was to start with a specific donation, so I consider that.",
#     "To align with my strategy, I will consider a donation that gives 4_0 a notable benefit but avoids giving away too much of my own resources, as I currently have 0 units."
#   ],
#   "donation": 0.0
# }
#
#
# Final players:
# player 4_3 with wallet 210.6696391261807 and strategy: My strategy will be to donate 2 units in the first round, then increase my donation by 1 unit if my recipient donated 2 or more units in their last round, otherwise maintain or decrease my donation slightly.
# player 4_0 with wallet 41.76394677001964 and strategy: My strategy will be to donate 4 units in the first round, increase my donation if the recipient donates at least 6 units, and decrease it if they donate less.
# player 4_1 with wallet 12.000837108851286 and strategy: My strategy will be to donate 3 units in the first round, then increase my donation by 1 unit if the recipient donated at least 3 units; otherwise, I will reduce my donation to 2 units or maintain my previous donation.
# player 4_2 with wallet 0.0 and strategy: My strategy will be to donate 3 units in the first round and adjust future donations based on the recipient's last round donation, increasing for generous behavior and decreasing for less generous behavior.

# %%
# !pip freeze > requirements.txt
